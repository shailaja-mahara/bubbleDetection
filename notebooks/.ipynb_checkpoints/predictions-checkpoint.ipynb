# %%
# training rough model

import os
import json
from pathlib import Path

import numpy as np
from tensorflow.keras import layers, models
import tensorflow as tf
import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch

# %%
DATA_DIR = Path("../data/processed/augmented")
FIGURE_DIR = '../outputs/figures'
PLOTS_DIR = '../outputs/figures/plots'
MODEL_DIR = Path("../outputs/models")
OUTPUT_DIR = Path("../outputs")

ACTIVE_STAGE = "stage05"

os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(FIGURE_DIR, exist_ok=True)
os.makedirs(PLOTS_DIR, exist_ok=True)

# %%
SEED = 42
EPOCHS = 100
BATCH_SIZE = 4

# WEIGHT = 0.5
# WEIGHT = 1.0
# WEIGHT = 1.5
WEIGHT = 2.0

EARLY_STOPPING_PATIENCE = 15

tf.keras.utils.set_random_seed(SEED)

X_train = np.load(DATA_DIR / "XtrainAug.npy").astype(np.float32)
X_val = np.load(DATA_DIR / "Xval.npy").astype(np.float32)
Y_train = np.load(DATA_DIR / "YtrainAug.npy").astype(np.float32)
Y_val = np.load(DATA_DIR / "Yval.npy").astype(np.float32)

print("X_train shape:", X_train.shape, "dtype:", X_train.dtype, "min/max:", X_train.min(), X_train.max())
print("X_val shape:", X_val.shape, "dtype:", X_val.dtype, "min/max:", X_val.min(), X_val.max())
print("Y_train shape:", Y_train.shape, "dtype:", Y_train.dtype, "min/max:", Y_train.min(), Y_train.max())
print("Y_val shape:", Y_val.shape, "dtype:", Y_val.dtype, "min/max:", Y_val.min(), Y_val.max())

print("Training foreground ratio:", float(Y_train.mean()))
print("Validation foreground ratio:", float(Y_val.mean()))
# Out:
# X_train shape: (384, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# X_val shape: (21, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_train shape: (384, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_val shape: (21, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Training foreground ratio: 0.20140759646892548
# Validation foreground ratio: 0.2084437757730484

# %%
# # simple unet model
# # inputs → encoder → bottleneck → decoder → sigmoid mask

# def build_unet(input_shape=(256, 256, 1)):
#     inputs = layers.Input(input_shape)

#     # Encoder
#     c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
#     c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
#     p1 = layers.MaxPooling2D()(c1)

#     c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
#     c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
#     p2 = layers.MaxPooling2D()(c2)

#     # Bottleneck
#     b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
#     b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(b1)

#     # Decoder
#     u1 = layers.UpSampling2D()(b1)
#     u1 = layers.concatenate([u1, c2])
#     c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(u1)
#     c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(c3)

#     u2 = layers.UpSampling2D()(c3)
#     u2 = layers.concatenate([u2, c1])
#     c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(u2)
#     c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(c4)

#     outputs = layers.Conv2D(1, 1, activation='sigmoid')(c4)

#     return models.Model(inputs, outputs, name="bubble_unet")

# %%
# 4-level unet model
# inputs → encoder (4 levels) → bottleneck → decoder (4 levels) → sigmoid mask

def build_unet(input_shape=(256, 256, 1)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D()(c1)

    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D()(c2)

    c3 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(64, 3, activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D()(c3)

    c4 = layers.Conv2D(128, 3, activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(128, 3, activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D()(c4)

    # Bottleneck (16x16 spatial resolution)
    b1 = layers.Conv2D(256, 3, activation='relu', padding='same')(p4)
    b1 = layers.Conv2D(256, 3, activation='relu', padding='same')(b1)

    # Decoder
    u4 = layers.UpSampling2D()(b1)
    u4 = layers.concatenate([u4, c4])
    d4 = layers.Conv2D(128, 3, activation='relu', padding='same')(u4)
    d4 = layers.Conv2D(128, 3, activation='relu', padding='same')(d4)

    u3 = layers.UpSampling2D()(d4)
    u3 = layers.concatenate([u3, c3])
    d3 = layers.Conv2D(64, 3, activation='relu', padding='same')(u3)
    d3 = layers.Conv2D(64, 3, activation='relu', padding='same')(d3)

    u2 = layers.UpSampling2D()(d3)
    u2 = layers.concatenate([u2, c2])
    d2 = layers.Conv2D(32, 3, activation='relu', padding='same')(u2)
    d2 = layers.Conv2D(32, 3, activation='relu', padding='same')(d2)

    u1 = layers.UpSampling2D()(d2)
    u1 = layers.concatenate([u1, c1])
    d1 = layers.Conv2D(16, 3, activation='relu', padding='same')(u1)
    d1 = layers.Conv2D(16, 3, activation='relu', padding='same')(d1)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(d1)

    return models.Model(inputs, outputs, name="bubble_unet4")

# %%
def dice_loss(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) /
                (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth))

def weighted_bce(y_true, y_pred):
    y_pred = tf.clip_by_value(
        y_pred,
        tf.keras.backend.epsilon(),
        1 - tf.keras.backend.epsilon()
    )

    weights = y_true * WEIGHT + 1
    bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)

    return tf.reduce_mean(weights * bce)

def combined_loss(y_true, y_pred):
    return weighted_bce(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def iou_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss,
    metrics=[dice_coef, iou_coef]
)
model.summary()
# Out:
# Model: "bubble_unet4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_114 (Conv2D) │ (None, 256, 256,  │        160 │ input_layer_6[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_115 (Conv2D) │ (None, 256, 256,  │      2,320 │ conv2d_114[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_24    │ (None, 128, 128,  │          0 │ conv2d_115[0][0]  │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_116 (Conv2D) │ (None, 128, 128,  │      4,640 │ max_pooling2d_24… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_117 (Conv2D) │ (None, 128, 128,  │      9,248 │ conv2d_116[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_25    │ (None, 64, 64,    │          0 │ conv2d_117[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_118 (Conv2D) │ (None, 64, 64,    │     18,496 │ max_pooling2d_25… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_119 (Conv2D) │ (None, 64, 64,    │     36,928 │ conv2d_118[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_26    │ (None, 32, 32,    │          0 │ conv2d_119[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_120 (Conv2D) │ (None, 32, 32,    │     73,856 │ max_pooling2d_26… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_121 (Conv2D) │ (None, 32, 32,    │    147,584 │ conv2d_120[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_27    │ (None, 16, 16,    │          0 │ conv2d_121[0][0]  │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_122 (Conv2D) │ (None, 16, 16,    │    295,168 │ max_pooling2d_27… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_123 (Conv2D) │ (None, 16, 16,    │    590,080 │ conv2d_122[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_24    │ (None, 32, 32,    │          0 │ conv2d_123[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_24      │ (None, 32, 32,    │          0 │ up_sampling2d_24… │
# │ (Concatenate)       │ 384)              │            │ conv2d_121[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_124 (Conv2D) │ (None, 32, 32,    │    442,496 │ concatenate_24[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_125 (Conv2D) │ (None, 32, 32,    │    147,584 │ conv2d_124[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_25    │ (None, 64, 64,    │          0 │ conv2d_125[0][0]  │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_25      │ (None, 64, 64,    │          0 │ up_sampling2d_25… │
# │ (Concatenate)       │ 192)              │            │ conv2d_119[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_126 (Conv2D) │ (None, 64, 64,    │    110,656 │ concatenate_25[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_127 (Conv2D) │ (None, 64, 64,    │     36,928 │ conv2d_126[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_26    │ (None, 128, 128,  │          0 │ conv2d_127[0][0]  │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_26      │ (None, 128, 128,  │          0 │ up_sampling2d_26… │
# │ (Concatenate)       │ 96)               │            │ conv2d_117[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_128 (Conv2D) │ (None, 128, 128,  │     27,680 │ concatenate_26[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_129 (Conv2D) │ (None, 128, 128,  │      9,248 │ conv2d_128[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_27    │ (None, 256, 256,  │          0 │ conv2d_129[0][0]  │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_27      │ (None, 256, 256,  │          0 │ up_sampling2d_27… │
# │ (Concatenate)       │ 48)               │            │ conv2d_115[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_130 (Conv2D) │ (None, 256, 256,  │      6,928 │ concatenate_27[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_131 (Conv2D) │ (None, 256, 256,  │      2,320 │ conv2d_130[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_132 (Conv2D) │ (None, 256, 256,  │         17 │ conv2d_131[0][0]  │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,962,337 (7.49 MB)
#  Trainable params: 1,962,337 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# checkpoint the best epoch, stop when validation stalls, lower LR on plateau

BEST_WEIGHTS_PATH = os.path.join(MODEL_DIR, f"{ACTIVE_STAGE}bubble_unet_best.weights.h5")
HISTORY_CSV_PATH = os.path.join(OUTPUT_DIR, f"{ACTIVE_STAGE}training_history.csv")

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(BEST_WEIGHTS_PATH),
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1,
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        verbose=1,
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        mode="min",
        factor=0.5,
        patience=6,
        min_lr=1e-6,
        verbose=1,
    ),
    tf.keras.callbacks.CSVLogger(str(HISTORY_CSV_PATH)),
]

# %%
history = model.fit(
    X_train,
    Y_train,
    validation_data=(X_val, Y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    shuffle=True,
    callbacks=callbacks
)

# all later evaluation must use the best checkpointed epoch, not the last one
model.load_weights(BEST_WEIGHTS_PATH)
# Out:
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - dice_coef: 0.2770 - iou_coef: 0.1626 - loss: 1.6806
# Epoch 1: val_dice_coef improved from None to 0.30789, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 1: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 38s 354ms/step - dice_coef: 0.2843 - iou_coef: 0.1674 - loss: 1.6546 - val_dice_coef: 0.3079 - val_iou_coef: 0.1850 - val_loss: 1.6158 - learning_rate: 1.0000e-04
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - dice_coef: 0.3075 - iou_coef: 0.1830 - loss: 1.5630
# Epoch 2: val_dice_coef improved from 0.30789 to 0.31226, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 2: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 345ms/step - dice_coef: 0.3083 - iou_coef: 0.1837 - loss: 1.5688 - val_dice_coef: 0.3123 - val_iou_coef: 0.1881 - val_loss: 1.6178 - learning_rate: 1.0000e-04
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - dice_coef: 0.3116 - iou_coef: 0.1860 - loss: 1.5587
# Epoch 3: val_dice_coef improved from 0.31226 to 0.31543, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 3: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 344ms/step - dice_coef: 0.3135 - iou_coef: 0.1875 - loss: 1.5655 - val_dice_coef: 0.3154 - val_iou_coef: 0.1905 - val_loss: 1.6176 - learning_rate: 1.0000e-04
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - dice_coef: 0.3194 - iou_coef: 0.1916 - loss: 1.5513
# Epoch 4: val_dice_coef did not improve from 0.31543
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 357ms/step - dice_coef: 0.3220 - iou_coef: 0.1936 - loss: 1.5495 - val_dice_coef: 0.2793 - val_iou_coef: 0.1638 - val_loss: 1.6880 - learning_rate: 1.0000e-04
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - dice_coef: 0.3132 - iou_coef: 0.1873 - loss: 1.5742
# Epoch 5: val_dice_coef did not improve from 0.31543
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 342ms/step - dice_coef: 0.3140 - iou_coef: 0.1879 - loss: 1.5733 - val_dice_coef: 0.2995 - val_iou_coef: 0.1784 - val_loss: 1.6242 - learning_rate: 1.0000e-04
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - dice_coef: 0.3148 - iou_coef: 0.1885 - loss: 1.5789
# Epoch 6: val_dice_coef did not improve from 0.31543
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 342ms/step - dice_coef: 0.3173 - iou_coef: 0.1904 - loss: 1.5726 - val_dice_coef: 0.3076 - val_iou_coef: 0.1841 - val_loss: 1.6163 - learning_rate: 1.0000e-04
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - dice_coef: 0.3217 - iou_coef: 0.1935 - loss: 1.5674
# Epoch 7: val_dice_coef improved from 0.31543 to 0.31581, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 7: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 340ms/step - dice_coef: 0.3161 - iou_coef: 0.1894 - loss: 1.5655 - val_dice_coef: 0.3158 - val_iou_coef: 0.1906 - val_loss: 1.6077 - learning_rate: 1.0000e-04
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - dice_coef: 0.3193 - iou_coef: 0.1916 - loss: 1.5495
# Epoch 8: val_dice_coef did not improve from 0.31581
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 340ms/step - dice_coef: 0.3212 - iou_coef: 0.1930 - loss: 1.5464 - val_dice_coef: 0.3126 - val_iou_coef: 0.1877 - val_loss: 1.5903 - learning_rate: 1.0000e-04
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - dice_coef: 0.3257 - iou_coef: 0.1962 - loss: 1.5527
# Epoch 9: val_dice_coef improved from 0.31581 to 0.31934, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 9: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 353ms/step - dice_coef: 0.3217 - iou_coef: 0.1933 - loss: 1.5540 - val_dice_coef: 0.3193 - val_iou_coef: 0.1932 - val_loss: 1.6028 - learning_rate: 1.0000e-04
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - dice_coef: 0.3267 - iou_coef: 0.1968 - loss: 1.5342
# Epoch 10: val_dice_coef improved from 0.31934 to 0.33814, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 10: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 367ms/step - dice_coef: 0.3354 - iou_coef: 0.2032 - loss: 1.5159 - val_dice_coef: 0.3381 - val_iou_coef: 0.2061 - val_loss: 1.5648 - learning_rate: 1.0000e-04
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - dice_coef: 0.3255 - iou_coef: 0.1961 - loss: 1.5567
# Epoch 11: val_dice_coef did not improve from 0.33814
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 345ms/step - dice_coef: 0.3218 - iou_coef: 0.1934 - loss: 1.5536 - val_dice_coef: 0.3218 - val_iou_coef: 0.1949 - val_loss: 1.5955 - learning_rate: 1.0000e-04
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - dice_coef: 0.3318 - iou_coef: 0.2004 - loss: 1.5218
# Epoch 12: val_dice_coef improved from 0.33814 to 0.35421, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 12: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 348ms/step - dice_coef: 0.3412 - iou_coef: 0.2074 - loss: 1.5031 - val_dice_coef: 0.3542 - val_iou_coef: 0.2179 - val_loss: 1.5409 - learning_rate: 1.0000e-04
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - dice_coef: 0.3377 - iou_coef: 0.2049 - loss: 1.5116
# Epoch 13: val_dice_coef did not improve from 0.35421
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 36s 374ms/step - dice_coef: 0.3444 - iou_coef: 0.2098 - loss: 1.4925 - val_dice_coef: 0.3464 - val_iou_coef: 0.2122 - val_loss: 1.5754 - learning_rate: 1.0000e-04
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - dice_coef: 0.3435 - iou_coef: 0.2091 - loss: 1.5001
# Epoch 14: val_dice_coef did not improve from 0.35421
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 370ms/step - dice_coef: 0.3493 - iou_coef: 0.2133 - loss: 1.4842 - val_dice_coef: 0.3508 - val_iou_coef: 0.2154 - val_loss: 1.5655 - learning_rate: 1.0000e-04
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - dice_coef: 0.3504 - iou_coef: 0.2142 - loss: 1.4841
# Epoch 15: val_dice_coef improved from 0.35421 to 0.36136, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 15: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 362ms/step - dice_coef: 0.3563 - iou_coef: 0.2184 - loss: 1.4676 - val_dice_coef: 0.3614 - val_iou_coef: 0.2232 - val_loss: 1.5297 - learning_rate: 1.0000e-04
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - dice_coef: 0.3607 - iou_coef: 0.2217 - loss: 1.4604
# Epoch 16: val_dice_coef improved from 0.36136 to 0.36468, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 16: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 354ms/step - dice_coef: 0.3633 - iou_coef: 0.2237 - loss: 1.4527 - val_dice_coef: 0.3647 - val_iou_coef: 0.2259 - val_loss: 1.5245 - learning_rate: 1.0000e-04
# Epoch 17/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - dice_coef: 0.3650 - iou_coef: 0.2248 - loss: 1.4505
# Epoch 17: val_dice_coef did not improve from 0.36468
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 359ms/step - dice_coef: 0.3654 - iou_coef: 0.2252 - loss: 1.4491 - val_dice_coef: 0.3643 - val_iou_coef: 0.2256 - val_loss: 1.5329 - learning_rate: 1.0000e-04
# Epoch 18/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - dice_coef: 0.3683 - iou_coef: 0.2275 - loss: 1.4426
# Epoch 18: val_dice_coef improved from 0.36468 to 0.37288, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 18: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 363ms/step - dice_coef: 0.3702 - iou_coef: 0.2290 - loss: 1.4351 - val_dice_coef: 0.3729 - val_iou_coef: 0.2322 - val_loss: 1.4892 - learning_rate: 1.0000e-04
# Epoch 19/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - dice_coef: 0.3769 - iou_coef: 0.2342 - loss: 1.4215
# Epoch 19: val_dice_coef improved from 0.37288 to 0.38129, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 19: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 368ms/step - dice_coef: 0.3795 - iou_coef: 0.2362 - loss: 1.4133 - val_dice_coef: 0.3813 - val_iou_coef: 0.2386 - val_loss: 1.4538 - learning_rate: 1.0000e-04
# Epoch 20/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - dice_coef: 0.3787 - iou_coef: 0.2355 - loss: 1.4197
# Epoch 20: val_dice_coef improved from 0.38129 to 0.38132, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 20: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 36s 374ms/step - dice_coef: 0.3823 - iou_coef: 0.2384 - loss: 1.4085 - val_dice_coef: 0.3813 - val_iou_coef: 0.2385 - val_loss: 1.4825 - learning_rate: 1.0000e-04
# Epoch 21/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - dice_coef: 0.3928 - iou_coef: 0.2465 - loss: 1.3855
# Epoch 21: val_dice_coef did not improve from 0.38132
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 363ms/step - dice_coef: 0.3981 - iou_coef: 0.2506 - loss: 1.3718 - val_dice_coef: 0.3641 - val_iou_coef: 0.2247 - val_loss: 1.5584 - learning_rate: 1.0000e-04
# Epoch 22/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - dice_coef: 0.4035 - iou_coef: 0.2549 - loss: 1.3658
# Epoch 22: val_dice_coef improved from 0.38132 to 0.38401, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 22: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 356ms/step - dice_coef: 0.4098 - iou_coef: 0.2600 - loss: 1.3469 - val_dice_coef: 0.3840 - val_iou_coef: 0.2401 - val_loss: 1.5211 - learning_rate: 1.0000e-04
# Epoch 23/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - dice_coef: 0.4134 - iou_coef: 0.2627 - loss: 1.3473
# Epoch 23: val_dice_coef improved from 0.38401 to 0.39382, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 23: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 356ms/step - dice_coef: 0.4098 - iou_coef: 0.2599 - loss: 1.3496 - val_dice_coef: 0.3938 - val_iou_coef: 0.2480 - val_loss: 1.4807 - learning_rate: 1.0000e-04
# Epoch 24/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - dice_coef: 0.4259 - iou_coef: 0.2726 - loss: 1.3160
# Epoch 24: val_dice_coef improved from 0.39382 to 0.40941, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 24: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 363ms/step - dice_coef: 0.4257 - iou_coef: 0.2727 - loss: 1.3122 - val_dice_coef: 0.4094 - val_iou_coef: 0.2606 - val_loss: 1.4672 - learning_rate: 1.0000e-04
# Epoch 25/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - dice_coef: 0.4368 - iou_coef: 0.2816 - loss: 1.2930
# Epoch 25: val_dice_coef did not improve from 0.40941
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 359ms/step - dice_coef: 0.4351 - iou_coef: 0.2805 - loss: 1.2919 - val_dice_coef: 0.4060 - val_iou_coef: 0.2576 - val_loss: 1.4731 - learning_rate: 1.0000e-04
# Epoch 26/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - dice_coef: 0.4550 - iou_coef: 0.2968 - loss: 1.2513
# Epoch 26: val_dice_coef improved from 0.40941 to 0.41099, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 26: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 353ms/step - dice_coef: 0.4569 - iou_coef: 0.2988 - loss: 1.2413 - val_dice_coef: 0.4110 - val_iou_coef: 0.2617 - val_loss: 1.4503 - learning_rate: 5.0000e-05
# Epoch 27/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - dice_coef: 0.4677 - iou_coef: 0.3078 - loss: 1.2180
# Epoch 27: val_dice_coef improved from 0.41099 to 0.41457, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 27: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 364ms/step - dice_coef: 0.4689 - iou_coef: 0.3091 - loss: 1.2140 - val_dice_coef: 0.4146 - val_iou_coef: 0.2647 - val_loss: 1.4683 - learning_rate: 5.0000e-05
# Epoch 28/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - dice_coef: 0.4792 - iou_coef: 0.3177 - loss: 1.1919
# Epoch 28: val_dice_coef improved from 0.41457 to 0.42102, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 28: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 359ms/step - dice_coef: 0.4792 - iou_coef: 0.3182 - loss: 1.1912 - val_dice_coef: 0.4210 - val_iou_coef: 0.2699 - val_loss: 1.4854 - learning_rate: 5.0000e-05
# Epoch 29/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - dice_coef: 0.4929 - iou_coef: 0.3299 - loss: 1.1606
# Epoch 29: val_dice_coef improved from 0.42102 to 0.42102, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 29: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 358ms/step - dice_coef: 0.4917 - iou_coef: 0.3291 - loss: 1.1633 - val_dice_coef: 0.4210 - val_iou_coef: 0.2698 - val_loss: 1.5137 - learning_rate: 5.0000e-05
# Epoch 30/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - dice_coef: 0.5058 - iou_coef: 0.3414 - loss: 1.1324
# Epoch 30: val_dice_coef improved from 0.42102 to 0.42115, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 30: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 359ms/step - dice_coef: 0.5039 - iou_coef: 0.3399 - loss: 1.1370 - val_dice_coef: 0.4212 - val_iou_coef: 0.2700 - val_loss: 1.5152 - learning_rate: 5.0000e-05
# Epoch 31/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - dice_coef: 0.5174 - iou_coef: 0.3518 - loss: 1.1051
# Epoch 31: val_dice_coef improved from 0.42115 to 0.43073, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 31: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 356ms/step - dice_coef: 0.5158 - iou_coef: 0.3505 - loss: 1.1114 - val_dice_coef: 0.4307 - val_iou_coef: 0.2782 - val_loss: 1.4877 - learning_rate: 5.0000e-05
# Epoch 32/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - dice_coef: 0.5302 - iou_coef: 0.3635 - loss: 1.0770
# Epoch 32: val_dice_coef improved from 0.43073 to 0.43385, saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 32: finished saving model to ../outputs/models/stage04bubble_unet_best.weights.h5
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 361ms/step - dice_coef: 0.5291 - iou_coef: 0.3625 - loss: 1.0824 - val_dice_coef: 0.4339 - val_iou_coef: 0.2807 - val_loss: 1.5050 - learning_rate: 5.0000e-05
# Epoch 33/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - dice_coef: 0.5408 - iou_coef: 0.3737 - loss: 1.0515
# Epoch 33: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 364ms/step - dice_coef: 0.5419 - iou_coef: 0.3747 - loss: 1.0513 - val_dice_coef: 0.4273 - val_iou_coef: 0.2749 - val_loss: 1.5606 - learning_rate: 2.5000e-05
# Epoch 34/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - dice_coef: 0.5527 - iou_coef: 0.3851 - loss: 1.0247
# Epoch 34: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 358ms/step - dice_coef: 0.5552 - iou_coef: 0.3873 - loss: 1.0209 - val_dice_coef: 0.4291 - val_iou_coef: 0.2761 - val_loss: 1.6077 - learning_rate: 2.5000e-05
# Epoch 35/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - dice_coef: 0.5662 - iou_coef: 0.3981 - loss: 0.9975
# Epoch 35: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 360ms/step - dice_coef: 0.5671 - iou_coef: 0.3988 - loss: 0.9960 - val_dice_coef: 0.4232 - val_iou_coef: 0.2710 - val_loss: 1.6542 - learning_rate: 2.5000e-05
# Epoch 36/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - dice_coef: 0.5773 - iou_coef: 0.4090 - loss: 0.9735
# Epoch 36: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 351ms/step - dice_coef: 0.5777 - iou_coef: 0.4092 - loss: 0.9729 - val_dice_coef: 0.4195 - val_iou_coef: 0.2679 - val_loss: 1.6918 - learning_rate: 2.5000e-05
# Epoch 37/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - dice_coef: 0.5884 - iou_coef: 0.4202 - loss: 0.9481
# Epoch 37: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 353ms/step - dice_coef: 0.5888 - iou_coef: 0.4203 - loss: 0.9474 - val_dice_coef: 0.4216 - val_iou_coef: 0.2696 - val_loss: 1.7171 - learning_rate: 2.5000e-05
# Epoch 38/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - dice_coef: 0.6000 - iou_coef: 0.4319 - loss: 0.9229
# Epoch 38: val_dice_coef did not improve from 0.43385
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 357ms/step - dice_coef: 0.5992 - iou_coef: 0.4308 - loss: 0.9240 - val_dice_coef: 0.4193 - val_iou_coef: 0.2677 - val_loss: 1.7460 - learning_rate: 2.5000e-05
# Epoch 39/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - dice_coef: 0.6047 - iou_coef: 0.4368 - loss: 0.9156
# Epoch 39: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 349ms/step - dice_coef: 0.6055 - iou_coef: 0.4373 - loss: 0.9126 - val_dice_coef: 0.4250 - val_iou_coef: 0.2725 - val_loss: 1.7156 - learning_rate: 1.2500e-05
# Epoch 40/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - dice_coef: 0.6109 - iou_coef: 0.4433 - loss: 0.8951
# Epoch 40: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 358ms/step - dice_coef: 0.6125 - iou_coef: 0.4446 - loss: 0.8935 - val_dice_coef: 0.4239 - val_iou_coef: 0.2715 - val_loss: 1.7375 - learning_rate: 1.2500e-05
# Epoch 41/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - dice_coef: 0.6178 - iou_coef: 0.4504 - loss: 0.8798
# Epoch 41: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 369ms/step - dice_coef: 0.6190 - iou_coef: 0.4513 - loss: 0.8789 - val_dice_coef: 0.4235 - val_iou_coef: 0.2712 - val_loss: 1.7555 - learning_rate: 1.2500e-05
# Epoch 42/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - dice_coef: 0.6240 - iou_coef: 0.4569 - loss: 0.8656
# Epoch 42: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 364ms/step - dice_coef: 0.6251 - iou_coef: 0.4577 - loss: 0.8653 - val_dice_coef: 0.4237 - val_iou_coef: 0.2713 - val_loss: 1.7707 - learning_rate: 1.2500e-05
# Epoch 43/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - dice_coef: 0.6298 - iou_coef: 0.4631 - loss: 0.8520
# Epoch 43: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 360ms/step - dice_coef: 0.6307 - iou_coef: 0.4637 - loss: 0.8525 - val_dice_coef: 0.4232 - val_iou_coef: 0.2708 - val_loss: 1.7902 - learning_rate: 1.2500e-05
# Epoch 44/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - dice_coef: 0.6354 - iou_coef: 0.4691 - loss: 0.8389
# Epoch 44: val_dice_coef did not improve from 0.43385
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 359ms/step - dice_coef: 0.6362 - iou_coef: 0.4695 - loss: 0.8400 - val_dice_coef: 0.4226 - val_iou_coef: 0.2703 - val_loss: 1.8109 - learning_rate: 1.2500e-05
# Epoch 45/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - dice_coef: 0.6390 - iou_coef: 0.4731 - loss: 0.8286
# Epoch 45: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 365ms/step - dice_coef: 0.6374 - iou_coef: 0.4710 - loss: 0.8372 - val_dice_coef: 0.4191 - val_iou_coef: 0.2671 - val_loss: 1.8398 - learning_rate: 6.2500e-06
# Epoch 46/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - dice_coef: 0.6428 - iou_coef: 0.4772 - loss: 0.8171
# Epoch 46: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 367ms/step - dice_coef: 0.6418 - iou_coef: 0.4756 - loss: 0.8248 - val_dice_coef: 0.4154 - val_iou_coef: 0.2640 - val_loss: 1.8728 - learning_rate: 6.2500e-06
# Epoch 47/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - dice_coef: 0.6465 - iou_coef: 0.4812 - loss: 0.8094
# Epoch 47: val_dice_coef did not improve from 0.43385
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 369ms/step - dice_coef: 0.6453 - iou_coef: 0.4793 - loss: 0.8169 - val_dice_coef: 0.4135 - val_iou_coef: 0.2623 - val_loss: 1.8938 - learning_rate: 6.2500e-06
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 32.

# %%
# MODEL_PATH = MODEL_DIR / "bubble_unet.keras"
MODEL_PATH = os.path.join(MODEL_DIR, f"{ACTIVE_STAGE}bubble_unet.keras")
HISTORY_PATH = os.path.join(OUTPUT_DIR, f"{ACTIVE_STAGE}training_history.json")

model.save(MODEL_PATH)
serializable_history = {
    name: [float(value) for value in values]
    for name, values in history.history.items()
}
with open(HISTORY_PATH, "w") as history_file:
    json.dump(serializable_history, history_file, indent=2)

print("Saved model to:", MODEL_PATH)
print("Saved training history to:", HISTORY_PATH)
# Out:
# Saved model to: ../outputs/models/stage04bubble_unet.keras
# Saved training history to: ../outputs/stage04training_history.json

# %%
# for previously trained model

if "model" not in globals():
    model = tf.keras.models.load_model(MODEL_PATH, compile=False)

# %%
preds_val = model.predict(X_val)

print("Prediction min:", preds_val.min())
print("Prediction max:", preds_val.max())
print("Prediction mean:", preds_val.mean())
print("Ground truth foreground ratio:", Y_val.mean())

def dice_at_threshold(y_true, y_pred, threshold):
    y_pred_bin = (y_pred > threshold).astype(np.float32)
    intersection = np.sum(y_true * y_pred_bin)
    return (2 * intersection + 1) / (np.sum(y_true) + np.sum(y_pred_bin) + 1)

for t in np.arange(0.25, 0.50, 0.025):
    d = dice_at_threshold(Y_val, preds_val, t)
    fg = (preds_val > t).mean()
    print(f"Threshold {t:.3f} | Dice: {d:.4f} | Pred foreground: {fg:.4f}")
    
# for t in [0.2, 0.3, 0.4, 0.5]:
#     print(f"Foreground ratio at threshold {t}:", (preds_val > t).mean())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 732ms/step
# Prediction min: 4.420445e-15
# Prediction max: 0.99547607
# Prediction mean: 0.3202335
# Ground truth foreground ratio: 0.20844378
# Threshold 0.250 | Dice: 0.5014 | Pred foreground: 0.4219
# Threshold 0.275 | Dice: 0.5025 | Pred foreground: 0.4065
# Threshold 0.300 | Dice: 0.5034 | Pred foreground: 0.3921
# Threshold 0.325 | Dice: 0.5040 | Pred foreground: 0.3787
# Threshold 0.350 | Dice: 0.5044 | Pred foreground: 0.3661
# Threshold 0.375 | Dice: 0.5047 | Pred foreground: 0.3541
# Threshold 0.400 | Dice: 0.5044 | Pred foreground: 0.3427
# Threshold 0.425 | Dice: 0.5036 | Pred foreground: 0.3316
# Threshold 0.450 | Dice: 0.5027 | Pred foreground: 0.3207
# Threshold 0.475 | Dice: 0.5016 | Pred foreground: 0.3100

# %%
thresholds = np.arange(0.05, 0.951, 0.025)
threshold_results = []

for threshold in thresholds:
    dice = dice_at_threshold(Y_val, preds_val, threshold)
    foreground_ratio = float((preds_val > threshold).mean())
    threshold_results.append(
        (float(threshold), float(dice), foreground_ratio)
    )
    print(
        f"Threshold {threshold:.3f} | Dice: {dice:.4f} | "
        f"Pred foreground: {foreground_ratio:.4f}"
    )

best_threshold, best_dice, best_foreground_ratio = max(
    threshold_results,
    key=lambda result: result[1]
)

threshold_summary = {
    "best_threshold": best_threshold,
    "validation_dice": best_dice,
    "predicted_foreground_ratio": best_foreground_ratio,
    "ground_truth_foreground_ratio": float(Y_val.mean()),
}
with (OUTPUT_DIR / "threshold_summary.json").open("w") as summary_file:
    json.dump(threshold_summary, summary_file, indent=2)

print("\nBest validation threshold:", best_threshold)
print("Best validation Dice:", best_dice)
print("Best foreground ratio:", best_foreground_ratio)
# Out:
# Threshold 0.050 | Dice: 0.4324 | Pred foreground: 0.7000
# Threshold 0.075 | Dice: 0.4508 | Pred foreground: 0.6367
# Threshold 0.100 | Dice: 0.4662 | Pred foreground: 0.5858
# Threshold 0.125 | Dice: 0.4768 | Pred foreground: 0.5433
# Threshold 0.150 | Dice: 0.4846 | Pred foreground: 0.5085
# Threshold 0.175 | Dice: 0.4907 | Pred foreground: 0.4808
# Threshold 0.200 | Dice: 0.4954 | Pred foreground: 0.4578
# Threshold 0.225 | Dice: 0.4992 | Pred foreground: 0.4387
# Threshold 0.250 | Dice: 0.5014 | Pred foreground: 0.4219
# Threshold 0.275 | Dice: 0.5025 | Pred foreground: 0.4065
# Threshold 0.300 | Dice: 0.5034 | Pred foreground: 0.3921
# Threshold 0.325 | Dice: 0.5040 | Pred foreground: 0.3787
# Threshold 0.350 | Dice: 0.5044 | Pred foreground: 0.3661
# Threshold 0.375 | Dice: 0.5047 | Pred foreground: 0.3541
# Threshold 0.400 | Dice: 0.5044 | Pred foreground: 0.3427
# Threshold 0.425 | Dice: 0.5036 | Pred foreground: 0.3316
# Threshold 0.450 | Dice: 0.5027 | Pred foreground: 0.3207
# Threshold 0.475 | Dice: 0.5016 | Pred foreground: 0.3100
# Threshold 0.500 | Dice: 0.5003 | Pred foreground: 0.2995
# Threshold 0.525 | Dice: 0.4985 | Pred foreground: 0.2892
# Threshold 0.550 | Dice: 0.4966 | Pred foreground: 0.2790
# Threshold 0.575 | Dice: 0.4940 | Pred foreground: 0.2688
# Threshold 0.600 | Dice: 0.4912 | Pred foreground: 0.2586
# Threshold 0.625 | Dice: 0.4873 | Pred foreground: 0.2481
# Threshold 0.650 | Dice: 0.4829 | Pred foreground: 0.2378
# Threshold 0.675 | Dice: 0.4778 | Pred foreground: 0.2276
# Threshold 0.700 | Dice: 0.4714 | Pred foreground: 0.2167
# Threshold 0.725 | Dice: 0.4628 | Pred foreground: 0.2054
# Threshold 0.750 | Dice: 0.4518 | Pred foreground: 0.1930
# Threshold 0.775 | Dice: 0.4380 | Pred foreground: 0.1789
# Threshold 0.800 | Dice: 0.4198 | Pred foreground: 0.1627
# Threshold 0.825 | Dice: 0.3937 | Pred foreground: 0.1440
# Threshold 0.850 | Dice: 0.3596 | Pred foreground: 0.1228
# Threshold 0.875 | Dice: 0.3176 | Pred foreground: 0.1002
# Threshold 0.900 | Dice: 0.2673 | Pred foreground: 0.0776
# Threshold 0.925 | Dice: 0.2054 | Pred foreground: 0.0542
# Threshold 0.950 | Dice: 0.1226 | Pred foreground: 0.0302
#
# Best validation threshold: 0.3750000000000001
# Best validation Dice: 0.504658579826355
# Best foreground ratio: 0.3540678478422619

# %%
for idx in [0, 10, 20]:
    image = X_val[idx].squeeze()
    ground_truth = Y_val[idx].squeeze() > 0.5
    probability = preds_val[idx].squeeze()
    prediction = probability > best_threshold

    tp = ground_truth & prediction
    fp = ~ground_truth & prediction
    fn = ground_truth & ~prediction

    tp_count = tp.sum()
    fp_count = fp.sum()
    fn_count = fn.sum()

    precision = tp_count / (tp_count + fp_count + 1e-8)
    recall = tp_count / (tp_count + fn_count + 1e-8)
    dice = (
        2 * tp_count /
        (2 * tp_count + fp_count + fn_count + 1e-8)
    )

    # 0 = correct background
    # 1 = true positive
    # 2 = false positive
    # 3 = false negative
    comparison = np.zeros(ground_truth.shape, dtype=np.uint8)
    comparison[tp] = 1
    comparison[fp] = 2
    comparison[fn] = 3

    comparison_cmap = ListedColormap([
        "black",       # correct background
        "limegreen",   # true positive
        "red",         # false positive
        "deepskyblue"  # false negative
    ])

    fig, axes = plt.subplots(1, 5, figsize=(21, 4))

    axes[0].imshow(image, cmap="gray")
    axes[0].set_title("Validation input\nF770W intensity")

    axes[1].imshow(
        ground_truth,
        cmap="gray",
        vmin=0,
        vmax=1
    )
    axes[1].set_title("Ground truth\nWhite = catalogue foreground")

    probability_plot = axes[2].imshow(
        probability,
        cmap="inferno",
        vmin=0,
        vmax=1
    )
    axes[2].set_title("Predicted probability")

    colorbar = fig.colorbar(
        probability_plot,
        ax=axes[2],
        fraction=0.046,
        pad=0.04
    )
    colorbar.set_label("Foreground probability")

    axes[3].imshow(
        prediction,
        cmap="gray",
        vmin=0,
        vmax=1
    )
    axes[3].set_title(
        f"Binary prediction\n"
        f"White = probability > {best_threshold:.2f}"
    )

    axes[4].imshow(
        comparison,
        cmap=comparison_cmap,
        vmin=0,
        vmax=3
    )
    axes[4].set_title(
        f"Prediction errors\n"
        f"Dice={dice:.3f}, P={precision:.3f}, R={recall:.3f}"
    )

    legend_items = [
        Patch(color="limegreen", label="True positive"),
        Patch(color="red", label="False positive"),
        Patch(color="deepskyblue", label="False negative"),
        Patch(color="black", label="Correct background")
    ]

    axes[4].legend(
        handles=legend_items,
        loc="lower center",
        bbox_to_anchor=(0.5, -0.35),
        ncol=2,
        frameon=False
    )

    for axis in axes:
        axis.axis("off")

    plt.tight_layout()
    plt.show()

# %%
# Loss curves
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOTS_DIR, f"{ACTIVE_STAGE}loss_curve.png"), dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['dice_coef'], label='Training Dice')
plt.plot(history.history['val_dice_coef'], label='Validation Dice')

plt.title('Dice Coefficient During Training')
plt.xlabel('Epoch')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig(os.path.join(PLOTS_DIR, f"{ACTIVE_STAGE}dice_curve.png"), dpi=300)
plt.show()
