# %%
# training rough model

import os
import json
from pathlib import Path

import numpy as np
from tensorflow.keras import layers, models
import tensorflow as tf
import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch

# %%
DATA_DIR = Path("../data/processed/augmented")
FIGURE_DIR = '../outputs/figures'
PLOTS_DIR = '../outputs/figures/plots'
MODEL_DIR = Path("../outputs/models")
OUTPUT_DIR = Path("../outputs")

ACTIVE_STAGE = "stage04"

os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(FIGURE_DIR, exist_ok=True)
os.makedirs(PLOTS_DIR, exist_ok=True)

# %%
SEED = 42
EPOCHS = 100
BATCH_SIZE = 4

# WEIGHT = 0.5
# WEIGHT = 1.0
# WEIGHT = 1.5
WEIGHT = 2.0

EARLY_STOPPING_PATIENCE = 15

tf.keras.utils.set_random_seed(SEED)

X_train = np.load(DATA_DIR / "XtrainAug.npy").astype(np.float32)
X_val = np.load(DATA_DIR / "Xval.npy").astype(np.float32)
Y_train = np.load(DATA_DIR / "YtrainAug.npy").astype(np.float32)
Y_val = np.load(DATA_DIR / "Yval.npy").astype(np.float32)

print("X_train shape:", X_train.shape, "dtype:", X_train.dtype, "min/max:", X_train.min(), X_train.max())
print("X_val shape:", X_val.shape, "dtype:", X_val.dtype, "min/max:", X_val.min(), X_val.max())
print("Y_train shape:", Y_train.shape, "dtype:", Y_train.dtype, "min/max:", Y_train.min(), Y_train.max())
print("Y_val shape:", Y_val.shape, "dtype:", Y_val.dtype, "min/max:", Y_val.min(), Y_val.max())

print("Training foreground ratio:", float(Y_train.mean()))
print("Validation foreground ratio:", float(Y_val.mean()))
# Out:
# X_train shape: (384, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# X_val shape: (21, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_train shape: (384, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_val shape: (21, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Training foreground ratio: 0.19655387103557587
# Validation foreground ratio: 0.2051871120929718

# %%
# # simple unet model
# # inputs → encoder → bottleneck → decoder → sigmoid mask

# def build_unet(input_shape=(256, 256, 1)):
#     inputs = layers.Input(input_shape)

#     # Encoder
#     c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
#     c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
#     p1 = layers.MaxPooling2D()(c1)

#     c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
#     c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
#     p2 = layers.MaxPooling2D()(c2)

#     # Bottleneck
#     b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
#     b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(b1)

#     # Decoder
#     u1 = layers.UpSampling2D()(b1)
#     u1 = layers.concatenate([u1, c2])
#     c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(u1)
#     c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(c3)

#     u2 = layers.UpSampling2D()(c3)
#     u2 = layers.concatenate([u2, c1])
#     c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(u2)
#     c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(c4)

#     outputs = layers.Conv2D(1, 1, activation='sigmoid')(c4)

#     return models.Model(inputs, outputs, name="bubble_unet")

# %%
# 4-level unet model
# inputs → encoder (4 levels) → bottleneck → decoder (4 levels) → sigmoid mask

def build_unet(input_shape=(256, 256, 1)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D()(c1)

    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D()(c2)

    c3 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(64, 3, activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D()(c3)

    c4 = layers.Conv2D(128, 3, activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(128, 3, activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D()(c4)

    # Bottleneck (16x16 spatial resolution)
    b1 = layers.Conv2D(256, 3, activation='relu', padding='same')(p4)
    b1 = layers.Conv2D(256, 3, activation='relu', padding='same')(b1)

    # Decoder
    u4 = layers.UpSampling2D()(b1)
    u4 = layers.concatenate([u4, c4])
    d4 = layers.Conv2D(128, 3, activation='relu', padding='same')(u4)
    d4 = layers.Conv2D(128, 3, activation='relu', padding='same')(d4)

    u3 = layers.UpSampling2D()(d4)
    u3 = layers.concatenate([u3, c3])
    d3 = layers.Conv2D(64, 3, activation='relu', padding='same')(u3)
    d3 = layers.Conv2D(64, 3, activation='relu', padding='same')(d3)

    u2 = layers.UpSampling2D()(d3)
    u2 = layers.concatenate([u2, c2])
    d2 = layers.Conv2D(32, 3, activation='relu', padding='same')(u2)
    d2 = layers.Conv2D(32, 3, activation='relu', padding='same')(d2)

    u1 = layers.UpSampling2D()(d2)
    u1 = layers.concatenate([u1, c1])
    d1 = layers.Conv2D(16, 3, activation='relu', padding='same')(u1)
    d1 = layers.Conv2D(16, 3, activation='relu', padding='same')(d1)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(d1)

    return models.Model(inputs, outputs, name="bubble_unet4")

# %%
def dice_loss(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) /
                (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth))

def weighted_bce(y_true, y_pred):
    y_pred = tf.clip_by_value(
        y_pred,
        tf.keras.backend.epsilon(),
        1 - tf.keras.backend.epsilon()
    )

    weights = y_true * WEIGHT + 1
    bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)

    return tf.reduce_mean(weights * bce)

def combined_loss(y_true, y_pred):
    return weighted_bce(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def iou_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss,
    metrics=[dice_coef, iou_coef]
)
model.summary()
# Out:
# Model: "bubble_unet4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, 256, 256,  │        160 │ input_layer_5[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_96 (Conv2D)  │ (None, 256, 256,  │      2,320 │ conv2d_95[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 128, 128,  │          0 │ conv2d_96[0][0]   │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_97 (Conv2D)  │ (None, 128, 128,  │      4,640 │ max_pooling2d_20… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, 128, 128,  │      9,248 │ conv2d_97[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_21    │ (None, 64, 64,    │          0 │ conv2d_98[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_99 (Conv2D)  │ (None, 64, 64,    │     18,496 │ max_pooling2d_21… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_100 (Conv2D) │ (None, 64, 64,    │     36,928 │ conv2d_99[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_22    │ (None, 32, 32,    │          0 │ conv2d_100[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_101 (Conv2D) │ (None, 32, 32,    │     73,856 │ max_pooling2d_22… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_102 (Conv2D) │ (None, 32, 32,    │    147,584 │ conv2d_101[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_23    │ (None, 16, 16,    │          0 │ conv2d_102[0][0]  │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_103 (Conv2D) │ (None, 16, 16,    │    295,168 │ max_pooling2d_23… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_104 (Conv2D) │ (None, 16, 16,    │    590,080 │ conv2d_103[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_20    │ (None, 32, 32,    │          0 │ conv2d_104[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 32, 32,    │          0 │ up_sampling2d_20… │
# │ (Concatenate)       │ 384)              │            │ conv2d_102[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_105 (Conv2D) │ (None, 32, 32,    │    442,496 │ concatenate_20[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_106 (Conv2D) │ (None, 32, 32,    │    147,584 │ conv2d_105[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_21    │ (None, 64, 64,    │          0 │ conv2d_106[0][0]  │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 64, 64,    │          0 │ up_sampling2d_21… │
# │ (Concatenate)       │ 192)              │            │ conv2d_100[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_107 (Conv2D) │ (None, 64, 64,    │    110,656 │ concatenate_21[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_108 (Conv2D) │ (None, 64, 64,    │     36,928 │ conv2d_107[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_22    │ (None, 128, 128,  │          0 │ conv2d_108[0][0]  │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, 128, 128,  │          0 │ up_sampling2d_22… │
# │ (Concatenate)       │ 96)               │            │ conv2d_98[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_109 (Conv2D) │ (None, 128, 128,  │     27,680 │ concatenate_22[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_110 (Conv2D) │ (None, 128, 128,  │      9,248 │ conv2d_109[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_23    │ (None, 256, 256,  │          0 │ conv2d_110[0][0]  │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 256, 256,  │          0 │ up_sampling2d_23… │
# │ (Concatenate)       │ 48)               │            │ conv2d_96[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_111 (Conv2D) │ (None, 256, 256,  │      6,928 │ concatenate_23[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_112 (Conv2D) │ (None, 256, 256,  │      2,320 │ conv2d_111[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_113 (Conv2D) │ (None, 256, 256,  │         17 │ conv2d_112[0][0]  │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,962,337 (7.49 MB)
#  Trainable params: 1,962,337 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# checkpoint the best epoch, stop when validation stalls, lower LR on plateau

BEST_WEIGHTS_PATH = os.path.join(MODEL_DIR, f"{ACTIVE_STAGE}bubble_unet_best.weights.h5")
HISTORY_CSV_PATH = os.path.join(OUTPUT_DIR, f"{ACTIVE_STAGE}training_history.csv")

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(BEST_WEIGHTS_PATH),
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1,
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        verbose=1,
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        mode="min",
        factor=0.5,
        patience=6,
        min_lr=1e-6,
        verbose=1,
    ),
    tf.keras.callbacks.CSVLogger(str(HISTORY_CSV_PATH)),
]

# %%
history = model.fit(
    X_train,
    Y_train,
    validation_data=(X_val, Y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    shuffle=True,
    callbacks=callbacks
)

# all later evaluation must use the best checkpointed epoch, not the last one
model.load_weights(BEST_WEIGHTS_PATH)
# Out:
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - dice_coef: 0.2709 - iou_coef: 0.1585 - loss: 1.6824
# Epoch 1: val_dice_coef improved from None to 0.30033, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 1: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 39s 378ms/step - dice_coef: 0.2789 - iou_coef: 0.1637 - loss: 1.6588 - val_dice_coef: 0.3003 - val_iou_coef: 0.1799 - val_loss: 1.6295 - learning_rate: 1.0000e-04
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - dice_coef: 0.3001 - iou_coef: 0.1780 - loss: 1.5767
# Epoch 2: val_dice_coef improved from 0.30033 to 0.30587, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 2: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 359ms/step - dice_coef: 0.3028 - iou_coef: 0.1798 - loss: 1.5761 - val_dice_coef: 0.3059 - val_iou_coef: 0.1835 - val_loss: 1.6162 - learning_rate: 1.0000e-04
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - dice_coef: 0.3057 - iou_coef: 0.1818 - loss: 1.5591
# Epoch 3: val_dice_coef did not improve from 0.30587
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 353ms/step - dice_coef: 0.3060 - iou_coef: 0.1821 - loss: 1.5651 - val_dice_coef: 0.2970 - val_iou_coef: 0.1768 - val_loss: 1.6159 - learning_rate: 1.0000e-04
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - dice_coef: 0.3091 - iou_coef: 0.1842 - loss: 1.5535
# Epoch 4: val_dice_coef improved from 0.30587 to 0.30675, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 4: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 348ms/step - dice_coef: 0.3095 - iou_coef: 0.1845 - loss: 1.5615 - val_dice_coef: 0.3068 - val_iou_coef: 0.1839 - val_loss: 1.6041 - learning_rate: 1.0000e-04
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - dice_coef: 0.3125 - iou_coef: 0.1867 - loss: 1.5461
# Epoch 5: val_dice_coef improved from 0.30675 to 0.31900, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 5: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 351ms/step - dice_coef: 0.3132 - iou_coef: 0.1873 - loss: 1.5505 - val_dice_coef: 0.3190 - val_iou_coef: 0.1925 - val_loss: 1.5660 - learning_rate: 1.0000e-04
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - dice_coef: 0.3166 - iou_coef: 0.1896 - loss: 1.5552
# Epoch 6: val_dice_coef did not improve from 0.31900
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 355ms/step - dice_coef: 0.3119 - iou_coef: 0.1863 - loss: 1.5580 - val_dice_coef: 0.2975 - val_iou_coef: 0.1769 - val_loss: 1.6078 - learning_rate: 1.0000e-04
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - dice_coef: 0.3152 - iou_coef: 0.1885 - loss: 1.5428
# Epoch 7: val_dice_coef did not improve from 0.31900
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 346ms/step - dice_coef: 0.3165 - iou_coef: 0.1895 - loss: 1.5483 - val_dice_coef: 0.3013 - val_iou_coef: 0.1794 - val_loss: 1.6022 - learning_rate: 1.0000e-04
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - dice_coef: 0.3197 - iou_coef: 0.1917 - loss: 1.5376
# Epoch 8: val_dice_coef did not improve from 0.31900
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 346ms/step - dice_coef: 0.3219 - iou_coef: 0.1934 - loss: 1.5342 - val_dice_coef: 0.3070 - val_iou_coef: 0.1834 - val_loss: 1.6001 - learning_rate: 1.0000e-04
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - dice_coef: 0.3201 - iou_coef: 0.1921 - loss: 1.5405
# Epoch 9: val_dice_coef improved from 0.31900 to 0.31956, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 9: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 36s 374ms/step - dice_coef: 0.3212 - iou_coef: 0.1929 - loss: 1.5350 - val_dice_coef: 0.3196 - val_iou_coef: 0.1924 - val_loss: 1.5982 - learning_rate: 1.0000e-04
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - dice_coef: 0.3224 - iou_coef: 0.1938 - loss: 1.5360
# Epoch 10: val_dice_coef did not improve from 0.31956
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 32s 332ms/step - dice_coef: 0.3174 - iou_coef: 0.1902 - loss: 1.5491 - val_dice_coef: 0.3180 - val_iou_coef: 0.1919 - val_loss: 1.5879 - learning_rate: 1.0000e-04
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - dice_coef: 0.3272 - iou_coef: 0.1970 - loss: 1.5041
# Epoch 11: val_dice_coef improved from 0.31956 to 0.33611, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 11: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 348ms/step - dice_coef: 0.3336 - iou_coef: 0.2018 - loss: 1.5008 - val_dice_coef: 0.3361 - val_iou_coef: 0.2047 - val_loss: 1.5392 - learning_rate: 1.0000e-04
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - dice_coef: 0.3376 - iou_coef: 0.2046 - loss: 1.4895
# Epoch 12: val_dice_coef improved from 0.33611 to 0.34034, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 12: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 32s 337ms/step - dice_coef: 0.3406 - iou_coef: 0.2067 - loss: 1.4878 - val_dice_coef: 0.3403 - val_iou_coef: 0.2076 - val_loss: 1.5573 - learning_rate: 1.0000e-04
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - dice_coef: 0.3362 - iou_coef: 0.2036 - loss: 1.5020
# Epoch 13: val_dice_coef improved from 0.34034 to 0.34299, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 13: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 32s 337ms/step - dice_coef: 0.3381 - iou_coef: 0.2050 - loss: 1.4975 - val_dice_coef: 0.3430 - val_iou_coef: 0.2096 - val_loss: 1.5292 - learning_rate: 1.0000e-04
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - dice_coef: 0.3472 - iou_coef: 0.2115 - loss: 1.4691
# Epoch 14: val_dice_coef improved from 0.34299 to 0.35162, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 14: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 36s 370ms/step - dice_coef: 0.3493 - iou_coef: 0.2131 - loss: 1.4693 - val_dice_coef: 0.3516 - val_iou_coef: 0.2161 - val_loss: 1.5139 - learning_rate: 1.0000e-04
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - dice_coef: 0.3551 - iou_coef: 0.2174 - loss: 1.4508
# Epoch 15: val_dice_coef improved from 0.35162 to 0.35217, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 15: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 370ms/step - dice_coef: 0.3555 - iou_coef: 0.2177 - loss: 1.4553 - val_dice_coef: 0.3522 - val_iou_coef: 0.2164 - val_loss: 1.5290 - learning_rate: 1.0000e-04
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - dice_coef: 0.3572 - iou_coef: 0.2191 - loss: 1.4474
# Epoch 16: val_dice_coef improved from 0.35217 to 0.35703, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 16: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 38s 398ms/step - dice_coef: 0.3583 - iou_coef: 0.2198 - loss: 1.4491 - val_dice_coef: 0.3570 - val_iou_coef: 0.2200 - val_loss: 1.5217 - learning_rate: 1.0000e-04
# Epoch 17/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - dice_coef: 0.3635 - iou_coef: 0.2238 - loss: 1.4337
# Epoch 17: val_dice_coef improved from 0.35703 to 0.35867, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 17: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 32s 331ms/step - dice_coef: 0.3635 - iou_coef: 0.2237 - loss: 1.4372 - val_dice_coef: 0.3587 - val_iou_coef: 0.2212 - val_loss: 1.5218 - learning_rate: 1.0000e-04
# Epoch 18/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - dice_coef: 0.3698 - iou_coef: 0.2286 - loss: 1.4216
# Epoch 18: val_dice_coef did not improve from 0.35867
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 344ms/step - dice_coef: 0.3706 - iou_coef: 0.2291 - loss: 1.4216 - val_dice_coef: 0.3580 - val_iou_coef: 0.2207 - val_loss: 1.4935 - learning_rate: 1.0000e-04
# Epoch 19/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - dice_coef: 0.3780 - iou_coef: 0.2348 - loss: 1.4000
# Epoch 19: val_dice_coef improved from 0.35867 to 0.36525, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 19: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 348ms/step - dice_coef: 0.3796 - iou_coef: 0.2360 - loss: 1.4010 - val_dice_coef: 0.3653 - val_iou_coef: 0.2263 - val_loss: 1.4579 - learning_rate: 1.0000e-04
# Epoch 20/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - dice_coef: 0.3888 - iou_coef: 0.2431 - loss: 1.3780
# Epoch 20: val_dice_coef improved from 0.36525 to 0.36929, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 20: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 359ms/step - dice_coef: 0.3893 - iou_coef: 0.2436 - loss: 1.3799 - val_dice_coef: 0.3693 - val_iou_coef: 0.2292 - val_loss: 1.4597 - learning_rate: 1.0000e-04
# Epoch 21/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - dice_coef: 0.4011 - iou_coef: 0.2528 - loss: 1.3530
# Epoch 21: val_dice_coef improved from 0.36929 to 0.37813, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 21: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 357ms/step - dice_coef: 0.4031 - iou_coef: 0.2544 - loss: 1.3499 - val_dice_coef: 0.3781 - val_iou_coef: 0.2358 - val_loss: 1.4833 - learning_rate: 1.0000e-04
# Epoch 22/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - dice_coef: 0.4125 - iou_coef: 0.2619 - loss: 1.3280
# Epoch 22: val_dice_coef improved from 0.37813 to 0.37819, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 22: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 353ms/step - dice_coef: 0.4134 - iou_coef: 0.2626 - loss: 1.3267 - val_dice_coef: 0.3782 - val_iou_coef: 0.2357 - val_loss: 1.4784 - learning_rate: 1.0000e-04
# Epoch 23/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - dice_coef: 0.4216 - iou_coef: 0.2692 - loss: 1.3153
# Epoch 23: val_dice_coef did not improve from 0.37819
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 345ms/step - dice_coef: 0.4180 - iou_coef: 0.2664 - loss: 1.3208 - val_dice_coef: 0.3744 - val_iou_coef: 0.2331 - val_loss: 1.4785 - learning_rate: 1.0000e-04
# Epoch 24/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - dice_coef: 0.4291 - iou_coef: 0.2753 - loss: 1.2927
# Epoch 24: val_dice_coef did not improve from 0.37819
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 31s 327ms/step - dice_coef: 0.4323 - iou_coef: 0.2779 - loss: 1.2882 - val_dice_coef: 0.3690 - val_iou_coef: 0.2287 - val_loss: 1.5208 - learning_rate: 1.0000e-04
# Epoch 25/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - dice_coef: 0.4351 - iou_coef: 0.2805 - loss: 1.2749
# Epoch 25: val_dice_coef did not improve from 0.37819
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 358ms/step - dice_coef: 0.4382 - iou_coef: 0.2830 - loss: 1.2744 - val_dice_coef: 0.3535 - val_iou_coef: 0.2169 - val_loss: 1.5856 - learning_rate: 1.0000e-04
# Epoch 26/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - dice_coef: 0.4494 - iou_coef: 0.2925 - loss: 1.2388
# Epoch 26: val_dice_coef improved from 0.37819 to 0.41538, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 26: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 346ms/step - dice_coef: 0.4600 - iou_coef: 0.3014 - loss: 1.2199 - val_dice_coef: 0.4154 - val_iou_coef: 0.2655 - val_loss: 1.4644 - learning_rate: 5.0000e-05
# Epoch 27/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - dice_coef: 0.4772 - iou_coef: 0.3160 - loss: 1.1831
# Epoch 27: val_dice_coef improved from 0.41538 to 0.41571, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 27: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 358ms/step - dice_coef: 0.4810 - iou_coef: 0.3194 - loss: 1.1783 - val_dice_coef: 0.4157 - val_iou_coef: 0.2657 - val_loss: 1.5020 - learning_rate: 5.0000e-05
# Epoch 28/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - dice_coef: 0.4901 - iou_coef: 0.3273 - loss: 1.1568
# Epoch 28: val_dice_coef improved from 0.41571 to 0.41763, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 28: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 356ms/step - dice_coef: 0.4930 - iou_coef: 0.3299 - loss: 1.1524 - val_dice_coef: 0.4176 - val_iou_coef: 0.2672 - val_loss: 1.5302 - learning_rate: 5.0000e-05
# Epoch 29/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - dice_coef: 0.5054 - iou_coef: 0.3410 - loss: 1.1241
# Epoch 29: val_dice_coef did not improve from 0.41763
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 346ms/step - dice_coef: 0.5073 - iou_coef: 0.3428 - loss: 1.1211 - val_dice_coef: 0.4164 - val_iou_coef: 0.2662 - val_loss: 1.5571 - learning_rate: 5.0000e-05
# Epoch 30/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - dice_coef: 0.5213 - iou_coef: 0.3556 - loss: 1.0890
# Epoch 30: val_dice_coef improved from 0.41763 to 0.42220, saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
#
# Epoch 30: finished saving model to ../outputs/models/stage03bubble_unet_best.weights.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 31s 326ms/step - dice_coef: 0.5231 - iou_coef: 0.3572 - loss: 1.0865 - val_dice_coef: 0.4222 - val_iou_coef: 0.2711 - val_loss: 1.5606 - learning_rate: 5.0000e-05
# Epoch 31/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - dice_coef: 0.5376 - iou_coef: 0.3708 - loss: 1.0538
# Epoch 31: val_dice_coef did not improve from 0.42220
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 37s 381ms/step - dice_coef: 0.5378 - iou_coef: 0.3709 - loss: 1.0544 - val_dice_coef: 0.4194 - val_iou_coef: 0.2691 - val_loss: 1.5518 - learning_rate: 5.0000e-05
# Epoch 32/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - dice_coef: 0.5471 - iou_coef: 0.3798 - loss: 1.0295
# Epoch 32: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 37s 382ms/step - dice_coef: 0.5480 - iou_coef: 0.3807 - loss: 1.0295 - val_dice_coef: 0.4219 - val_iou_coef: 0.2710 - val_loss: 1.5698 - learning_rate: 2.5000e-05
# Epoch 33/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - dice_coef: 0.5596 - iou_coef: 0.3918 - loss: 0.9995
# Epoch 33: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 352ms/step - dice_coef: 0.5604 - iou_coef: 0.3925 - loss: 1.0018 - val_dice_coef: 0.4178 - val_iou_coef: 0.2676 - val_loss: 1.6100 - learning_rate: 2.5000e-05
# Epoch 34/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - dice_coef: 0.5708 - iou_coef: 0.4028 - loss: 0.9742
# Epoch 34: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 35s 364ms/step - dice_coef: 0.5715 - iou_coef: 0.4032 - loss: 0.9775 - val_dice_coef: 0.4151 - val_iou_coef: 0.2655 - val_loss: 1.6460 - learning_rate: 2.5000e-05
# Epoch 35/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - dice_coef: 0.5820 - iou_coef: 0.4139 - loss: 0.9481
# Epoch 35: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 32s 331ms/step - dice_coef: 0.5832 - iou_coef: 0.4148 - loss: 0.9511 - val_dice_coef: 0.4086 - val_iou_coef: 0.2602 - val_loss: 1.6989 - learning_rate: 2.5000e-05
# Epoch 36/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - dice_coef: 0.5932 - iou_coef: 0.4252 - loss: 0.9231
# Epoch 36: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 342ms/step - dice_coef: 0.5947 - iou_coef: 0.4263 - loss: 0.9255 - val_dice_coef: 0.4015 - val_iou_coef: 0.2545 - val_loss: 1.7652 - learning_rate: 2.5000e-05
# Epoch 37/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - dice_coef: 0.6047 - iou_coef: 0.4370 - loss: 0.8989
# Epoch 37: val_dice_coef did not improve from 0.42220
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 355ms/step - dice_coef: 0.6060 - iou_coef: 0.4378 - loss: 0.9008 - val_dice_coef: 0.3961 - val_iou_coef: 0.2501 - val_loss: 1.8185 - learning_rate: 2.5000e-05
# Epoch 38/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - dice_coef: 0.6067 - iou_coef: 0.4393 - loss: 0.8973
# Epoch 38: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 37s 381ms/step - dice_coef: 0.6054 - iou_coef: 0.4374 - loss: 0.9013 - val_dice_coef: 0.4022 - val_iou_coef: 0.2550 - val_loss: 1.7840 - learning_rate: 1.2500e-05
# Epoch 39/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - dice_coef: 0.6094 - iou_coef: 0.4424 - loss: 0.8945
# Epoch 39: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 34s 352ms/step - dice_coef: 0.6078 - iou_coef: 0.4401 - loss: 0.8972 - val_dice_coef: 0.4089 - val_iou_coef: 0.2608 - val_loss: 1.7528 - learning_rate: 1.2500e-05
# Epoch 40/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - dice_coef: 0.6143 - iou_coef: 0.4474 - loss: 0.8801
# Epoch 40: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - dice_coef: 0.6130 - iou_coef: 0.4455 - loss: 0.8846 - val_dice_coef: 0.4104 - val_iou_coef: 0.2620 - val_loss: 1.7584 - learning_rate: 1.2500e-05
# Epoch 41/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - dice_coef: 0.6217 - iou_coef: 0.4551 - loss: 0.8601
# Epoch 41: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 31s 324ms/step - dice_coef: 0.6206 - iou_coef: 0.4534 - loss: 0.8663 - val_dice_coef: 0.4102 - val_iou_coef: 0.2617 - val_loss: 1.7791 - learning_rate: 1.2500e-05
# Epoch 42/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - dice_coef: 0.6293 - iou_coef: 0.4632 - loss: 0.8415
# Epoch 42: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 339ms/step - dice_coef: 0.6280 - iou_coef: 0.4613 - loss: 0.8488 - val_dice_coef: 0.4095 - val_iou_coef: 0.2612 - val_loss: 1.8064 - learning_rate: 1.2500e-05
# Epoch 43/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - dice_coef: 0.6365 - iou_coef: 0.4709 - loss: 0.8253
# Epoch 43: val_dice_coef did not improve from 0.42220
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 346ms/step - dice_coef: 0.6350 - iou_coef: 0.4687 - loss: 0.8330 - val_dice_coef: 0.4091 - val_iou_coef: 0.2608 - val_loss: 1.8320 - learning_rate: 1.2500e-05
# Epoch 44/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - dice_coef: 0.6421 - iou_coef: 0.4769 - loss: 0.8107
# Epoch 44: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 32s 328ms/step - dice_coef: 0.6406 - iou_coef: 0.4745 - loss: 0.8171 - val_dice_coef: 0.4037 - val_iou_coef: 0.2559 - val_loss: 1.9082 - learning_rate: 6.2500e-06
# Epoch 45/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - dice_coef: 0.6477 - iou_coef: 0.4831 - loss: 0.8031
# Epoch 45: val_dice_coef did not improve from 0.42220
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - dice_coef: 0.6451 - iou_coef: 0.4795 - loss: 0.8087 - val_dice_coef: 0.4040 - val_iou_coef: 0.2562 - val_loss: 1.9190 - learning_rate: 6.2500e-06
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 30.

# %%
# MODEL_PATH = MODEL_DIR / "bubble_unet.keras"
MODEL_PATH = os.path.join(MODEL_DIR, f"{ACTIVE_STAGE}bubble_unet.keras")
HISTORY_PATH = os.path.join(OUTPUT_DIR, f"{ACTIVE_STAGE}training_history.json")

model.save(MODEL_PATH)
serializable_history = {
    name: [float(value) for value in values]
    for name, values in history.history.items()
}
with open(HISTORY_PATH, "w") as history_file:
    json.dump(serializable_history, history_file, indent=2)

print("Saved model to:", MODEL_PATH)
print("Saved training history to:", HISTORY_PATH)
# Out:
# Saved model to: ../outputs/models/stage03bubble_unet.keras
# Saved training history to: ../outputs/stage03training_history.json

# %%
# for previously trained model

if "model" not in globals():
    model = tf.keras.models.load_model(MODEL_PATH, compile=False)

# %%
preds_val = model.predict(X_val)

print("Prediction min:", preds_val.min())
print("Prediction max:", preds_val.max())
print("Prediction mean:", preds_val.mean())
print("Ground truth foreground ratio:", Y_val.mean())

def dice_at_threshold(y_true, y_pred, threshold):
    y_pred_bin = (y_pred > threshold).astype(np.float32)
    intersection = np.sum(y_true * y_pred_bin)
    return (2 * intersection + 1) / (np.sum(y_true) + np.sum(y_pred_bin) + 1)

for t in np.arange(0.25, 0.50, 0.025):
    d = dice_at_threshold(Y_val, preds_val, t)
    fg = (preds_val > t).mean()
    print(f"Threshold {t:.3f} | Dice: {d:.4f} | Pred foreground: {fg:.4f}")
    
# for t in [0.2, 0.3, 0.4, 0.5]:
#     print(f"Foreground ratio at threshold {t}:", (preds_val > t).mean())
# Out:
# WARNING:tensorflow:6 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x36a1998a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 719ms/step
# Prediction min: 3.8340046e-16
# Prediction max: 0.9962054
# Prediction mean: 0.2780688
# Ground truth foreground ratio: 0.20518711
# Threshold 0.250 | Dice: 0.4991 | Pred foreground: 0.3544
# Threshold 0.275 | Dice: 0.4996 | Pred foreground: 0.3394
# Threshold 0.300 | Dice: 0.4995 | Pred foreground: 0.3257
# Threshold 0.325 | Dice: 0.4988 | Pred foreground: 0.3135
# Threshold 0.350 | Dice: 0.4973 | Pred foreground: 0.3022
# Threshold 0.375 | Dice: 0.4954 | Pred foreground: 0.2918
# Threshold 0.400 | Dice: 0.4931 | Pred foreground: 0.2824
# Threshold 0.425 | Dice: 0.4902 | Pred foreground: 0.2734
# Threshold 0.450 | Dice: 0.4872 | Pred foreground: 0.2647
# Threshold 0.475 | Dice: 0.4839 | Pred foreground: 0.2562

# %%
thresholds = np.arange(0.05, 0.951, 0.025)
threshold_results = []

for threshold in thresholds:
    dice = dice_at_threshold(Y_val, preds_val, threshold)
    foreground_ratio = float((preds_val > threshold).mean())
    threshold_results.append(
        (float(threshold), float(dice), foreground_ratio)
    )
    print(
        f"Threshold {threshold:.3f} | Dice: {dice:.4f} | "
        f"Pred foreground: {foreground_ratio:.4f}"
    )

best_threshold, best_dice, best_foreground_ratio = max(
    threshold_results,
    key=lambda result: result[1]
)

threshold_summary = {
    "best_threshold": best_threshold,
    "validation_dice": best_dice,
    "predicted_foreground_ratio": best_foreground_ratio,
    "ground_truth_foreground_ratio": float(Y_val.mean()),
}
with (OUTPUT_DIR / "threshold_summary.json").open("w") as summary_file:
    json.dump(threshold_summary, summary_file, indent=2)

print("\nBest validation threshold:", best_threshold)
print("Best validation Dice:", best_dice)
print("Best foreground ratio:", best_foreground_ratio)
# Out:
# Threshold 0.050 | Dice: 0.4326 | Pred foreground: 0.6829
# Threshold 0.075 | Dice: 0.4579 | Pred foreground: 0.5911
# Threshold 0.100 | Dice: 0.4712 | Pred foreground: 0.5276
# Threshold 0.125 | Dice: 0.4797 | Pred foreground: 0.4803
# Threshold 0.150 | Dice: 0.4863 | Pred foreground: 0.4449
# Threshold 0.175 | Dice: 0.4921 | Pred foreground: 0.4161
# Threshold 0.200 | Dice: 0.4954 | Pred foreground: 0.3923
# Threshold 0.225 | Dice: 0.4974 | Pred foreground: 0.3721
# Threshold 0.250 | Dice: 0.4991 | Pred foreground: 0.3544
# Threshold 0.275 | Dice: 0.4996 | Pred foreground: 0.3394
# Threshold 0.300 | Dice: 0.4995 | Pred foreground: 0.3257
# Threshold 0.325 | Dice: 0.4988 | Pred foreground: 0.3135
# Threshold 0.350 | Dice: 0.4973 | Pred foreground: 0.3022
# Threshold 0.375 | Dice: 0.4954 | Pred foreground: 0.2918
# Threshold 0.400 | Dice: 0.4931 | Pred foreground: 0.2824
# Threshold 0.425 | Dice: 0.4902 | Pred foreground: 0.2734
# Threshold 0.450 | Dice: 0.4872 | Pred foreground: 0.2647
# Threshold 0.475 | Dice: 0.4839 | Pred foreground: 0.2562
# Threshold 0.500 | Dice: 0.4802 | Pred foreground: 0.2477
# Threshold 0.525 | Dice: 0.4761 | Pred foreground: 0.2391
# Threshold 0.550 | Dice: 0.4714 | Pred foreground: 0.2302
# Threshold 0.575 | Dice: 0.4659 | Pred foreground: 0.2211
# Threshold 0.600 | Dice: 0.4596 | Pred foreground: 0.2117
# Threshold 0.625 | Dice: 0.4523 | Pred foreground: 0.2021
# Threshold 0.650 | Dice: 0.4451 | Pred foreground: 0.1929
# Threshold 0.675 | Dice: 0.4376 | Pred foreground: 0.1841
# Threshold 0.700 | Dice: 0.4287 | Pred foreground: 0.1751
# Threshold 0.725 | Dice: 0.4179 | Pred foreground: 0.1658
# Threshold 0.750 | Dice: 0.4053 | Pred foreground: 0.1557
# Threshold 0.775 | Dice: 0.3887 | Pred foreground: 0.1443
# Threshold 0.800 | Dice: 0.3676 | Pred foreground: 0.1314
# Threshold 0.825 | Dice: 0.3421 | Pred foreground: 0.1176
# Threshold 0.850 | Dice: 0.3091 | Pred foreground: 0.1016
# Threshold 0.875 | Dice: 0.2694 | Pred foreground: 0.0841
# Threshold 0.900 | Dice: 0.2236 | Pred foreground: 0.0662
# Threshold 0.925 | Dice: 0.1699 | Pred foreground: 0.0464
# Threshold 0.950 | Dice: 0.0995 | Pred foreground: 0.0266
#
# Best validation threshold: 0.2750000000000001
# Best validation Dice: 0.499568372964859
# Best foreground ratio: 0.33939179920014884

# %%
for idx in [0, 10, 20]:
    image = X_val[idx].squeeze()
    ground_truth = Y_val[idx].squeeze() > 0.5
    probability = preds_val[idx].squeeze()
    prediction = probability > best_threshold

    tp = ground_truth & prediction
    fp = ~ground_truth & prediction
    fn = ground_truth & ~prediction

    tp_count = tp.sum()
    fp_count = fp.sum()
    fn_count = fn.sum()

    precision = tp_count / (tp_count + fp_count + 1e-8)
    recall = tp_count / (tp_count + fn_count + 1e-8)
    dice = (
        2 * tp_count /
        (2 * tp_count + fp_count + fn_count + 1e-8)
    )

    # 0 = correct background
    # 1 = true positive
    # 2 = false positive
    # 3 = false negative
    comparison = np.zeros(ground_truth.shape, dtype=np.uint8)
    comparison[tp] = 1
    comparison[fp] = 2
    comparison[fn] = 3

    comparison_cmap = ListedColormap([
        "black",       # correct background
        "limegreen",   # true positive
        "red",         # false positive
        "deepskyblue"  # false negative
    ])

    fig, axes = plt.subplots(1, 5, figsize=(21, 4))

    axes[0].imshow(image, cmap="gray")
    axes[0].set_title("Validation input\nF770W intensity")

    axes[1].imshow(
        ground_truth,
        cmap="gray",
        vmin=0,
        vmax=1
    )
    axes[1].set_title("Ground truth\nWhite = catalogue foreground")

    probability_plot = axes[2].imshow(
        probability,
        cmap="inferno",
        vmin=0,
        vmax=1
    )
    axes[2].set_title("Predicted probability")

    colorbar = fig.colorbar(
        probability_plot,
        ax=axes[2],
        fraction=0.046,
        pad=0.04
    )
    colorbar.set_label("Foreground probability")

    axes[3].imshow(
        prediction,
        cmap="gray",
        vmin=0,
        vmax=1
    )
    axes[3].set_title(
        f"Binary prediction\n"
        f"White = probability > {best_threshold:.2f}"
    )

    axes[4].imshow(
        comparison,
        cmap=comparison_cmap,
        vmin=0,
        vmax=3
    )
    axes[4].set_title(
        f"Prediction errors\n"
        f"Dice={dice:.3f}, P={precision:.3f}, R={recall:.3f}"
    )

    legend_items = [
        Patch(color="limegreen", label="True positive"),
        Patch(color="red", label="False positive"),
        Patch(color="deepskyblue", label="False negative"),
        Patch(color="black", label="Correct background")
    ]

    axes[4].legend(
        handles=legend_items,
        loc="lower center",
        bbox_to_anchor=(0.5, -0.35),
        ncol=2,
        frameon=False
    )

    for axis in axes:
        axis.axis("off")

    plt.tight_layout()
    plt.show()

# %%
# Loss curves
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOTS_DIR, f"{ACTIVE_STAGE}loss_curve.png"), dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['dice_coef'], label='Training Dice')
plt.plot(history.history['val_dice_coef'], label='Validation Dice')

plt.title('Dice Coefficient During Training')
plt.xlabel('Epoch')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig(os.path.join(PLOTS_DIR, f"{ACTIVE_STAGE}dice_curve.png"), dpi=300)
plt.show()
