# %%
# training rough model

import numpy as np
from tensorflow.keras import layers, models
import tensorflow as tf
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
EPOCHS = 20
BATCH_SIZE = 4

X_DIR = "../data/processed/patches/X.npy"
Y_DIR = "../data/processed/patches/Y.npy"

X = np.load(X_DIR).astype(np.float32)
Y = np.load(Y_DIR).astype(np.float32)

print("X shape:", X.shape, "dtype:", X.dtype, "min/max:", X.min(), X.max())
print("Y shape:", Y.shape, "dtype:", Y.dtype, "min/max:", Y.min(), Y.max())

print("Foreground pixel ratio:", np.mean(Y))
# Out:
# X shape: (136, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y shape: (136, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Foreground pixel ratio: 0.14651524

# %%
# simple unet model
# inputs → encoder → bottleneck → decoder → sigmoid mask

def build_unet(input_shape=(256,256,1)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D()(c1)

    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D()(c2)

    # Bottleneck
    b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
    b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(b1)

    # Decoder
    u1 = layers.UpSampling2D()(b1)
    u1 = layers.concatenate([u1, c2])
    c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(u1)
    c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(c3)

    u2 = layers.UpSampling2D()(c3)
    u2 = layers.concatenate([u2, c1])
    c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(u2)
    c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(c4)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(c4)

    model = models.Model(inputs, outputs)
    return model

# %%
# intensity augmentation to image only
# same geometric augmentation to image and mask
def augment_patch(image, mask):

    if random.random() < 0.5:
        image = np.flip(image, axis=1)
        mask = np.flip(mask, axis=1)

    if random.random() < 0.5:
        image = np.flip(image, axis=0)
        mask = np.flip(mask, axis=0)

    # 90 deg rotation
    k = random.choice([0, 1, 2, 3])
    image = np.rot90(image, k)
    mask = np.rot90(mask, k)

    # Brightness shift — image only
    if random.random() < 0.5:
        shift = random.uniform(-0.08, 0.08)
        image = image + shift

    # Contrast adjustment — image only
    if random.random() < 0.5:
        factor = random.uniform(0.85, 1.15)
        image = (image - image.mean()) * factor + image.mean()

    # Clip image back to valid range
    image = np.clip(image, 0, 1)

    # Ensure mask stays binary
    mask = (mask > 0.5).astype(np.float32)

    return image.astype(np.float32), mask.astype(np.float32)

# %%
def augment_dataset(X_train, Y_train, augment_factor=3):
    X_aug = [X_train]
    Y_aug = [Y_train]

    for _ in range(augment_factor):
        augmented_images = []
        augmented_masks = []

        for img, msk in zip(X_train, Y_train):
            img_aug, msk_aug = augment_patch(img, msk)
            augmented_images.append(img_aug)
            augmented_masks.append(msk_aug)

        X_aug.append(np.array(augmented_images, dtype=np.float32))
        Y_aug.append(np.array(augmented_masks, dtype=np.float32))

    X_aug = np.concatenate(X_aug, axis=0)
    Y_aug = np.concatenate(Y_aug, axis=0)

    return X_aug, Y_aug

# %%
X_train, X_val, Y_train, Y_val = train_test_split(
    X, Y,
    test_size=0.2,
    random_state=42,
    shuffle=True
)

print("Before augmentation:")
print("X_train:", X_train.shape)
print("Y_train:", Y_train.shape)
print("X_val:", X_val.shape)
print("Y_val:", Y_val.shape)

X_train_aug, Y_train_aug = augment_dataset(
    X_train,
    Y_train,
    augment_factor=3
)

print("\nAfter augmentation:")
print("X_train_aug:", X_train_aug.shape)
print("Y_train_aug:", Y_train_aug.shape)
print("X_val:", X_val.shape)
print("Y_val:", Y_val.shape)
# Out:
# Before augmentation:
# X_train: (108, 256, 256, 1)
# Y_train: (108, 256, 256, 1)
# X_val: (28, 256, 256, 1)
# Y_val: (28, 256, 256, 1)
#
# After augmentation:
# X_train_aug: (432, 256, 256, 1)
# Y_train_aug: (432, 256, 256, 1)
# X_val: (28, 256, 256, 1)
# Y_val: (28, 256, 256, 1)

# %%
def dice_loss(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) /
                (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth))

def weighted_bce(y_true, y_pred):
    y_pred = tf.clip_by_value(
        y_pred,
        tf.keras.backend.epsilon(),
        1 - tf.keras.backend.epsilon()
    )

    weights = y_true * 1.5 + 1
    bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)

    return tf.reduce_mean(weights * bce)

def combined_loss(y_true, y_pred):
    return weighted_bce(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
def weighted_bce(y_true, y_pred):
    y_pred = tf.clip_by_value(
        y_pred,
        tf.keras.backend.epsilon(),
        1 - tf.keras.backend.epsilon()
    )

    weights = y_true * 1.5 + 1
    bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)

    return tf.reduce_mean(weights * bce)

def combined_loss(y_true, y_pred):
    return weighted_bce(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def iou_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
model = build_unet()

model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss=combined_loss,
              metrics=[dice_coef, iou_coef])

# %%
history = model.fit(
    X_train_aug,
    Y_train_aug,
    validation_data=(X_val, Y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE
)
# Out:
# Epoch 1/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 28s 243ms/step - dice_coef: 0.2040 - iou_coef: 0.1151 - loss: 1.5806 - val_dice_coef: 0.1902 - val_iou_coef: 0.1059 - val_loss: 1.5874
# Epoch 2/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - dice_coef: 0.1973 - iou_coef: 0.1105 - loss: 1.5566 - val_dice_coef: 0.2063 - val_iou_coef: 0.1161 - val_loss: 1.5693
# Epoch 3/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - dice_coef: 0.1977 - iou_coef: 0.1107 - loss: 1.5507 - val_dice_coef: 0.1986 - val_iou_coef: 0.1112 - val_loss: 1.5713
# Epoch 4/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - dice_coef: 0.1950 - iou_coef: 0.1091 - loss: 1.5506 - val_dice_coef: 0.2050 - val_iou_coef: 0.1154 - val_loss: 1.5649
# Epoch 5/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 239ms/step - dice_coef: 0.1951 - iou_coef: 0.1095 - loss: 1.5536 - val_dice_coef: 0.1965 - val_iou_coef: 0.1099 - val_loss: 1.5696
# Epoch 6/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - dice_coef: 0.1944 - iou_coef: 0.1089 - loss: 1.5513 - val_dice_coef: 0.2028 - val_iou_coef: 0.1139 - val_loss: 1.5641
# Epoch 7/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - dice_coef: 0.1958 - iou_coef: 0.1098 - loss: 1.5503 - val_dice_coef: 0.1980 - val_iou_coef: 0.1109 - val_loss: 1.5665
# Epoch 8/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 239ms/step - dice_coef: 0.1943 - iou_coef: 0.1090 - loss: 1.5531 - val_dice_coef: 0.2035 - val_iou_coef: 0.1144 - val_loss: 1.5628
# Epoch 9/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - dice_coef: 0.1951 - iou_coef: 0.1093 - loss: 1.5508 - val_dice_coef: 0.2033 - val_iou_coef: 0.1142 - val_loss: 1.5625
# Epoch 10/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 241ms/step - dice_coef: 0.1950 - iou_coef: 0.1094 - loss: 1.5518 - val_dice_coef: 0.1957 - val_iou_coef: 0.1094 - val_loss: 1.5707
# Epoch 11/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - dice_coef: 0.1939 - iou_coef: 0.1085 - loss: 1.5512 - val_dice_coef: 0.2043 - val_iou_coef: 0.1149 - val_loss: 1.5623
# Epoch 12/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 237ms/step - dice_coef: 0.1965 - iou_coef: 0.1101 - loss: 1.5509 - val_dice_coef: 0.2030 - val_iou_coef: 0.1140 - val_loss: 1.5628
# Epoch 13/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - dice_coef: 0.1944 - iou_coef: 0.1089 - loss: 1.5506 - val_dice_coef: 0.2046 - val_iou_coef: 0.1151 - val_loss: 1.5614
# Epoch 14/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 239ms/step - dice_coef: 0.1944 - iou_coef: 0.1087 - loss: 1.5498 - val_dice_coef: 0.2075 - val_iou_coef: 0.1169 - val_loss: 1.5614
# Epoch 15/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 241ms/step - dice_coef: 0.1949 - iou_coef: 0.1095 - loss: 1.5534 - val_dice_coef: 0.2045 - val_iou_coef: 0.1150 - val_loss: 1.5608
# Epoch 16/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - dice_coef: 0.1942 - iou_coef: 0.1090 - loss: 1.5519 - val_dice_coef: 0.1924 - val_iou_coef: 0.1073 - val_loss: 1.5749
# Epoch 17/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 231ms/step - dice_coef: 0.1939 - iou_coef: 0.1088 - loss: 1.5522 - val_dice_coef: 0.2090 - val_iou_coef: 0.1179 - val_loss: 1.5625
# Epoch 18/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - dice_coef: 0.1961 - iou_coef: 0.1099 - loss: 1.5502 - val_dice_coef: 0.2065 - val_iou_coef: 0.1163 - val_loss: 1.5624
# Epoch 19/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 237ms/step - dice_coef: 0.1940 - iou_coef: 0.1088 - loss: 1.5528 - val_dice_coef: 0.2061 - val_iou_coef: 0.1161 - val_loss: 1.5621
# Epoch 20/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - dice_coef: 0.1955 - iou_coef: 0.1096 - loss: 1.5492 - val_dice_coef: 0.2012 - val_iou_coef: 0.1129 - val_loss: 1.5635

# %%
preds_val = model.predict(X_val)

print("Prediction min:", preds_val.min())
print("Prediction max:", preds_val.max())
print("Prediction mean:", preds_val.mean())
print("Ground truth foreground ratio:", Y_val.mean())

def dice_at_threshold(y_true, y_pred, threshold):
    y_pred_bin = (y_pred > threshold).astype(np.float32)
    intersection = np.sum(y_true * y_pred_bin)
    return (2 * intersection + 1) / (np.sum(y_true) + np.sum(y_pred_bin) + 1)

for t in np.arange(0.25, 0.50, 0.025):
    d = dice_at_threshold(Y_val, preds_val, t)
    fg = (preds_val > t).mean()
    print(f"Threshold {t:.3f} | Dice: {d:.4f} | Pred foreground: {fg:.4f}")
    
# for t in [0.2, 0.3, 0.4, 0.5]:
#     print(f"Foreground ratio at threshold {t}:", (preds_val > t).mean())
# Out:
# WARNING:tensorflow:6 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x152f33560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# Prediction min: 0.10881904
# Prediction max: 0.4609872
# Prediction mean: 0.32520738
# Ground truth foreground ratio: 0.15308926
# Threshold 0.250 | Dice: 0.2671 | Pred foreground: 0.9881
# Threshold 0.275 | Dice: 0.2659 | Pred foreground: 0.9673
# Threshold 0.300 | Dice: 0.2611 | Pred foreground: 0.9073
# Threshold 0.325 | Dice: 0.2351 | Pred foreground: 0.6519
# Threshold 0.350 | Dice: 0.0206 | Pred foreground: 0.0131
# Threshold 0.375 | Dice: 0.0077 | Pred foreground: 0.0042
# Threshold 0.400 | Dice: 0.0008 | Pred foreground: 0.0006
# Threshold 0.425 | Dice: 0.0001 | Pred foreground: 0.0001
# Threshold 0.450 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.475 | Dice: 0.0000 | Pred foreground: 0.0000

# %%
idx = 0
pred = preds_val[idx].squeeze()
pred_thresh = (pred > 0.3).astype(np.float32)

plt.figure(figsize=(16, 4))

plt.subplot(1, 4, 1)
plt.imshow(X_val[idx].squeeze(), cmap="gray")
plt.title("Validation Input")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(Y_val[idx].squeeze(), cmap="gray")
plt.title("Ground Truth")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.imshow(pred, cmap="inferno")
plt.title("Prediction Probability")
plt.axis("off")

plt.subplot(1, 4, 4)
plt.imshow(pred_thresh, cmap="gray")
plt.title("Thresholded Prediction: 0.3")
plt.axis("off")

plt.show()

# %%
# Loss curves
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('../outputs/figures/loss_curve.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['dice_coef'], label='Training Dice')
plt.plot(history.history['val_dice_coef'], label='Validation Dice')

plt.title('Dice Coefficient During Training')
plt.xlabel('Epoch')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('../outputs/figures/dice_curve.png', dpi=300)
plt.show()
