# %%
# training rough model

import os
import json
from pathlib import Path

import numpy as np
from tensorflow.keras import layers, models
import tensorflow as tf
import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch

# %%
SEED = 42
EPOCHS = 100
BATCH_SIZE = 4

# POSITIVE_CLASS_WEIGHT = 0.5
# POSITIVE_CLASS_WEIGHT = 1.0
# POSITIVE_CLASS_WEIGHT = 1.5
POSITIVE_CLASS_WEIGHT = 2.0

EARLY_STOPPING_PATIENCE = 15

tf.keras.utils.set_random_seed(SEED)

DATA_DIR = Path("../data/processed/augmented")
FIGURE_DIR = '../outputs/figures'
MODEL_DIR = Path("../outputs/models")
OUTPUT_DIR = Path("../outputs")

os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(FIGURE_DIR, exist_ok=True)

X_train = np.load(DATA_DIR / "XtrainAug.npy").astype(np.float32)
X_val = np.load(DATA_DIR / "XVal.npy").astype(np.float32)
Y_train = np.load(DATA_DIR / "YtrainAug.npy").astype(np.float32)
Y_val = np.load(DATA_DIR / "YVal.npy").astype(np.float32)

print("X_train shape:", X_train.shape, "dtype:", X_train.dtype, "min/max:", X_train.min(), X_train.max())
print("X_val shape:", X_val.shape, "dtype:", X_val.dtype, "min/max:", X_val.min(), X_val.max())
print("Y_train shape:", Y_train.shape, "dtype:", Y_train.dtype, "min/max:", Y_train.min(), Y_train.max())
print("Y_val shape:", Y_val.shape, "dtype:", Y_val.dtype, "min/max:", Y_val.min(), Y_val.max())

print("Training foreground ratio:", float(Y_train.mean()))
print("Validation foreground ratio:", float(Y_val.mean()))
# Out:
# X_train shape: (432, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# X_val shape: (28, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_train shape: (432, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_val shape: (28, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Training foreground ratio: 0.11102577298879623
# Validation foreground ratio: 0.08361434936523438

# %%
# # simple unet model
# # inputs → encoder → bottleneck → decoder → sigmoid mask

# def build_unet(input_shape=(256, 256, 1)):
#     inputs = layers.Input(input_shape)

#     # Encoder
#     c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
#     c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
#     p1 = layers.MaxPooling2D()(c1)

#     c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
#     c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
#     p2 = layers.MaxPooling2D()(c2)

#     # Bottleneck
#     b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
#     b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(b1)

#     # Decoder
#     u1 = layers.UpSampling2D()(b1)
#     u1 = layers.concatenate([u1, c2])
#     c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(u1)
#     c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(c3)

#     u2 = layers.UpSampling2D()(c3)
#     u2 = layers.concatenate([u2, c1])
#     c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(u2)
#     c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(c4)

#     outputs = layers.Conv2D(1, 1, activation='sigmoid')(c4)

#     return models.Model(inputs, outputs, name="bubble_unet")

# %%
# 4-level unet model
# inputs → encoder (4 levels) → bottleneck → decoder (4 levels) → sigmoid mask

def build_unet(input_shape=(256, 256, 1)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D()(c1)

    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D()(c2)

    c3 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(64, 3, activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D()(c3)

    c4 = layers.Conv2D(128, 3, activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(128, 3, activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D()(c4)

    # Bottleneck (16x16 spatial resolution)
    b1 = layers.Conv2D(256, 3, activation='relu', padding='same')(p4)
    b1 = layers.Conv2D(256, 3, activation='relu', padding='same')(b1)

    # Decoder
    u4 = layers.UpSampling2D()(b1)
    u4 = layers.concatenate([u4, c4])
    d4 = layers.Conv2D(128, 3, activation='relu', padding='same')(u4)
    d4 = layers.Conv2D(128, 3, activation='relu', padding='same')(d4)

    u3 = layers.UpSampling2D()(d4)
    u3 = layers.concatenate([u3, c3])
    d3 = layers.Conv2D(64, 3, activation='relu', padding='same')(u3)
    d3 = layers.Conv2D(64, 3, activation='relu', padding='same')(d3)

    u2 = layers.UpSampling2D()(d3)
    u2 = layers.concatenate([u2, c2])
    d2 = layers.Conv2D(32, 3, activation='relu', padding='same')(u2)
    d2 = layers.Conv2D(32, 3, activation='relu', padding='same')(d2)

    u1 = layers.UpSampling2D()(d2)
    u1 = layers.concatenate([u1, c1])
    d1 = layers.Conv2D(16, 3, activation='relu', padding='same')(u1)
    d1 = layers.Conv2D(16, 3, activation='relu', padding='same')(d1)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(d1)

    return models.Model(inputs, outputs, name="bubble_unet4")

# %%
def dice_loss(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) /
                (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth))

def weighted_bce(y_true, y_pred):
    y_pred = tf.clip_by_value(
        y_pred,
        tf.keras.backend.epsilon(),
        1 - tf.keras.backend.epsilon()
    )

    weights = y_true * POSITIVE_CLASS_WEIGHT + 1
    bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)

    return tf.reduce_mean(weights * bce)

def combined_loss(y_true, y_pred):
    return weighted_bce(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def iou_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss,
    metrics=[dice_coef, iou_coef]
)
model.summary()
# Out:
# Model: "bubble_unet4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 256, 256,  │        160 │ input_layer_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 256, 256,  │      2,320 │ conv2d_30[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 128, 128,  │          0 │ conv2d_31[0][0]   │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │      4,640 │ max_pooling2d_6[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │      9,248 │ conv2d_32[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 64, 64,    │          0 │ conv2d_33[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 64, 64,    │     18,496 │ max_pooling2d_7[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 64, 64,    │     36,928 │ conv2d_34[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 32, 32,    │          0 │ conv2d_35[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 32, 32,    │     73,856 │ max_pooling2d_8[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 32, 32,    │    147,584 │ conv2d_36[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 16, 16,    │          0 │ conv2d_37[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 16, 16,    │    295,168 │ max_pooling2d_9[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 16, 16,    │    590,080 │ conv2d_38[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 32, 32,    │          0 │ conv2d_39[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 32, 32,    │          0 │ up_sampling2d_6[… │
# │ (Concatenate)       │ 384)              │            │ conv2d_37[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 32, 32,    │    442,496 │ concatenate_6[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 32, 32,    │    147,584 │ conv2d_40[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 64, 64,    │          0 │ conv2d_41[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 64, 64,    │          0 │ up_sampling2d_7[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_35[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 64, 64,    │    110,656 │ concatenate_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 64, 64,    │     36,928 │ conv2d_42[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_8     │ (None, 128, 128,  │          0 │ conv2d_43[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 128, 128,  │          0 │ up_sampling2d_8[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_33[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 128, 128,  │     27,680 │ concatenate_8[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 128, 128,  │      9,248 │ conv2d_44[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_9     │ (None, 256, 256,  │          0 │ conv2d_45[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 256, 256,  │          0 │ up_sampling2d_9[… │
# │ (Concatenate)       │ 48)               │            │ conv2d_31[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 256, 256,  │      6,928 │ concatenate_9[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 256, 256,  │      2,320 │ conv2d_46[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 256, 256,  │         17 │ conv2d_47[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,962,337 (7.49 MB)
#  Trainable params: 1,962,337 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# checkpoint the best epoch, stop when validation stalls, lower LR on plateau

BEST_WEIGHTS_PATH = MODEL_DIR / "bubble_unet_best.weights.h5"
HISTORY_CSV_PATH = OUTPUT_DIR / "training_history.csv"

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(BEST_WEIGHTS_PATH),
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1,
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        verbose=1,
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        mode="min",
        factor=0.5,
        patience=6,
        min_lr=1e-6,
        verbose=1,
    ),
    tf.keras.callbacks.CSVLogger(str(HISTORY_CSV_PATH)),
]

# %%
history = model.fit(
    X_train,
    Y_train,
    validation_data=(X_val, Y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    shuffle=True,
    callbacks=callbacks
)

# all later evaluation must use the best checkpointed epoch, not the last one
model.load_weights(BEST_WEIGHTS_PATH)
# Out:
# Epoch 1/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - dice_coef: 0.1698 - iou_coef: 0.0945 - loss: 1.6094
# Epoch 1: val_dice_coef improved from None to 0.13318, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 1: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 324ms/step - dice_coef: 0.1578 - iou_coef: 0.0872 - loss: 1.5920 - val_dice_coef: 0.1332 - val_iou_coef: 0.0722 - val_loss: 1.4699 - learning_rate: 1.0000e-04
# Epoch 2/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - dice_coef: 0.1743 - iou_coef: 0.0968 - loss: 1.5369
# Epoch 2: val_dice_coef improved from 0.13318 to 0.18924, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 2: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 315ms/step - dice_coef: 0.1736 - iou_coef: 0.0966 - loss: 1.5077 - val_dice_coef: 0.1892 - val_iou_coef: 0.1058 - val_loss: 1.3143 - learning_rate: 1.0000e-04
# Epoch 3/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - dice_coef: 0.1881 - iou_coef: 0.1053 - loss: 1.4993
# Epoch 3: val_dice_coef improved from 0.18924 to 0.18934, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 3: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 316ms/step - dice_coef: 0.1809 - iou_coef: 0.1011 - loss: 1.4830 - val_dice_coef: 0.1893 - val_iou_coef: 0.1059 - val_loss: 1.3068 - learning_rate: 1.0000e-04
# Epoch 4/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - dice_coef: 0.1880 - iou_coef: 0.1052 - loss: 1.4964
# Epoch 4: val_dice_coef improved from 0.18934 to 0.19041, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 4: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 318ms/step - dice_coef: 0.1812 - iou_coef: 0.1012 - loss: 1.4801 - val_dice_coef: 0.1904 - val_iou_coef: 0.1065 - val_loss: 1.3036 - learning_rate: 1.0000e-04
# Epoch 5/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - dice_coef: 0.1883 - iou_coef: 0.1054 - loss: 1.4950
# Epoch 5: val_dice_coef improved from 0.19041 to 0.19072, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 5: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 317ms/step - dice_coef: 0.1816 - iou_coef: 0.1015 - loss: 1.4791 - val_dice_coef: 0.1907 - val_iou_coef: 0.1068 - val_loss: 1.3031 - learning_rate: 1.0000e-04
# Epoch 6/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - dice_coef: 0.1885 - iou_coef: 0.1056 - loss: 1.4944
# Epoch 6: val_dice_coef improved from 0.19072 to 0.19097, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 6: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 321ms/step - dice_coef: 0.1818 - iou_coef: 0.1016 - loss: 1.4779 - val_dice_coef: 0.1910 - val_iou_coef: 0.1069 - val_loss: 1.3017 - learning_rate: 1.0000e-04
# Epoch 7/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - dice_coef: 0.1887 - iou_coef: 0.1056 - loss: 1.4936
# Epoch 7: val_dice_coef improved from 0.19097 to 0.19158, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 7: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 339ms/step - dice_coef: 0.1820 - iou_coef: 0.1017 - loss: 1.4771 - val_dice_coef: 0.1916 - val_iou_coef: 0.1073 - val_loss: 1.3009 - learning_rate: 1.0000e-04
# Epoch 8/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - dice_coef: 0.1889 - iou_coef: 0.1058 - loss: 1.4928
# Epoch 8: val_dice_coef did not improve from 0.19158
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 350ms/step - dice_coef: 0.1822 - iou_coef: 0.1019 - loss: 1.4764 - val_dice_coef: 0.1914 - val_iou_coef: 0.1072 - val_loss: 1.3010 - learning_rate: 1.0000e-04
# Epoch 9/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - dice_coef: 0.1890 - iou_coef: 0.1058 - loss: 1.4925
# Epoch 9: val_dice_coef improved from 0.19158 to 0.19173, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 9: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 349ms/step - dice_coef: 0.1823 - iou_coef: 0.1019 - loss: 1.4761 - val_dice_coef: 0.1917 - val_iou_coef: 0.1073 - val_loss: 1.3005 - learning_rate: 1.0000e-04
# Epoch 10/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - dice_coef: 0.1889 - iou_coef: 0.1058 - loss: 1.4925
# Epoch 10: val_dice_coef improved from 0.19173 to 0.19260, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 10: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 340ms/step - dice_coef: 0.1822 - iou_coef: 0.1019 - loss: 1.4761 - val_dice_coef: 0.1926 - val_iou_coef: 0.1079 - val_loss: 1.2999 - learning_rate: 1.0000e-04
# Epoch 11/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - dice_coef: 0.1892 - iou_coef: 0.1060 - loss: 1.4920
# Epoch 11: val_dice_coef did not improve from 0.19260
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 331ms/step - dice_coef: 0.1822 - iou_coef: 0.1019 - loss: 1.4763 - val_dice_coef: 0.1926 - val_iou_coef: 0.1079 - val_loss: 1.3029 - learning_rate: 1.0000e-04
# Epoch 12/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - dice_coef: 0.1895 - iou_coef: 0.1062 - loss: 1.4911
# Epoch 12: val_dice_coef did not improve from 0.19260
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 323ms/step - dice_coef: 0.1828 - iou_coef: 0.1022 - loss: 1.4750 - val_dice_coef: 0.1922 - val_iou_coef: 0.1076 - val_loss: 1.3009 - learning_rate: 1.0000e-04
# Epoch 13/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - dice_coef: 0.1895 - iou_coef: 0.1061 - loss: 1.4905
# Epoch 13: val_dice_coef improved from 0.19260 to 0.19318, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 13: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 318ms/step - dice_coef: 0.1829 - iou_coef: 0.1023 - loss: 1.4740 - val_dice_coef: 0.1932 - val_iou_coef: 0.1083 - val_loss: 1.3001 - learning_rate: 1.0000e-04
# Epoch 14/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - dice_coef: 0.1899 - iou_coef: 0.1064 - loss: 1.4897
# Epoch 14: val_dice_coef improved from 0.19318 to 0.19345, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 14: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 315ms/step - dice_coef: 0.1832 - iou_coef: 0.1025 - loss: 1.4733 - val_dice_coef: 0.1934 - val_iou_coef: 0.1084 - val_loss: 1.2993 - learning_rate: 1.0000e-04
# Epoch 15/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - dice_coef: 0.1900 - iou_coef: 0.1065 - loss: 1.4890
# Epoch 15: val_dice_coef improved from 0.19345 to 0.19369, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 15: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 317ms/step - dice_coef: 0.1834 - iou_coef: 0.1026 - loss: 1.4729 - val_dice_coef: 0.1937 - val_iou_coef: 0.1086 - val_loss: 1.2999 - learning_rate: 1.0000e-04
# Epoch 16/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - dice_coef: 0.1903 - iou_coef: 0.1067 - loss: 1.4882
# Epoch 16: val_dice_coef did not improve from 0.19369
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 316ms/step - dice_coef: 0.1837 - iou_coef: 0.1028 - loss: 1.4720 - val_dice_coef: 0.1937 - val_iou_coef: 0.1086 - val_loss: 1.2990 - learning_rate: 1.0000e-04
# Epoch 17/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - dice_coef: 0.1906 - iou_coef: 0.1068 - loss: 1.4876
# Epoch 17: val_dice_coef improved from 0.19369 to 0.19402, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 17: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 320ms/step - dice_coef: 0.1842 - iou_coef: 0.1031 - loss: 1.4713 - val_dice_coef: 0.1940 - val_iou_coef: 0.1088 - val_loss: 1.3023 - learning_rate: 1.0000e-04
# Epoch 18/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - dice_coef: 0.1907 - iou_coef: 0.1069 - loss: 1.4868
# Epoch 18: val_dice_coef improved from 0.19402 to 0.19442, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 18: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 322ms/step - dice_coef: 0.1844 - iou_coef: 0.1032 - loss: 1.4711 - val_dice_coef: 0.1944 - val_iou_coef: 0.1090 - val_loss: 1.3007 - learning_rate: 1.0000e-04
# Epoch 19/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - dice_coef: 0.1913 - iou_coef: 0.1072 - loss: 1.4853
# Epoch 19: val_dice_coef did not improve from 0.19442
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 318ms/step - dice_coef: 0.1851 - iou_coef: 0.1037 - loss: 1.4691 - val_dice_coef: 0.1939 - val_iou_coef: 0.1086 - val_loss: 1.3008 - learning_rate: 1.0000e-04
# Epoch 20/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - dice_coef: 0.1918 - iou_coef: 0.1076 - loss: 1.4839
# Epoch 20: val_dice_coef did not improve from 0.19442
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 318ms/step - dice_coef: 0.1853 - iou_coef: 0.1038 - loss: 1.4700 - val_dice_coef: 0.1935 - val_iou_coef: 0.1084 - val_loss: 1.3020 - learning_rate: 1.0000e-04
# Epoch 21/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - dice_coef: 0.1915 - iou_coef: 0.1074 - loss: 1.4852
# Epoch 21: val_dice_coef improved from 0.19442 to 0.19485, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 21: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 320ms/step - dice_coef: 0.1853 - iou_coef: 0.1038 - loss: 1.4683 - val_dice_coef: 0.1949 - val_iou_coef: 0.1093 - val_loss: 1.2994 - learning_rate: 1.0000e-04
# Epoch 22/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - dice_coef: 0.1933 - iou_coef: 0.1085 - loss: 1.4802
# Epoch 22: val_dice_coef did not improve from 0.19485
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 315ms/step - dice_coef: 0.1874 - iou_coef: 0.1052 - loss: 1.4646 - val_dice_coef: 0.1924 - val_iou_coef: 0.1077 - val_loss: 1.3021 - learning_rate: 1.0000e-04
# Epoch 23/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - dice_coef: 0.1940 - iou_coef: 0.1090 - loss: 1.4788
# Epoch 23: val_dice_coef improved from 0.19485 to 0.19939, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 23: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 318ms/step - dice_coef: 0.1897 - iou_coef: 0.1066 - loss: 1.4583 - val_dice_coef: 0.1994 - val_iou_coef: 0.1121 - val_loss: 1.2891 - learning_rate: 5.0000e-05
# Epoch 24/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - dice_coef: 0.1998 - iou_coef: 0.1126 - loss: 1.4631
# Epoch 24: val_dice_coef improved from 0.19939 to 0.21350, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 24: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 318ms/step - dice_coef: 0.1963 - iou_coef: 0.1107 - loss: 1.4399 - val_dice_coef: 0.2135 - val_iou_coef: 0.1214 - val_loss: 1.2664 - learning_rate: 5.0000e-05
# Epoch 25/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - dice_coef: 0.2125 - iou_coef: 0.1206 - loss: 1.4363
# Epoch 25: val_dice_coef improved from 0.21350 to 0.22926, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 25: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 320ms/step - dice_coef: 0.2093 - iou_coef: 0.1190 - loss: 1.4120 - val_dice_coef: 0.2293 - val_iou_coef: 0.1319 - val_loss: 1.2377 - learning_rate: 5.0000e-05
# Epoch 26/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - dice_coef: 0.2239 - iou_coef: 0.1280 - loss: 1.4146
# Epoch 26: val_dice_coef improved from 0.22926 to 0.23240, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 26: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 324ms/step - dice_coef: 0.2207 - iou_coef: 0.1263 - loss: 1.3913 - val_dice_coef: 0.2324 - val_iou_coef: 0.1340 - val_loss: 1.2274 - learning_rate: 5.0000e-05
# Epoch 27/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - dice_coef: 0.2316 - iou_coef: 0.1329 - loss: 1.3960
# Epoch 27: val_dice_coef improved from 0.23240 to 0.25012, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 27: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 333ms/step - dice_coef: 0.2321 - iou_coef: 0.1337 - loss: 1.3695 - val_dice_coef: 0.2501 - val_iou_coef: 0.1463 - val_loss: 1.2027 - learning_rate: 5.0000e-05
# Epoch 28/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - dice_coef: 0.2488 - iou_coef: 0.1444 - loss: 1.3754
# Epoch 28: val_dice_coef improved from 0.25012 to 0.26589, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 28: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 329ms/step - dice_coef: 0.2514 - iou_coef: 0.1469 - loss: 1.3468 - val_dice_coef: 0.2659 - val_iou_coef: 0.1578 - val_loss: 1.1743 - learning_rate: 5.0000e-05
# Epoch 29/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - dice_coef: 0.2672 - iou_coef: 0.1570 - loss: 1.3477
# Epoch 29: val_dice_coef improved from 0.26589 to 0.27736, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 29: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 352ms/step - dice_coef: 0.2665 - iou_coef: 0.1571 - loss: 1.3226 - val_dice_coef: 0.2774 - val_iou_coef: 0.1661 - val_loss: 1.1594 - learning_rate: 5.0000e-05
# Epoch 30/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - dice_coef: 0.2773 - iou_coef: 0.1640 - loss: 1.3316
# Epoch 30: val_dice_coef improved from 0.27736 to 0.29293, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 30: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 325ms/step - dice_coef: 0.2757 - iou_coef: 0.1635 - loss: 1.3068 - val_dice_coef: 0.2929 - val_iou_coef: 0.1771 - val_loss: 1.1322 - learning_rate: 5.0000e-05
# Epoch 31/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - dice_coef: 0.2867 - iou_coef: 0.1705 - loss: 1.3162
# Epoch 31: val_dice_coef improved from 0.29293 to 0.30250, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 31: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 315ms/step - dice_coef: 0.2856 - iou_coef: 0.1705 - loss: 1.2889 - val_dice_coef: 0.3025 - val_iou_coef: 0.1842 - val_loss: 1.1206 - learning_rate: 5.0000e-05
# Epoch 32/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - dice_coef: 0.2951 - iou_coef: 0.1764 - loss: 1.3030
# Epoch 32: val_dice_coef improved from 0.30250 to 0.30907, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 32: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 314ms/step - dice_coef: 0.2938 - iou_coef: 0.1763 - loss: 1.2762 - val_dice_coef: 0.3091 - val_iou_coef: 0.1889 - val_loss: 1.1119 - learning_rate: 5.0000e-05
# Epoch 33/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - dice_coef: 0.3036 - iou_coef: 0.1825 - loss: 1.2858
# Epoch 33: val_dice_coef improved from 0.30907 to 0.32443, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 33: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 34s 315ms/step - dice_coef: 0.3044 - iou_coef: 0.1839 - loss: 1.2546 - val_dice_coef: 0.3244 - val_iou_coef: 0.2007 - val_loss: 1.0871 - learning_rate: 5.0000e-05
# Epoch 34/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - dice_coef: 0.3166 - iou_coef: 0.1919 - loss: 1.2642
# Epoch 34: val_dice_coef improved from 0.32443 to 0.33722, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 34: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 325ms/step - dice_coef: 0.3168 - iou_coef: 0.1930 - loss: 1.2332 - val_dice_coef: 0.3372 - val_iou_coef: 0.2102 - val_loss: 1.0661 - learning_rate: 5.0000e-05
# Epoch 35/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - dice_coef: 0.3300 - iou_coef: 0.2017 - loss: 1.2387
# Epoch 35: val_dice_coef improved from 0.33722 to 0.34649, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 35: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 326ms/step - dice_coef: 0.3322 - iou_coef: 0.2046 - loss: 1.2055 - val_dice_coef: 0.3465 - val_iou_coef: 0.2171 - val_loss: 1.0536 - learning_rate: 5.0000e-05
# Epoch 36/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - dice_coef: 0.3421 - iou_coef: 0.2107 - loss: 1.2147
# Epoch 36: val_dice_coef improved from 0.34649 to 0.35336, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 36: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 339ms/step - dice_coef: 0.3434 - iou_coef: 0.2130 - loss: 1.1860 - val_dice_coef: 0.3534 - val_iou_coef: 0.2223 - val_loss: 1.0520 - learning_rate: 5.0000e-05
# Epoch 37/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - dice_coef: 0.3544 - iou_coef: 0.2200 - loss: 1.1917
# Epoch 37: val_dice_coef improved from 0.35336 to 0.36541, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 37: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 335ms/step - dice_coef: 0.3568 - iou_coef: 0.2232 - loss: 1.1615 - val_dice_coef: 0.3654 - val_iou_coef: 0.2318 - val_loss: 1.0219 - learning_rate: 5.0000e-05
# Epoch 38/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - dice_coef: 0.3693 - iou_coef: 0.2314 - loss: 1.1637
# Epoch 38: val_dice_coef improved from 0.36541 to 0.37465, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 38: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 328ms/step - dice_coef: 0.3725 - iou_coef: 0.2355 - loss: 1.1341 - val_dice_coef: 0.3747 - val_iou_coef: 0.2389 - val_loss: 1.0114 - learning_rate: 5.0000e-05
# Epoch 39/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - dice_coef: 0.3876 - iou_coef: 0.2458 - loss: 1.1275
# Epoch 39: val_dice_coef improved from 0.37465 to 0.38277, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 39: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 329ms/step - dice_coef: 0.3909 - iou_coef: 0.2502 - loss: 1.1005 - val_dice_coef: 0.3828 - val_iou_coef: 0.2454 - val_loss: 1.0015 - learning_rate: 5.0000e-05
# Epoch 40/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - dice_coef: 0.4058 - iou_coef: 0.2606 - loss: 1.0925
# Epoch 40: val_dice_coef improved from 0.38277 to 0.39671, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 40: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 325ms/step - dice_coef: 0.4103 - iou_coef: 0.2661 - loss: 1.0658 - val_dice_coef: 0.3967 - val_iou_coef: 0.2562 - val_loss: 0.9824 - learning_rate: 5.0000e-05
# Epoch 41/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - dice_coef: 0.4279 - iou_coef: 0.2787 - loss: 1.0504
# Epoch 41: val_dice_coef improved from 0.39671 to 0.41729, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 41: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 332ms/step - dice_coef: 0.4330 - iou_coef: 0.2849 - loss: 1.0247 - val_dice_coef: 0.4173 - val_iou_coef: 0.2727 - val_loss: 0.9633 - learning_rate: 5.0000e-05
# Epoch 42/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - dice_coef: 0.4506 - iou_coef: 0.2980 - loss: 1.0124
# Epoch 42: val_dice_coef improved from 0.41729 to 0.43026, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 42: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 332ms/step - dice_coef: 0.4549 - iou_coef: 0.3035 - loss: 0.9870 - val_dice_coef: 0.4303 - val_iou_coef: 0.2836 - val_loss: 0.9414 - learning_rate: 5.0000e-05
# Epoch 43/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - dice_coef: 0.4774 - iou_coef: 0.3214 - loss: 0.9640
# Epoch 43: val_dice_coef improved from 0.43026 to 0.44021, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 43: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 326ms/step - dice_coef: 0.4808 - iou_coef: 0.3265 - loss: 0.9419 - val_dice_coef: 0.4402 - val_iou_coef: 0.2920 - val_loss: 0.9328 - learning_rate: 5.0000e-05
# Epoch 44/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - dice_coef: 0.5031 - iou_coef: 0.3446 - loss: 0.9198
# Epoch 44: val_dice_coef improved from 0.44021 to 0.45250, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch
100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - dice_coef: 0.8809 - iou_coef: 0.7907 - loss: 0.2309
# Epoch 71: val_dice_coef did not improve from 0.65862
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 323ms/step - dice_coef: 0.8842 - iou_coef: 0.7962 - loss: 0.2240 - val_dice_coef: 0.6314 - val_iou_coef: 0.4840 - val_loss: 0.9178 - learning_rate: 2.5000e-05
# Epoch 72/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - dice_coef: 0.8834 - iou_coef: 0.7943 - loss: 0.2290
# Epoch 72: val_dice_coef did not improve from 0.65862
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 320ms/step - dice_coef: 0.8884 - iou_coef: 0.8024 - loss: 0.2162 - val_dice_coef: 0.6155 - val_iou_coef: 0.4663 - val_loss: 1.0021 - learning_rate: 2.5000e-05
# Epoch 73/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - dice_coef: 0.8655 - iou_coef: 0.7680 - loss: 0.2717
# Epoch 73: val_dice_coef did not improve from 0.65862
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 321ms/step - dice_coef: 0.8697 - iou_coef: 0.7753 - loss: 0.2468 - val_dice_coef: 0.6249 - val_iou_coef: 0.4712 - val_loss: 0.9922 - learning_rate: 1.2500e-05
# Epoch 74/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - dice_coef: 0.8608 - iou_coef: 0.7603 - loss: 0.3002
# Epoch 74: val_dice_coef improved from 0.65862 to 0.66368, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 74: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 321ms/step - dice_coef: 0.8697 - iou_coef: 0.7746 - loss: 0.2514 - val_dice_coef: 0.6637 - val_iou_coef: 0.5148 - val_loss: 0.8403 - learning_rate: 1.2500e-05
# Epoch 75/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - dice_coef: 0.8813 - iou_coef: 0.7915 - loss: 0.2442
# Epoch 75: val_dice_coef improved from 0.66368 to 0.67568, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 75: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 330ms/step - dice_coef: 0.8835 - iou_coef: 0.7954 - loss: 0.2205 - val_dice_coef: 0.6757 - val_iou_coef: 0.5302 - val_loss: 0.7937 - learning_rate: 1.2500e-05
# Epoch 76/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - dice_coef: 0.8946 - iou_coef: 0.8124 - loss: 0.2118
# Epoch 76: val_dice_coef improved from 0.67568 to 0.67968, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 76: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 323ms/step - dice_coef: 0.8942 - iou_coef: 0.8119 - loss: 0.1993 - val_dice_coef: 0.6797 - val_iou_coef: 0.5365 - val_loss: 0.7861 - learning_rate: 1.2500e-05
# Epoch 77/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - dice_coef: 0.9030 - iou_coef: 0.8257 - loss: 0.1934
# Epoch 77: val_dice_coef improved from 0.67968 to 0.68243, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 77: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 322ms/step - dice_coef: 0.9014 - iou_coef: 0.8233 - loss: 0.1858 - val_dice_coef: 0.6824 - val_iou_coef: 0.5403 - val_loss: 0.7830 - learning_rate: 1.2500e-05
# Epoch 78/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - dice_coef: 0.9087 - iou_coef: 0.8350 - loss: 0.1811
# Epoch 78: val_dice_coef improved from 0.68243 to 0.68401, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 78: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 321ms/step - dice_coef: 0.9069 - iou_coef: 0.8321 - loss: 0.1756 - val_dice_coef: 0.6840 - val_iou_coef: 0.5418 - val_loss: 0.7902 - learning_rate: 1.2500e-05
# Epoch 79/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - dice_coef: 0.9093 - iou_coef: 0.8360 - loss: 0.1794
# Epoch 79: val_dice_coef improved from 0.68401 to 0.68425, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 79: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 324ms/step - dice_coef: 0.9224 - iou_coef: 0.8573 - loss: 0.1454 - val_dice_coef: 0.6835 - val_iou_coef: 0.5407 - val_loss: 0.8175 - learning_rate: 3.1250e-06
# Epoch 89/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - dice_coef: 0.9241 - iou_coef: 0.8602 - loss: 0.1437
# Epoch 89: val_dice_coef did not improve from 0.68646
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 326ms/step - dice_coef: 0.9237 - iou_coef: 0.8595 - loss: 0.1429 - val_dice_coef: 0.6838 - val_iou_coef: 0.5411 - val_loss: 0.8208 - learning_rate: 3.1250e-06
# Epoch 90/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - dice_coef: 0.9251 - iou_coef: 0.8619 - loss: 0.1419
# Epoch 90: val_dice_coef did not improve from 0.68646
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 326ms/step - dice_coef: 0.9248 - iou_coef: 0.8614 - loss: 0.1408 - val_dice_coef: 0.6840 - val_iou_coef: 0.5413 - val_loss: 0.8244 - learning_rate: 3.1250e-06
# Epoch 91/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - dice_coef: 0.9251 - iou_coef: 0.8619 - loss: 0.1417
# Epoch 91: val_dice_coef did not improve from 0.68646
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 325ms/step - dice_coef: 0.9249 - iou_coef: 0.8616 - loss: 0.1397 - val_dice_coef: 0.6822 - val_iou_coef: 0.5393 - val_loss: 0.8411 - learning_rate: 1.5625e-06
# Epoch 92/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - dice_coef: 0.9261 - iou_coef: 0.8637 - loss: 0.1412
# Epoch 92: val_dice_coef did not improve from 0.68646
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 325ms/step - dice_coef: 0.9259 - iou_coef: 0.8633 - loss: 0.1383 - val_dice_coef: 0.6824 - val_iou_coef: 0.5396 - val_loss: 0.8419 - learning_rate: 1.5625e-06
# Epoch 93/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - dice_coef: 0.9268 - iou_coef: 0.8648 - loss: 0.1397
# Epoch 93: val_dice_coef did not improve from 0.68646
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 328ms/step - dice_coef: 0.9266 - iou_coef: 0.8644 - loss: 0.1370 - val_dice_coef: 0.6826 - val_iou_coef: 0.5398 - val_loss: 0.8432 - learning_rate: 1.5625e-06
# Epoch 94/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - dice_coef: 0.9274 - iou_coef: 0.8658 - loss: 0.1385
# Epoch 94: val_dice_coef did not improve from 0.68646
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 329ms/step - dice_coef: 0.9272 - iou_coef: 0.8655 - loss: 0.1358 - val_dice_coef: 0.6827 - val_iou_coef: 0.5400 - val_loss: 0.8446 - learning_rate: 1.5625e-06
# Epoch 95/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - dice_coef: 0.9280 - iou_coef: 0.8668 - loss: 0.1373
# Epoch 95: val_dice_coef did not improve from 0.68646
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 326ms/step - dice_coef: 0.9278 - iou_coef: 0.8665 - loss: 0.1347 - val_dice_coef: 0.6829 - val_iou_coef: 0.5403 - val_loss: 0.8462 - learning_rate: 1.5625e-06
# Epoch 96/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - dice_coef: 0.9285 - iou_coef: 0.8677 - loss: 0.1362
# Epoch 96: val_dice_coef did not improve from 0.68646
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1e-06.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 336ms/step - dice_coef: 0.9284 - iou_coef: 0.8675 - loss: 0.1336 - val_dice_coef: 0.6831 - val_iou_coef: 0.5405 - val_loss: 0.8477 - learning_rate: 1.5625e-06
# Epoch 97/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - dice_coef: 0.9288 - iou_coef: 0.8681 - loss: 0.1358
# Epoch 97: val_dice_coef did not improve from 0.68646
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 327ms/step - dice_coef: 0.9287 - iou_coef: 0.8680 - loss: 0.1328 - val_dice_coef: 0.6829 - val_iou_coef: 0.5403 - val_loss: 0.8518 - learning_rate: 1.0000e-06
# Epoch 98/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - dice_coef: 0.9293 - iou_coef: 0.8690 - loss: 0.1349
# Epoch 98: val_dice_coef did not improve from 0.68646
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 327ms/step - dice_coef: 0.9291 - iou_coef: 0.8688 - loss: 0.1320 - val_dice_coef: 0.6830 - val_iou_coef: 0.5403 - val_loss: 0.8534 - learning_rate: 1.0000e-06
# Epoch 99/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - dice_coef: 0.9297 - iou_coef: 0.8697 - loss: 0.1342
# Epoch 99: val_dice_coef did not improve from 0.68646
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 326ms/step - dice_coef: 0.9295 - iou_coef: 0.8695 - loss: 0.1313 - val_dice_coef: 0.6831 - val_iou_coef: 0.5404 - val_loss: 0.8549 - learning_rate: 1.0000e-06
# Epoch 99: early stopping
# Restoring model weights from the end of the best epoch: 84.

# %%
MODEL_PATH = MODEL_DIR / "bubble_unet.keras"
HISTORY_PATH = OUTPUT_DIR / "training_history.json"

model.save(MODEL_PATH)
serializable_history = {
    name: [float(value) for value in values]
    for name, values in history.history.items()
}
with HISTORY_PATH.open("w") as history_file:
    json.dump(serializable_history, history_file, indent=2)

print("Saved model to:", MODEL_PATH)
print("Saved training history to:", HISTORY_PATH)
# Out:
# Saved model to: ../outputs/models/bubble_unet.keras
# Saved training history to: ../outputs/training_history.json

# %%
preds_val = model.predict(X_val)

print("Prediction min:", preds_val.min())
print("Prediction max:", preds_val.max())
print("Prediction mean:", preds_val.mean())
print("Ground truth foreground ratio:", Y_val.mean())

def dice_at_threshold(y_true, y_pred, threshold):
    y_pred_bin = (y_pred > threshold).astype(np.float32)
    intersection = np.sum(y_true * y_pred_bin)
    return (2 * intersection + 1) / (np.sum(y_true) + np.sum(y_pred_bin) + 1)

for t in np.arange(0.25, 0.50, 0.025):
    d = dice_at_threshold(Y_val, preds_val, t)
    fg = (preds_val > t).mean()
    print(f"Threshold {t:.3f} | Dice: {d:.4f} | Pred foreground: {fg:.4f}")
    
# for t in [0.2, 0.3, 0.4, 0.5]:
#     print(f"Foreground ratio at threshold {t}:", (preds_val > t).mean())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 779ms/step
# Prediction min: 0.0
# Prediction max: 1.0
# Prediction mean: 0.09255332
# Ground truth foreground ratio: 0.08361435
# Threshold 0.250 | Dice: 0.7254 | Pred foreground: 0.0990
# Threshold 0.275 | Dice: 0.7265 | Pred foreground: 0.0980
# Threshold 0.300 | Dice: 0.7276 | Pred foreground: 0.0971
# Threshold 0.325 | Dice: 0.7285 | Pred foreground: 0.0963
# Threshold 0.350 | Dice: 0.7294 | Pred foreground: 0.0955
# Threshold 0.375 | Dice: 0.7304 | Pred foreground: 0.0947
# Threshold 0.400 | Dice: 0.7313 | Pred foreground: 0.0940
# Threshold 0.425 | Dice: 0.7321 | Pred foreground: 0.0932
# Threshold 0.450 | Dice: 0.7326 | Pred foreground: 0.0925
# Threshold 0.475 | Dice: 0.7332 | Pred foreground: 0.0918

# %%
thresholds = np.arange(0.05, 0.951, 0.025)
threshold_results = []

for threshold in thresholds:
    dice = dice_at_threshold(Y_val, preds_val, threshold)
    foreground_ratio = float((preds_val > threshold).mean())
    threshold_results.append(
        (float(threshold), float(dice), foreground_ratio)
    )
    print(
        f"Threshold {threshold:.3f} | Dice: {dice:.4f} | "
        f"Pred foreground: {foreground_ratio:.4f}"
    )

best_threshold, best_dice, best_foreground_ratio = max(
    threshold_results,
    key=lambda result: result[1]
)

threshold_summary = {
    "best_threshold": best_threshold,
    "validation_dice": best_dice,
    "predicted_foreground_ratio": best_foreground_ratio,
    "ground_truth_foreground_ratio": float(Y_val.mean()),
}
# with (OUTPUT_DIR / "threshold_summary.json").open("w") as summary_file:
#     json.dump(threshold_summary, summary_file, indent=2)

print("\nBest validation threshold:", best_threshold)
print("Best validation Dice:", best_dice)
# print("Best validation Dice:", best_dice)
# Out:
# Threshold 0.050 | Dice: 0.6971 | Pred foreground: 0.1158
# Threshold 0.075 | Dice: 0.7066 | Pred foreground: 0.1111
# Threshold 0.100 | Dice: 0.7126 | Pred foreground: 0.1081
# Threshold 0.125 | Dice: 0.7163 | Pred foreground: 0.1058
# Threshold 0.150 | Dice: 0.7188 | Pred foreground: 0.1040
# Threshold 0.175 | Dice: 0.7208 | Pred foreground: 0.1025
# Threshold 0.200 | Dice: 0.7227 | Pred foreground: 0.1012
# Threshold 0.225 | Dice: 0.7242 | Pred foreground: 0.1000
# Threshold 0.250 | Dice: 0.7254 | Pred foreground: 0.0990
# Threshold 0.275 | Dice: 0.7265 | Pred foreground: 0.0980
# Threshold 0.300 | Dice: 0.7276 | Pred foreground: 0.0971
# Threshold 0.325 | Dice: 0.7285 | Pred foreground: 0.0963
# Threshold 0.350 | Dice: 0.7294 | Pred foreground: 0.0955
# Threshold 0.375 | Dice: 0.7304 | Pred foreground: 0.0947
# Threshold 0.400 | Dice: 0.7313 | Pred foreground: 0.0940
# Threshold 0.425 | Dice: 0.7321 | Pred foreground: 0.0932
# Threshold 0.450 | Dice: 0.7326 | Pred foreground: 0.0925
# Threshold 0.475 | Dice: 0.7332 | Pred foreground: 0.0918
# Threshold 0.500 | Dice: 0.7336 | Pred foreground: 0.0911
# Threshold 0.525 | Dice: 0.7341 | Pred foreground: 0.0905
# Threshold 0.550 | Dice: 0.7347 | Pred foreground: 0.0899
# Threshold 0.575 | Dice: 0.7353 | Pred foreground: 0.0892
# Threshold 0.600 | Dice: 0.7359 | Pred foreground: 0.0886
# Threshold 0.625 | Dice: 0.7365 | Pred foreground: 0.0879
# Threshold 0.650 | Dice: 0.7368 | Pred foreground: 0.0873
# Threshold 0.675 | Dice: 0.7373 | Pred foreground: 0.0866
# Threshold 0.700 | Dice: 0.7375 | Pred foreground: 0.0859
# Threshold 0.725 | Dice: 0.7378 | Pred foreground: 0.0852
# Threshold 0.750 | Dice: 0.7380 | Pred foreground: 0.0845
# Threshold 0.775 | Dice: 0.7381 | Pred foreground: 0.0837
# Threshold 0.800 | Dice: 0.7379 | Pred foreground: 0.0828
# Threshold 0.825 | Dice: 0.7378 | Pred foreground: 0.0819
# Threshold 0.850 | Dice: 0.7378 | Pred foreground: 0.0808
# Threshold 0.875 | Dice: 0.7375 | Pred foreground: 0.0796
# Threshold 0.900 | Dice: 0.7368 | Pred foreground: 0.0781
# Threshold 0.925 | Dice: 0.7358 | Pred foreground: 0.0762
# Threshold 0.950 | Dice: 0.7331 | Pred foreground: 0.0733
#
# Best validation threshold: 0.7750000000000002
# Best validation Dice: 0.7381235361099243

# %%
for idx in [0, 10, 13, 20]:
    image = X_val[idx].squeeze()
    ground_truth = Y_val[idx].squeeze() > 0.5
    probability = preds_val[idx].squeeze()
    prediction = probability > best_threshold

    tp = ground_truth & prediction
    fp = ~ground_truth & prediction
    fn = ground_truth & ~prediction

    tp_count = tp.sum()
    fp_count = fp.sum()
    fn_count = fn.sum()

    precision = tp_count / (tp_count + fp_count + 1e-8)
    recall = tp_count / (tp_count + fn_count + 1e-8)
    dice = (
        2 * tp_count /
        (2 * tp_count + fp_count + fn_count + 1e-8)
    )

    # 0 = correct background
    # 1 = true positive
    # 2 = false positive
    # 3 = false negative
    comparison = np.zeros(ground_truth.shape, dtype=np.uint8)
    comparison[tp] = 1
    comparison[fp] = 2
    comparison[fn] = 3

    comparison_cmap = ListedColormap([
        "black",       # correct background
        "limegreen",   # true positive
        "red",         # false positive
        "deepskyblue"  # false negative
    ])

    fig, axes = plt.subplots(1, 5, figsize=(21, 4))

    axes[0].imshow(image, cmap="gray")
    axes[0].set_title("Validation input\nF770W intensity")

    axes[1].imshow(
        ground_truth,
        cmap="gray",
        vmin=0,
        vmax=1
    )
    axes[1].set_title("Ground truth\nWhite = catalogue foreground")

    probability_plot = axes[2].imshow(
        probability,
        cmap="inferno",
        vmin=0,
        vmax=1
    )
    axes[2].set_title("Predicted probability")

    colorbar = fig.colorbar(
        probability_plot,
        ax=axes[2],
        fraction=0.046,
        pad=0.04
    )
    colorbar.set_label("Foreground probability")

    axes[3].imshow(
        prediction,
        cmap="gray",
        vmin=0,
        vmax=1
    )
    axes[3].set_title(
        f"Binary prediction\n"
        f"White = probability > {best_threshold:.2f}"
    )

    axes[4].imshow(
        comparison,
        cmap=comparison_cmap,
        vmin=0,
        vmax=3
    )
    axes[4].set_title(
        f"Prediction errors\n"
        f"Dice={dice:.3f}, P={precision:.3f}, R={recall:.3f}"
    )

    legend_items = [
        Patch(color="limegreen", label="True positive"),
        Patch(color="red", label="False positive"),
        Patch(color="deepskyblue", label="False negative"),
        Patch(color="black", label="Correct background")
    ]

    axes[4].legend(
        handles=legend_items,
        loc="lower center",
        bbox_to_anchor=(0.5, -0.35),
        ncol=2,
        frameon=False
    )

    for axis in axes:
        axis.axis("off")

    plt.tight_layout()
    plt.show()

# %%
# Loss curves
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, "loss_curve.png"), dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['dice_coef'], label='Training Dice')
plt.plot(history.history['val_dice_coef'], label='Validation Dice')

plt.title('Dice Coefficient During Training')
plt.xlabel('Epoch')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig(os.path.join(FIGURE_DIR, "dice_curve.png"), dpi=300)
plt.show()
