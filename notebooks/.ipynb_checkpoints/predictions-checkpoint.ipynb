# %%
# training rough model

import numpy as np
from tensorflow.keras import layers, models
import tensorflow as tf
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
EPOCHS = 10
BATCH_SIZE = 4

X_DIR = "../data/processed/patches/X.npy"
Y_DIR = "../data/processed/patches/Y.npy"

X = np.load(X_DIR).astype(np.float32)
Y = np.load(Y_DIR).astype(np.float32)

print("X shape:", X.shape, "dtype:", X.dtype, "min/max:", X.min(), X.max())
print("Y shape:", Y.shape, "dtype:", Y.dtype, "min/max:", Y.min(), Y.max())

print("Foreground pixel ratio:", np.mean(Y))
# Out:
# X shape: (136, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y shape: (136, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Foreground pixel ratio: 0.14651524

# %%
# simple unet model
# inputs → encoder → bottleneck → decoder → sigmoid mask

def build_unet(input_shape=(256,256,1)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D()(c1)

    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D()(c2)

    # Bottleneck
    b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
    b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(b1)

    # Decoder
    u1 = layers.UpSampling2D()(b1)
    u1 = layers.concatenate([u1, c2])
    c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(u1)
    c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(c3)

    u2 = layers.UpSampling2D()(c3)
    u2 = layers.concatenate([u2, c1])
    c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(u2)
    c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(c4)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(c4)

    model = models.Model(inputs, outputs)
    return model

# %%
# intensity augmentation to image only
# same geometric augmentation to image and mask
def augment_patch(image, mask):

    if random.random() < 0.5:
        image = np.flip(image, axis=1)
        mask = np.flip(mask, axis=1)

    if random.random() < 0.5:
        image = np.flip(image, axis=0)
        mask = np.flip(mask, axis=0)

    # 90 deg rotation
    k = random.choice([0, 1, 2, 3])
    image = np.rot90(image, k)
    mask = np.rot90(mask, k)

    # Brightness shift — image only
    if random.random() < 0.5:
        shift = random.uniform(-0.08, 0.08)
        image = image + shift

    # Contrast adjustment — image only
    if random.random() < 0.5:
        factor = random.uniform(0.85, 1.15)
        image = (image - image.mean()) * factor + image.mean()

    # Clip image back to valid range
    image = np.clip(image, 0, 1)

    # Ensure mask stays binary
    mask = (mask > 0.5).astype(np.float32)

    return image.astype(np.float32), mask.astype(np.float32)

# %%
def augment_dataset(X_train, Y_train, augment_factor=3):
    X_aug = [X_train]
    Y_aug = [Y_train]

    for _ in range(augment_factor):
        augmented_images = []
        augmented_masks = []

        for img, msk in zip(X_train, Y_train):
            img_aug, msk_aug = augment_patch(img, msk)
            augmented_images.append(img_aug)
            augmented_masks.append(msk_aug)

        X_aug.append(np.array(augmented_images, dtype=np.float32))
        Y_aug.append(np.array(augmented_masks, dtype=np.float32))

    X_aug = np.concatenate(X_aug, axis=0)
    Y_aug = np.concatenate(Y_aug, axis=0)

    return X_aug, Y_aug

# %%
X_train, X_val, Y_train, Y_val = train_test_split(
    X, Y,
    test_size=0.2,
    random_state=42,
    shuffle=True
)

print("Before augmentation:")
print("X_train:", X_train.shape)
print("Y_train:", Y_train.shape)
print("X_val:", X_val.shape)
print("Y_val:", Y_val.shape)

X_train_aug, Y_train_aug = augment_dataset(
    X_train,
    Y_train,
    augment_factor=3
)

print("\nAfter augmentation:")
print("X_train_aug:", X_train_aug.shape)
print("Y_train_aug:", Y_train_aug.shape)
print("X_val:", X_val.shape)
print("Y_val:", Y_val.shape)
# Out:
# Before augmentation:
# X_train: (108, 256, 256, 1)
# Y_train: (108, 256, 256, 1)
# X_val: (28, 256, 256, 1)
# Y_val: (28, 256, 256, 1)
#
# After augmentation:
# X_train_aug: (432, 256, 256, 1)
# Y_train_aug: (432, 256, 256, 1)
# X_val: (28, 256, 256, 1)
# Y_val: (28, 256, 256, 1)

# %%
def dice_loss(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) /
                (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth))

def weighted_bce(y_true, y_pred):
    y_pred = tf.clip_by_value(
        y_pred,
        tf.keras.backend.epsilon(),
        1 - tf.keras.backend.epsilon()
    )

    # weights = y_true * 5 + 1
    weights = y_true * 2 + 1
    # choosing 5 manually... for now

    bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)

    return tf.reduce_mean(weights * bce)
    
def combined_loss(y_true, y_pred):
    return weighted_bce(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def iou_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
model = build_unet()

model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss=combined_loss,
              metrics=[dice_coef, iou_coef])

# %%
history = model.fit(
    X_train_aug,
    Y_train_aug,
    validation_data=(X_val, Y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE
)
# Out:
# Epoch 1/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 29s 249ms/step - dice_coef: 0.2056 - iou_coef: 0.1161 - loss: 1.6446 - val_dice_coef: 0.2122 - val_iou_coef: 0.1200 - val_loss: 1.6475
# Epoch 2/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 27s 248ms/step - dice_coef: 0.2038 - iou_coef: 0.1151 - loss: 1.6257 - val_dice_coef: 0.2055 - val_iou_coef: 0.1156 - val_loss: 1.6502
# Epoch 3/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 235ms/step - dice_coef: 0.2007 - iou_coef: 0.1130 - loss: 1.6289 - val_dice_coef: 0.2035 - val_iou_coef: 0.1144 - val_loss: 1.6502
# Epoch 4/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 239ms/step - dice_coef: 0.2008 - iou_coef: 0.1132 - loss: 1.6308 - val_dice_coef: 0.2073 - val_iou_coef: 0.1168 - val_loss: 1.6435
# Epoch 5/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 228ms/step - dice_coef: 0.2016 - iou_coef: 0.1133 - loss: 1.6269 - val_dice_coef: 0.2118 - val_iou_coef: 0.1197 - val_loss: 1.6407
# Epoch 6/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 27s 253ms/step - dice_coef: 0.2017 - iou_coef: 0.1134 - loss: 1.6254 - val_dice_coef: 0.2110 - val_iou_coef: 0.1192 - val_loss: 1.6389
# Epoch 7/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - dice_coef: 0.2011 - iou_coef: 0.1132 - loss: 1.6271 - val_dice_coef: 0.2105 - val_iou_coef: 0.1189 - val_loss: 1.6381
# Epoch 8/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 229ms/step - dice_coef: 0.2010 - iou_coef: 0.1130 - loss: 1.6274 - val_dice_coef: 0.2104 - val_iou_coef: 0.1188 - val_loss: 1.6394
# Epoch 9/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 240ms/step - dice_coef: 0.1992 - iou_coef: 0.1124 - loss: 1.6291 - val_dice_coef: 0.2109 - val_iou_coef: 0.1192 - val_loss: 1.6387
# Epoch 10/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 231ms/step - dice_coef: 0.2011 - iou_coef: 0.1131 - loss: 1.6271 - val_dice_coef: 0.2064 - val_iou_coef: 0.1163 - val_loss: 1.6419
# Epoch 11/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 238ms/step - dice_coef: 0.2003 - iou_coef: 0.1128 - loss: 1.6268 - val_dice_coef: 0.2050 - val_iou_coef: 0.1154 - val_loss: 1.6449
# Epoch 12/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - dice_coef: 0.1998 - iou_coef: 0.1125 - loss: 1.6271 - val_dice_coef: 0.2125 - val_iou_coef: 0.1202 - val_loss: 1.6383
# Epoch 13/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - dice_coef: 0.2013 - iou_coef: 0.1134 - loss: 1.6268 - val_dice_coef: 0.2088 - val_iou_coef: 0.1178 - val_loss: 1.6397
# Epoch 14/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 245ms/step - dice_coef: 0.2008 - iou_coef: 0.1131 - loss: 1.6252 - val_dice_coef: 0.2024 - val_iou_coef: 0.1137 - val_loss: 1.6486
# Epoch 15/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - dice_coef: 0.2014 - iou_coef: 0.1132 - loss: 1.6248 - val_dice_coef: 0.2088 - val_iou_coef: 0.1178 - val_loss: 1.6406
# Epoch 16/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 235ms/step - dice_coef: 0.2002 - iou_coef: 0.1127 - loss: 1.6267 - val_dice_coef: 0.2098 - val_iou_coef: 0.1184 - val_loss: 1.6394
# Epoch 17/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - dice_coef: 0.2002 - iou_coef: 0.1127 - loss: 1.6261 - val_dice_coef: 0.2111 - val_iou_coef: 0.1193 - val_loss: 1.6386
# Epoch 18/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - dice_coef: 0.2007 - iou_coef: 0.1130 - loss: 1.6266 - val_dice_coef: 0.2074 - val_iou_coef: 0.1169 - val_loss: 1.6412
# Epoch 19/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 236ms/step - dice_coef: 0.1998 - iou_coef: 0.1127 - loss: 1.6277 - val_dice_coef: 0.2083 - val_iou_coef: 0.1175 - val_loss: 1.6404
# Epoch 20/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - dice_coef: 0.1987 - iou_coef: 0.1119 - loss: 1.6272 - val_dice_coef: 0.2089 - val_iou_coef: 0.1179 - val_loss: 1.6397

# %%
preds_val = model.predict(X_val)

print("Prediction min:", preds_val.min())
print("Prediction max:", preds_val.max())
print("Prediction mean:", preds_val.mean())
print("Ground truth foreground ratio:", Y_val.mean())

for t in [0.2, 0.3, 0.4, 0.5]:
    print(f"Foreground ratio at threshold {t}:", (preds_val > t).mean())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# Prediction min: 0.1672882
# Prediction max: 0.47855145
# Prediction mean: 0.3644317
# Ground truth foreground ratio: 0.15308926
# Foreground ratio at threshold 0.2: 0.999481201171875
# Foreground ratio at threshold 0.3: 0.9851711818150112
# Foreground ratio at threshold 0.4: 0.006093706403459821
# Foreground ratio at threshold 0.5: 0.0

# %%
idx = 0
pred = preds_val[idx].squeeze()
pred_thresh = (pred > 0.3).astype(np.float32)

plt.figure(figsize=(16, 4))

plt.subplot(1, 4, 1)
plt.imshow(X_val[idx].squeeze(), cmap="gray")
plt.title("Validation Input")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(Y_val[idx].squeeze(), cmap="gray")
plt.title("Ground Truth")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.imshow(pred, cmap="inferno")
plt.title("Prediction Probability")
plt.axis("off")

plt.subplot(1, 4, 4)
plt.imshow(pred_thresh, cmap="gray")
plt.title("Thresholded Prediction: 0.3")
plt.axis("off")

plt.show()

# %%
# Loss curves
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('../outputs/figures/loss_curve.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['dice_coef'], label='Training Dice')
plt.plot(history.history['val_dice_coef'], label='Validation Dice')

plt.title('Dice Coefficient During Training')
plt.xlabel('Epoch')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('../outputs/figures/dice_curve.png', dpi=300)
plt.show()
