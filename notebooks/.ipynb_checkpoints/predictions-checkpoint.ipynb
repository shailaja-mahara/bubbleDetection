# %%
# training rough model

import numpy as np
from tensorflow.keras import layers, models
import tensorflow as tf
import random
import matplotlib.pyplot as plt

# %%
SEED = 42
EPOCHS = 20
BATCH_SIZE = 4
POSITIVE_CLASS_WEIGHT = 1.5

tf.keras.utils.set_random_seed(SEED)

DATA_DIR = Path("../data/processed/augumented")
FIGURE_DIR = '../outputs/figures'

X_train = np.load(DATA_DIR / "X_train_aug.npy").astype(np.float32)
X_val = np.load(DATA_DIR / "X_validation.npy").astype(np.float32)
Y_train = np.load(DATA_DIR / "Y_train_aug.npy").astype(np.float32)
Y_val = np.load(DATA_DIR / "Y_validation.npy").astype(np.float32)

print("X_train shape:", X_train.shape, "dtype:", X_train.dtype, "min/max:", X_train.min(), X_train.max())
print("X_val shape:", X_val.shape, "dtype:", X_val.dtype, "min/max:", X_val.min(), X_val.max())
print("Y_train shape:", Y_train.shape, "dtype:", Y_train.dtype, "min/max:", Y_train.min(), Y_train.max())
print("Y_val shape:", Y_val.shape, "dtype:", Y_val.dtype, "min/max:", Y_val.min(), Y_val.max())

print("Training foreground ratio:", float(Y_train.mean()))
print("Validation foreground ratio:", float(Y_val.mean()))
# Out:
# X_train shape: (432, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# X_val shape: (28, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_train shape: (432, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_val shape: (28, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Training foreground ratio: 0.2216905653476715
# Validation foreground ratio: 0.2596871554851532

# %%
# simple unet model
# inputs → encoder → bottleneck → decoder → sigmoid mask

def build_unet(input_shape=(256, 256, 1)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D()(c1)

    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D()(c2)

    # Bottleneck
    b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
    b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(b1)

    # Decoder
    u1 = layers.UpSampling2D()(b1)
    u1 = layers.concatenate([u1, c2])
    c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(u1)
    c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(c3)

    u2 = layers.UpSampling2D()(c3)
    u2 = layers.concatenate([u2, c1])
    c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(u2)
    c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(c4)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(c4)

    return models.Model(inputs, outputs, name="bubble_unet")

# %%
def dice_loss(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) /
                (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth))

def weighted_bce(y_true, y_pred):
    y_pred = tf.clip_by_value(
        y_pred,
        tf.keras.backend.epsilon(),
        1 - tf.keras.backend.epsilon()
    )

    weights = y_true * 1.5 + 1
    bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)

    return tf.reduce_mean(weights * bce)

def combined_loss(y_true, y_pred):
    return weighted_bce(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def iou_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss,
    metrics=[dice_coef, iou_coef]
)
model.summary()
# Out:
# Model: "bubble_unet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 256, 256,  │        160 │ input_layer_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 256, 256,  │      2,320 │ conv2d_22[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 128, 128,  │          0 │ conv2d_23[0][0]   │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 128, 128,  │      4,640 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 128, 128,  │      9,248 │ conv2d_24[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 64, 64,    │          0 │ conv2d_25[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 64, 64,    │     18,496 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 64, 64,    │     36,928 │ conv2d_26[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 128, 128,  │          0 │ conv2d_27[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 128, 128,  │          0 │ up_sampling2d_4[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_25[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 128, 128,  │     27,680 │ concatenate_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 128, 128,  │      9,248 │ conv2d_28[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 256, 256,  │          0 │ conv2d_29[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 256, 256,  │          0 │ up_sampling2d_5[… │
# │ (Concatenate)       │ 48)               │            │ conv2d_23[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 256, 256,  │      6,928 │ concatenate_5[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 256, 256,  │      2,320 │ conv2d_30[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 256, 256,  │         17 │ conv2d_31[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 117,985 (460.88 KB)
#  Trainable params: 117,985 (460.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train,
    Y_train,
    validation_data=(X_val, Y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    shuffle=True
)
# Out:
# Epoch 1/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 27s 237ms/step - dice_coef: 0.2992 - iou_coef: 0.1777 - loss: 1.6182 - val_dice_coef: 0.3314 - val_iou_coef: 0.2000 - val_loss: 1.6165
# Epoch 2/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 235ms/step - dice_coef: 0.3252 - iou_coef: 0.1957 - loss: 1.5215 - val_dice_coef: 0.3592 - val_iou_coef: 0.2212 - val_loss: 1.5650
# Epoch 3/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - dice_coef: 0.3346 - iou_coef: 0.2023 - loss: 1.5032 - val_dice_coef: 0.3483 - val_iou_coef: 0.2128 - val_loss: 1.5733
# Epoch 4/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - dice_coef: 0.3362 - iou_coef: 0.2036 - loss: 1.5015 - val_dice_coef: 0.3579 - val_iou_coef: 0.2202 - val_loss: 1.5644
# Epoch 5/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - dice_coef: 0.3371 - iou_coef: 0.2041 - loss: 1.4983 - val_dice_coef: 0.3560 - val_iou_coef: 0.2186 - val_loss: 1.5664
# Epoch 6/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 239ms/step - dice_coef: 0.3373 - iou_coef: 0.2043 - loss: 1.4989 - val_dice_coef: 0.3502 - val_iou_coef: 0.2143 - val_loss: 1.5689
# Epoch 7/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 238ms/step - dice_coef: 0.3359 - iou_coef: 0.2034 - loss: 1.4981 - val_dice_coef: 0.3566 - val_iou_coef: 0.2191 - val_loss: 1.5633
# Epoch 8/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - dice_coef: 0.3366 - iou_coef: 0.2038 - loss: 1.4969 - val_dice_coef: 0.3583 - val_iou_coef: 0.2204 - val_loss: 1.5613
# Epoch 9/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 235ms/step - dice_coef: 0.3393 - iou_coef: 0.2057 - loss: 1.4935 - val_dice_coef: 0.3536 - val_iou_coef: 0.2167 - val_loss: 1.5629
# Epoch 10/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - dice_coef: 0.3408 - iou_coef: 0.2069 - loss: 1.4885 - val_dice_coef: 0.3533 - val_iou_coef: 0.2164 - val_loss: 1.5595
# Epoch 11/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 228ms/step - dice_coef: 0.3436 - iou_coef: 0.2088 - loss: 1.4830 - val_dice_coef: 0.3512 - val_iou_coef: 0.2148 - val_loss: 1.5617
# Epoch 12/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - dice_coef: 0.3435 - iou_coef: 0.2088 - loss: 1.4797 - val_dice_coef: 0.3560 - val_iou_coef: 0.2182 - val_loss: 1.5533
# Epoch 13/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 240ms/step - dice_coef: 0.3457 - iou_coef: 0.2104 - loss: 1.4763 - val_dice_coef: 0.3534 - val_iou_coef: 0.2162 - val_loss: 1.5569
# Epoch 14/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 229ms/step - dice_coef: 0.3477 - iou_coef: 0.2118 - loss: 1.4720 - val_dice_coef: 0.3568 - val_iou_coef: 0.2187 - val_loss: 1.5519
# Epoch 15/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 230ms/step - dice_coef: 0.3490 - iou_coef: 0.2127 - loss: 1.4688 - val_dice_coef: 0.3582 - val_iou_coef: 0.2197 - val_loss: 1.5489
# Epoch 16/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 230ms/step - dice_coef: 0.3505 - iou_coef: 0.2138 - loss: 1.4650 - val_dice_coef: 0.3610 - val_iou_coef: 0.2218 - val_loss: 1.5428
# Epoch 17/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 236ms/step - dice_coef: 0.3530 - iou_coef: 0.2157 - loss: 1.4584 - val_dice_coef: 0.3655 - val_iou_coef: 0.2252 - val_loss: 1.5340
# Epoch 18/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - dice_coef: 0.3552 - iou_coef: 0.2173 - loss: 1.4541 - val_dice_coef: 0.3718 - val_iou_coef: 0.2300 - val_loss: 1.5239
# Epoch 19/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 230ms/step - dice_coef: 0.3600 - iou_coef: 0.2208 - loss: 1.4437 - val_dice_coef: 0.3707 - val_iou_coef: 0.2290 - val_loss: 1.5219
# Epoch 20/20
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 239ms/step - dice_coef: 0.3626 - iou_coef: 0.2227 - loss: 1.4381 - val_dice_coef: 0.3774 - val_iou_coef: 0.2341 - val_loss: 1.5108

# %%
# MODEL_PATH = MODEL_DIR / "bubble_unet.keras"
# HISTORY_PATH = OUTPUT_DIR / "training_history.json"

# model.save(MODEL_PATH)
# serializable_history = {
#     name: [float(value) for value in values]
#     for name, values in history.history.items()
# }
# with HISTORY_PATH.open("w") as history_file:
#     json.dump(serializable_history, history_file, indent=2)

# print("Saved model to:", MODEL_PATH)
# print("Saved training history to:", HISTORY_PATH)

# %%
preds_val = model.predict(X_val)

print("Prediction min:", preds_val.min())
print("Prediction max:", preds_val.max())
print("Prediction mean:", preds_val.mean())
print("Ground truth foreground ratio:", Y_val.mean())

def dice_at_threshold(y_true, y_pred, threshold):
    y_pred_bin = (y_pred > threshold).astype(np.float32)
    intersection = np.sum(y_true * y_pred_bin)
    return (2 * intersection + 1) / (np.sum(y_true) + np.sum(y_pred_bin) + 1)

for t in np.arange(0.25, 0.50, 0.025):
    d = dice_at_threshold(Y_val, preds_val, t)
    fg = (preds_val > t).mean()
    print(f"Threshold {t:.3f} | Dice: {d:.4f} | Pred foreground: {fg:.4f}")
    
# for t in [0.2, 0.3, 0.4, 0.5]:
#     print(f"Foreground ratio at threshold {t}:", (preds_val > t).mean())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# Prediction min: 1.2477355e-08
# Prediction max: 0.9008407
# Prediction mean: 0.43106312
# Ground truth foreground ratio: 0.25968716
# Threshold 0.250 | Dice: 0.4390 | Pred foreground: 0.9203
# Threshold 0.275 | Dice: 0.4393 | Pred foreground: 0.9193
# Threshold 0.300 | Dice: 0.4397 | Pred foreground: 0.9180
# Threshold 0.325 | Dice: 0.4401 | Pred foreground: 0.9156
# Threshold 0.350 | Dice: 0.4449 | Pred foreground: 0.8265
# Threshold 0.375 | Dice: 0.4510 | Pred foreground: 0.6293
# Threshold 0.400 | Dice: 0.4517 | Pred foreground: 0.5045
# Threshold 0.425 | Dice: 0.4504 | Pred foreground: 0.4327
# Threshold 0.450 | Dice: 0.4439 | Pred foreground: 0.3730
# Threshold 0.475 | Dice: 0.4323 | Pred foreground: 0.3226

# %%
thresholds = np.arange(0.05, 0.951, 0.025)
threshold_results = []

for threshold in thresholds:
    dice = dice_at_threshold(Y_val, preds_val, threshold)
    foreground_ratio = float((preds_val > threshold).mean())
    threshold_results.append(
        (float(threshold), float(dice), foreground_ratio)
    )
    print(
        f"Threshold {threshold:.3f} | Dice: {dice:.4f} | "
        f"Pred foreground: {foreground_ratio:.4f}"
    )

best_threshold, best_dice, best_foreground_ratio = max(
    threshold_results,
    key=lambda result: result[1]
)

threshold_summary = {
    "best_threshold": best_threshold,
    "validation_dice": best_dice,
    "predicted_foreground_ratio": best_foreground_ratio,
    "ground_truth_foreground_ratio": float(Y_val.mean()),
}
# with (OUTPUT_DIR / "threshold_summary.json").open("w") as summary_file:
#     json.dump(threshold_summary, summary_file, indent=2)

print("\nBest validation threshold:", best_threshold)
print("Best validation Dice:", best_dice)
# Out:
# Threshold 0.050 | Dice: 0.4369 | Pred foreground: 0.9265
# Threshold 0.075 | Dice: 0.4373 | Pred foreground: 0.9254
# Threshold 0.100 | Dice: 0.4376 | Pred foreground: 0.9245
# Threshold 0.125 | Dice: 0.4378 | Pred foreground: 0.9237
# Threshold 0.150 | Dice: 0.4380 | Pred foreground: 0.9231
# Threshold 0.175 | Dice: 0.4382 | Pred foreground: 0.9225
# Threshold 0.200 | Dice: 0.4384 | Pred foreground: 0.9218
# Threshold 0.225 | Dice: 0.4387 | Pred foreground: 0.9211
# Threshold 0.250 | Dice: 0.4390 | Pred foreground: 0.9203
# Threshold 0.275 | Dice: 0.4393 | Pred foreground: 0.9193
# Threshold 0.300 | Dice: 0.4397 | Pred foreground: 0.9180
# Threshold 0.325 | Dice: 0.4401 | Pred foreground: 0.9156
# Threshold 0.350 | Dice: 0.4449 | Pred foreground: 0.8265
# Threshold 0.375 | Dice: 0.4510 | Pred foreground: 0.6293
# Threshold 0.400 | Dice: 0.4517 | Pred foreground: 0.5045
# Threshold 0.425 | Dice: 0.4504 | Pred foreground: 0.4327
# Threshold 0.450 | Dice: 0.4439 | Pred foreground: 0.3730
# Threshold 0.475 | Dice: 0.4323 | Pred foreground: 0.3226
# Threshold 0.500 | Dice: 0.4186 | Pred foreground: 0.2776
# Threshold 0.525 | Dice: 0.4047 | Pred foreground: 0.2442
# Threshold 0.550 | Dice: 0.3901 | Pred foreground: 0.2173
# Threshold 0.575 | Dice: 0.3736 | Pred foreground: 0.1940
# Threshold 0.600 | Dice: 0.3540 | Pred foreground: 0.1729
# Threshold 0.625 | Dice: 0.3300 | Pred foreground: 0.1504
# Threshold 0.650 | Dice: 0.2994 | Pred foreground: 0.1263
# Threshold 0.675 | Dice: 0.2629 | Pred foreground: 0.1021
# Threshold 0.700 | Dice: 0.2220 | Pred foreground: 0.0790
# Threshold 0.725 | Dice: 0.1773 | Pred foreground: 0.0564
# Threshold 0.750 | Dice: 0.1287 | Pred foreground: 0.0361
# Threshold 0.775 | Dice: 0.0797 | Pred foreground: 0.0199
# Threshold 0.800 | Dice: 0.0441 | Pred foreground: 0.0095
# Threshold 0.825 | Dice: 0.0161 | Pred foreground: 0.0030
# Threshold 0.850 | Dice: 0.0038 | Pred foreground: 0.0006
# Threshold 0.875 | Dice: 0.0007 | Pred foreground: 0.0001
# Threshold 0.900 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.925 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.950 | Dice: 0.0000 | Pred foreground: 0.0000
#
# Best validation threshold: 0.40000000000000013
# Best validation Dice: 0.45174118876457214

# %%
for idx in [0, 5, 10]:
    plt.figure(figsize=(16, 4))

    plt.subplot(1, 4, 1)
    plt.imshow(X_val[idx].squeeze(), cmap="gray")
    plt.title("Validation input")
    plt.axis("off")

    plt.subplot(1, 4, 2)
    plt.imshow(Y_val[idx].squeeze(), cmap="gray")
    plt.title("Ground truth")
    plt.axis("off")

    plt.subplot(1, 4, 3)
    plt.imshow(preds_val[idx].squeeze(), cmap="inferno")
    plt.title("Prediction probability")
    plt.axis("off")

    plt.subplot(1, 4, 4)
    prediction = (
        preds_val[idx].squeeze() > best_threshold
    ).astype(np.float32)
    plt.imshow(prediction, cmap="gray")
    plt.title(f"Threshold: {best_threshold:.3f}")
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
# Loss curves
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, "loss_curve.png"), dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['dice_coef'], label='Training Dice')
plt.plot(history.history['val_dice_coef'], label='Validation Dice')

plt.title('Dice Coefficient During Training')
plt.xlabel('Epoch')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig(os.path.join(FIGURE_DIR, "dice_curve.png"), dpi=300)
plt.show()
