# %%
# training rough model

import os
import json
from pathlib import Path

import numpy as np
from tensorflow.keras import layers, models
import tensorflow as tf
import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch

# %%
DATA_DIR = Path("../data/processed/augmented")
FIGURE_DIR = '../outputs/figures'
PLOTS_DIR = '../outputs/figures/plots'
MODEL_DIR = Path("../outputs/models")
OUTPUT_DIR = Path("../outputs")

ACTIVE_STAGE = "stage00"

os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(FIGURE_DIR, exist_ok=True)
os.makedirs(PLOTS_DIR, exist_ok=True)

# %%
SEED = 42
EPOCHS = 100
BATCH_SIZE = 4

# POSITIVE_CLASS_WEIGHT = 0.5
# POSITIVE_CLASS_WEIGHT = 1.0
# POSITIVE_CLASS_WEIGHT = 1.5
POSITIVE_CLASS_WEIGHT = 2.0

EARLY_STOPPING_PATIENCE = 15

tf.keras.utils.set_random_seed(SEED)

X_train = np.load(DATA_DIR / "XtrainAug.npy").astype(np.float32)
X_val = np.load(DATA_DIR / "XVal.npy").astype(np.float32)
Y_train = np.load(DATA_DIR / "YtrainAug.npy").astype(np.float32)
Y_val = np.load(DATA_DIR / "YVal.npy").astype(np.float32)

print("X_train shape:", X_train.shape, "dtype:", X_train.dtype, "min/max:", X_train.min(), X_train.max())
print("X_val shape:", X_val.shape, "dtype:", X_val.dtype, "min/max:", X_val.min(), X_val.max())
print("Y_train shape:", Y_train.shape, "dtype:", Y_train.dtype, "min/max:", Y_train.min(), Y_train.max())
print("Y_val shape:", Y_val.shape, "dtype:", Y_val.dtype, "min/max:", Y_val.min(), Y_val.max())

print("Training foreground ratio:", float(Y_train.mean()))
print("Validation foreground ratio:", float(Y_val.mean()))
# Out:
# X_train shape: (432, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# X_val shape: (28, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_train shape: (432, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_val shape: (28, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Training foreground ratio: 0.09421736747026443
# Validation foreground ratio: 0.11299514770507812

# %%
# # simple unet model
# # inputs → encoder → bottleneck → decoder → sigmoid mask

# def build_unet(input_shape=(256, 256, 1)):
#     inputs = layers.Input(input_shape)

#     # Encoder
#     c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
#     c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
#     p1 = layers.MaxPooling2D()(c1)

#     c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
#     c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
#     p2 = layers.MaxPooling2D()(c2)

#     # Bottleneck
#     b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
#     b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(b1)

#     # Decoder
#     u1 = layers.UpSampling2D()(b1)
#     u1 = layers.concatenate([u1, c2])
#     c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(u1)
#     c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(c3)

#     u2 = layers.UpSampling2D()(c3)
#     u2 = layers.concatenate([u2, c1])
#     c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(u2)
#     c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(c4)

#     outputs = layers.Conv2D(1, 1, activation='sigmoid')(c4)

#     return models.Model(inputs, outputs, name="bubble_unet")

# %%
# 4-level unet model
# inputs → encoder (4 levels) → bottleneck → decoder (4 levels) → sigmoid mask

def build_unet(input_shape=(256, 256, 1)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D()(c1)

    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D()(c2)

    c3 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(64, 3, activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D()(c3)

    c4 = layers.Conv2D(128, 3, activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(128, 3, activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D()(c4)

    # Bottleneck (16x16 spatial resolution)
    b1 = layers.Conv2D(256, 3, activation='relu', padding='same')(p4)
    b1 = layers.Conv2D(256, 3, activation='relu', padding='same')(b1)

    # Decoder
    u4 = layers.UpSampling2D()(b1)
    u4 = layers.concatenate([u4, c4])
    d4 = layers.Conv2D(128, 3, activation='relu', padding='same')(u4)
    d4 = layers.Conv2D(128, 3, activation='relu', padding='same')(d4)

    u3 = layers.UpSampling2D()(d4)
    u3 = layers.concatenate([u3, c3])
    d3 = layers.Conv2D(64, 3, activation='relu', padding='same')(u3)
    d3 = layers.Conv2D(64, 3, activation='relu', padding='same')(d3)

    u2 = layers.UpSampling2D()(d3)
    u2 = layers.concatenate([u2, c2])
    d2 = layers.Conv2D(32, 3, activation='relu', padding='same')(u2)
    d2 = layers.Conv2D(32, 3, activation='relu', padding='same')(d2)

    u1 = layers.UpSampling2D()(d2)
    u1 = layers.concatenate([u1, c1])
    d1 = layers.Conv2D(16, 3, activation='relu', padding='same')(u1)
    d1 = layers.Conv2D(16, 3, activation='relu', padding='same')(d1)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(d1)

    return models.Model(inputs, outputs, name="bubble_unet4")

# %%
def dice_loss(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) /
                (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth))

def weighted_bce(y_true, y_pred):
    y_pred = tf.clip_by_value(
        y_pred,
        tf.keras.backend.epsilon(),
        1 - tf.keras.backend.epsilon()
    )

    weights = y_true * POSITIVE_CLASS_WEIGHT + 1
    bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)

    return tf.reduce_mean(weights * bce)

def combined_loss(y_true, y_pred):
    return weighted_bce(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def iou_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss,
    metrics=[dice_coef, iou_coef]
)
model.summary()
# Out:
# Model: "bubble_unet4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        160 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      2,320 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      9,248 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │     36,928 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    147,584 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │    295,168 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │    590,080 │ conv2d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ conv2d_9[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 384)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │    442,496 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    147,584 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ conv2d_11[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    110,656 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │     36,928 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ conv2d_13[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     27,680 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │      9,248 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ conv2d_15[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 48)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │      6,928 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      2,320 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         17 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,962,337 (7.49 MB)
#  Trainable params: 1,962,337 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# checkpoint the best epoch, stop when validation stalls, lower LR on plateau

BEST_WEIGHTS_PATH = os.path.join(MODEL_DIR, f"{ACTIVE_STAGE}bubble_unet_best.weights.h5")
HISTORY_CSV_PATH = os.path.join(OUTPUT_DIR, f"{ACTIVE_STAGE}training_history.csv")

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(BEST_WEIGHTS_PATH),
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1,
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        verbose=1,
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        mode="min",
        factor=0.5,
        patience=6,
        min_lr=1e-6,
        verbose=1,
    ),
    tf.keras.callbacks.CSVLogger(str(HISTORY_CSV_PATH)),
]

# %%
history = model.fit(
    X_train,
    Y_train,
    validation_data=(X_val, Y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    shuffle=True,
    callbacks=callbacks
)

# all later evaluation must use the best checkpointed epoch, not the last one
model.load_weights(BEST_WEIGHTS_PATH)
# Out:
# Epoch 1/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - dice_coef: 0.1412 - iou_coef: 0.0774 - loss: 1.5938
# Epoch 1: val_dice_coef improved from None to 0.16515, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 1: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 43s 370ms/step - dice_coef: 0.1373 - iou_coef: 0.0748 - loss: 1.5500 - val_dice_coef: 0.1651 - val_iou_coef: 0.0904 - val_loss: 1.5253 - learning_rate: 1.0000e-04
# Epoch 2/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - dice_coef: 0.1580 - iou_coef: 0.0869 - loss: 1.4581
# Epoch 2: val_dice_coef improved from 0.16515 to 0.19512, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 2: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 41s 380ms/step - dice_coef: 0.1607 - iou_coef: 0.0885 - loss: 1.4438 - val_dice_coef: 0.1951 - val_iou_coef: 0.1088 - val_loss: 1.4480 - learning_rate: 1.0000e-04
# Epoch 3/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - dice_coef: 0.1644 - iou_coef: 0.0908 - loss: 1.4418
# Epoch 3: val_dice_coef improved from 0.19512 to 0.19619, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 3: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 356ms/step - dice_coef: 0.1636 - iou_coef: 0.0903 - loss: 1.4330 - val_dice_coef: 0.1962 - val_iou_coef: 0.1095 - val_loss: 1.4440 - learning_rate: 1.0000e-04
# Epoch 4/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - dice_coef: 0.1652 - iou_coef: 0.0912 - loss: 1.4390
# Epoch 4: val_dice_coef improved from 0.19619 to 0.19706, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 4: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 351ms/step - dice_coef: 0.1641 - iou_coef: 0.0906 - loss: 1.4301 - val_dice_coef: 0.1971 - val_iou_coef: 0.1101 - val_loss: 1.4411 - learning_rate: 1.0000e-04
# Epoch 5/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - dice_coef: 0.1659 - iou_coef: 0.0917 - loss: 1.4359
# Epoch 5: val_dice_coef did not improve from 0.19706
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 347ms/step - dice_coef: 0.1644 - iou_coef: 0.0908 - loss: 1.4278 - val_dice_coef: 0.1958 - val_iou_coef: 0.1092 - val_loss: 1.4437 - learning_rate: 1.0000e-04
# Epoch 6/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - dice_coef: 0.1661 - iou_coef: 0.0918 - loss: 1.4335
# Epoch 6: val_dice_coef did not improve from 0.19706
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 344ms/step - dice_coef: 0.1649 - iou_coef: 0.0911 - loss: 1.4260 - val_dice_coef: 0.1970 - val_iou_coef: 0.1100 - val_loss: 1.4406 - learning_rate: 1.0000e-04
# Epoch 7/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - dice_coef: 0.1667 - iou_coef: 0.0922 - loss: 1.4321
# Epoch 7: val_dice_coef improved from 0.19706 to 0.19749, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 7: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 345ms/step - dice_coef: 0.1652 - iou_coef: 0.0913 - loss: 1.4247 - val_dice_coef: 0.1975 - val_iou_coef: 0.1103 - val_loss: 1.4392 - learning_rate: 1.0000e-04
# Epoch 8/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - dice_coef: 0.1670 - iou_coef: 0.0924 - loss: 1.4308
# Epoch 8: val_dice_coef improved from 0.19749 to 0.19867, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 8: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 352ms/step - dice_coef: 0.1656 - iou_coef: 0.0915 - loss: 1.4237 - val_dice_coef: 0.1987 - val_iou_coef: 0.1111 - val_loss: 1.4359 - learning_rate: 1.0000e-04
# Epoch 9/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - dice_coef: 0.1674 - iou_coef: 0.0926 - loss: 1.4298
# Epoch 9: val_dice_coef did not improve from 0.19867
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 352ms/step - dice_coef: 0.1659 - iou_coef: 0.0917 - loss: 1.4228 - val_dice_coef: 0.1983 - val_iou_coef: 0.1108 - val_loss: 1.4361 - learning_rate: 1.0000e-04
# Epoch 10/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - dice_coef: 0.1678 - iou_coef: 0.0928 - loss: 1.4284
# Epoch 10: val_dice_coef did not improve from 0.19867
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 355ms/step - dice_coef: 0.1668 - iou_coef: 0.0922 - loss: 1.4216 - val_dice_coef: 0.1967 - val_iou_coef: 0.1098 - val_loss: 1.4375 - learning_rate: 1.0000e-04
# Epoch 11/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - dice_coef: 0.1692 - iou_coef: 0.0936 - loss: 1.4251
# Epoch 11: val_dice_coef improved from 0.19867 to 0.19985, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 11: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 337ms/step - dice_coef: 0.1685 - iou_coef: 0.0932 - loss: 1.4177 - val_dice_coef: 0.1999 - val_iou_coef: 0.1118 - val_loss: 1.4291 - learning_rate: 1.0000e-04
# Epoch 12/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - dice_coef: 0.1730 - iou_coef: 0.0960 - loss: 1.4199
# Epoch 12: val_dice_coef improved from 0.19985 to 0.20154, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 12: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 337ms/step - dice_coef: 0.1703 - iou_coef: 0.0943 - loss: 1.4222 - val_dice_coef: 0.2015 - val_iou_coef: 0.1128 - val_loss: 1.4275 - learning_rate: 1.0000e-04
# Epoch 13/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - dice_coef: 0.1732 - iou_coef: 0.0961 - loss: 1.4149
# Epoch 13: val_dice_coef improved from 0.20154 to 0.21155, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 13: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 343ms/step - dice_coef: 0.1747 - iou_coef: 0.0970 - loss: 1.4030 - val_dice_coef: 0.2116 - val_iou_coef: 0.1189 - val_loss: 1.4179 - learning_rate: 1.0000e-04
# Epoch 14/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - dice_coef: 0.1864 - iou_coef: 0.1042 - loss: 1.3906
# Epoch 14: val_dice_coef improved from 0.21155 to 0.22529, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 14: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 328ms/step - dice_coef: 0.1889 - iou_coef: 0.1058 - loss: 1.3769 - val_dice_coef: 0.2253 - val_iou_coef: 0.1279 - val_loss: 1.4137 - learning_rate: 1.0000e-04
# Epoch 15/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - dice_coef: 0.2009 - iou_coef: 0.1133 - loss: 1.3687
# Epoch 15: val_dice_coef improved from 0.22529 to 0.26072, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 15: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 40s 367ms/step - dice_coef: 0.2066 - iou_coef: 0.1169 - loss: 1.3474 - val_dice_coef: 0.2607 - val_iou_coef: 0.1510 - val_loss: 1.3594 - learning_rate: 1.0000e-04
# Epoch 16/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - dice_coef: 0.2177 - iou_coef: 0.1243 - loss: 1.3527
# Epoch 16: val_dice_coef improved from 0.26072 to 0.29015, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 16: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 348ms/step - dice_coef: 0.2253 - iou_coef: 0.1291 - loss: 1.3246 - val_dice_coef: 0.2901 - val_iou_coef: 0.1709 - val_loss: 1.3022 - learning_rate: 1.0000e-04
# Epoch 17/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - dice_coef: 0.2475 - iou_coef: 0.1441 - loss: 1.3069
# Epoch 17: val_dice_coef improved from 0.29015 to 0.30273, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 17: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 40s 370ms/step - dice_coef: 0.2468 - iou_coef: 0.1435 - loss: 1.2949 - val_dice_coef: 0.3027 - val_iou_coef: 0.1796 - val_loss: 1.3026 - learning_rate: 1.0000e-04
# Epoch 18/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - dice_coef: 0.2592 - iou_coef: 0.1521 - loss: 1.2830
# Epoch 18: val_dice_coef did not improve from 0.30273
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 39s 357ms/step - dice_coef: 0.2613 - iou_coef: 0.1533 - loss: 1.2682 - val_dice_coef: 0.2851 - val_iou_coef: 0.1669 - val_loss: 1.3657 - learning_rate: 1.0000e-04
# Epoch 19/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - dice_coef: 0.2708 - iou_coef: 0.1598 - loss: 1.2628
# Epoch 19: val_dice_coef improved from 0.30273 to 0.31600, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 19: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 39s 359ms/step - dice_coef: 0.2741 - iou_coef: 0.1619 - loss: 1.2440 - val_dice_coef: 0.3160 - val_iou_coef: 0.1884 - val_loss: 1.2931 - learning_rate: 1.0000e-04
# Epoch 20/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - dice_coef: 0.2853 - iou_coef: 0.1699 - loss: 1.2370
# Epoch 20: val_dice_coef improved from 0.31600 to 0.33181, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 20: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 342ms/step - dice_coef: 0.2856 - iou_coef: 0.1700 - loss: 1.2246 - val_dice_coef: 0.3318 - val_iou_coef: 0.1996 - val_loss: 1.2687 - learning_rate: 1.0000e-04
# Epoch 21/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - dice_coef: 0.3015 - iou_coef: 0.1814 - loss: 1.2076
# Epoch 21: val_dice_coef improved from 0.33181 to 0.34231, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 21: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 339ms/step - dice_coef: 0.3026 - iou_coef: 0.1822 - loss: 1.1954 - val_dice_coef: 0.3423 - val_iou_coef: 0.2073 - val_loss: 1.2346 - learning_rate: 1.0000e-04
# Epoch 22/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - dice_coef: 0.3128 - iou_coef: 0.1895 - loss: 1.1887
# Epoch 22: val_dice_coef improved from 0.34231 to 0.38070, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 22: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 336ms/step - dice_coef: 0.3209 - iou_coef: 0.1954 - loss: 1.1633 - val_dice_coef: 0.3807 - val_iou_coef: 0.2362 - val_loss: 1.2494 - learning_rate: 1.0000e-04
# Epoch 23/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - dice_coef: 0.3333 - iou_coef: 0.2046 - loss: 1.1525
# Epoch 23: val_dice_coef improved from 0.38070 to 0.39701, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 23: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 343ms/step - dice_coef: 0.3412 - iou_coef: 0.2105 - loss: 1.1282 - val_dice_coef: 0.3970 - val_iou_coef: 0.2490 - val_loss: 1.2725 - learning_rate: 1.0000e-04
# Epoch 24/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - dice_coef: 0.3572 - iou_coef: 0.2222 - loss: 1.1129
# Epoch 24: val_dice_coef did not improve from 0.39701
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 334ms/step - dice_coef: 0.3619 - iou_coef: 0.2259 - loss: 1.0922 - val_dice_coef: 0.3948 - val_iou_coef: 0.2472 - val_loss: 1.2619 - learning_rate: 1.0000e-04
# Epoch 25/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - dice_coef: 0.3801 - iou_coef: 0.2395 - loss: 1.0754
# Epoch 25: val_dice_coef improved from 0.39701 to 0.40231, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 25: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 336ms/step - dice_coef: 0.3859 - iou_coef: 0.2446 - loss: 1.0540 - val_dice_coef: 0.4023 - val_iou_coef: 0.2536 - val_loss: 1.2689 - learning_rate: 1.0000e-04
# Epoch 26/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - dice_coef: 0.3935 - iou_coef: 0.2502 - loss: 1.0617
# Epoch 26: val_dice_coef improved from 0.40231 to 0.43833, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 26: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 40s 375ms/step - dice_coef: 0.4029 - iou_coef: 0.2583 - loss: 1.0292 - val_dice_coef: 0.4383 - val_iou_coef: 0.2823 - val_loss: 1.2149 - learning_rate: 1.0000e-04
# Epoch 27/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - dice_coef: 0.4096 - iou_coef: 0.2637 - loss: 1.0426
# Epoch 27: val_dice_coef did not improve from 0.43833
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 344ms/step - dice_coef: 0.4208 - iou_coef: 0.2735 - loss: 1.0009 - val_dice_coef: 0.4270 - val_iou_coef: 0.2732 - val_loss: 1.2523 - learning_rate: 1.0000e-04
# Epoch 28/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - dice_coef: 0.4436 - iou_coef: 0.2919 - loss: 0.9705
# Epoch 28: val_dice_coef improved from 0.43833 to 0.46105, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 28: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 331ms/step - dice_coef: 0.4409 - iou_coef: 0.2900 - loss: 0.9667 - val_dice_coef: 0.4611 - val_iou_coef: 0.3024 - val_loss: 1.1009 - learning_rate: 1.0000e-04
# Epoch 29/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - dice_coef: 0.4834 - iou_coef: 0.3273 - loss: 0.8968
# Epoch 29: val_dice_coef improved from 0.46105 to 0.46430, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 29: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 331ms/step - dice_coef: 0.4895 - iou_coef: 0.3330 - loss: 0.8854 - val_dice_coef: 0.4643 - val_iou_coef: 0.3040 - val_loss: 1.2807 - learning_rate: 1.0000e-04
# Epoch 30/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - dice_coef: 0.5268 - iou_coef: 0.3667 - loss: 0.8359
# Epoch 30: val_dice_coef improved from 0.46430 to 0.53713, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 30: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 343ms/step - dice_coef: 0.5416 - iou_coef: 0.3807 - loss: 0.7953 - val_dice_coef: 0.5371 - val_iou_coef: 0.3712 - val_loss: 1.1005 - learning_rate: 1.0000e-04
# Epoch 31/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - dice_coef: 0.5814 - iou_coef: 0.4209 - loss: 0.7403
# Epoch 31: val_dice_coef improved from 0.53713 to 0.53977, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 31: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 349ms/step - dice_coef: 0.5925 - iou_coef: 0.4312 - loss: 0.7124 - val_dice_coef: 0.5398 - val_iou_coef: 0.3732 - val_loss: 1.1473 - learning_rate: 1.0000e-04
# Epoch 32/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - dice_coef: 0.6117 - iou_coef: 0.4526 - loss: 0.6943
# Epoch 32: val_dice_coef did not improve from 0.53977
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 348ms/step - dice_coef: 0.6055 - iou_coef: 0.4460 - loss: 0.6941 - val_dice_coef: 0.5202 - val_iou_coef: 0.3544 - val_loss: 1.2391 - learning_rate: 1.0000e-04
# Epoch 33/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - dice_coef: 0.6404 - iou_coef: 0.4809 - loss: 0.6505
# Epoch 33: val_dice_coef improved from 0.53977 to 0.55257, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 33: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 337ms/step - dice_coef: 0.6533 - iou_coef: 0.4951 - loss: 0.6130 - val_dice_coef: 0.5526 - val_iou_coef: 0.3881 - val_loss: 1.1767 - learning_rate: 1.0000e-04
# Epoch 34/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - dice_coef: 0.6892 - iou_coef: 0.5356 - loss: 0.5634
# Epoch 34: val_dice_coef improved from 0.55257 to 0.63590, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 34: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 342ms/step - dice_coef: 0.6858 - iou_coef: 0.5319 - loss: 0.5597 - val_dice_coef: 0.6359 - val_iou_coef: 0.4719 - val_loss: 0.8772 - learning_rate: 1.0000e-04
# Epoch 35/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - dice_coef: 0.7052 - iou_coef: 0.5547 - loss: 0.5316
# Epoch 35: val_dice_coef did not improve from 0.63590
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 40s 369ms/step - dice_coef: 0.7063 - iou_coef: 0.5558 - loss: 0.5251 - val_dice_coef: 0.5692 - val_iou_coef: 0.4050 - val_loss: 1.1628 - learning_rate: 1.0000e-04
# Epoch 36/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - dice_coef: 0.7513 - iou_coef: 0.6086 - loss: 0.4498
# Epoch 36: val_dice_coef did not improve from 0.63590
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 39s 358ms/step - dice_coef: 0.7532 - iou_coef: 0.6123 - loss: 0.4407 - val_dice_coef: 0.5493 - val_iou_coef: 0.3887 - val_loss: 1.3700 - learning_rate: 1.0000e-04
# Epoch 37/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - dice_coef: 0.7915 - iou_coef: 0.6602 - loss: 0.3839
# Epoch 37: val_dice_coef did not improve from 0.63590
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 344ms/step - dice_coef: 0.7821 - iou_coef: 0.6495 - loss: 0.3906 - val_dice_coef: 0.5784 - val_iou_coef: 0.4150 - val_loss: 1.3103 - learning_rate: 1.0000e-04
# Epoch 38/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - dice_coef: 0.7885 - iou_coef: 0.6567 - loss: 0.3982
# Epoch 38: val_dice_coef improved from 0.63590 to 0.66319, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 38: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 333ms/step - dice_coef: 0.7845 - iou_coef: 0.6523 - loss: 0.3905 - val_dice_coef: 0.6632 - val_iou_coef: 0.5070 - val_loss: 0.9343 - learning_rate: 1.0000e-04
# Epoch 39/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - dice_coef: 0.7767 - iou_coef: 0.6425 - loss: 0.4203
# Epoch 39: val_dice_coef did not improve from 0.66319
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 340ms/step - dice_coef: 0.7718 - iou_coef: 0.6360 - loss: 0.4180 - val_dice_coef: 0.6313 - val_iou_coef: 0.4735 - val_loss: 1.0486 - learning_rate: 1.0000e-04
# Epoch 40/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - dice_coef: 0.8045 - iou_coef: 0.6792 - loss: 0.3532
# Epoch 40: val_dice_coef did not improve from 0.66319
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 353ms/step - dice_coef: 0.7867 - iou_coef: 0.6577 - loss: 0.3813 - val_dice_coef: 0.6128 - val_iou_coef: 0.4525 - val_loss: 1.1256 - learning_rate: 1.0000e-04
# Epoch 41/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - dice_coef: 0.8051 - iou_coef: 0.6786 - loss: 0.3605
# Epoch 41: val_dice_coef improved from 0.66319 to 0.74546, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 41: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 39s 360ms/step - dice_coef: 0.8250 - iou_coef: 0.7065 - loss: 0.3145 - val_dice_coef: 0.7455 - val_iou_coef: 0.6036 - val_loss: 0.6600 - learning_rate: 5.0000e-05
# Epoch 42/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - dice_coef: 0.8527 - iou_coef: 0.7470 - loss: 0.2617
# Epoch 42: val_dice_coef improved from 0.74546 to 0.74804, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 42: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 39s 357ms/step - dice_coef: 0.8635 - iou_coef: 0.7626 - loss: 0.2448 - val_dice_coef: 0.7480 - val_iou_coef: 0.6087 - val_loss: 0.7187 - learning_rate: 5.0000e-05
# Epoch 43/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - dice_coef: 0.8809 - iou_coef: 0.7897 - loss: 0.2105
# Epoch 43: val_dice_coef improved from 0.74804 to 0.74806, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 43: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 350ms/step - dice_coef: 0.8865 - iou_coef: 0.7980 - loss: 0.2039 - val_dice_coef: 0.7481 - val_iou_coef: 0.6095 - val_loss: 0.7584 - learning_rate: 5.0000e-05
# Epoch 44/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - dice_coef: 0.8963 - iou_coef: 0.8142 - loss: 0.1834
# Epoch 44: val_dice_coef improved from 0.74806 to 0.76272, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 44: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 353ms/step - dice_coef: 0.9009 - iou_coef: 0.8212 - loss: 0.1785 - val_dice_coef: 0.7627 - val_iou_coef: 0.6270 - val_loss: 0.7316 - learning_rate: 5.0000e-05
# Epoch 45/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - dice_coef: 0.9074 - iou_coef: 0.8322 - loss: 0.1649
# Epoch 45: val_dice_coef did not improve from 0.76272
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 336ms/step - dice_coef: 0.9108 - iou_coef: 0.8376 - loss: 0.1609 - val_dice_coef: 0.7547 - val_iou_coef: 0.6174 - val_loss: 0.7958 - learning_rate: 5.0000e-05
# Epoch 46/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - dice_coef: 0.9173 - iou_coef: 0.8485 - loss: 0.1469
# Epoch 46: val_dice_coef did not improve from 0.76272
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 321ms/step - dice_coef: 0.9203 - iou_coef: 0.8534 - loss: 0.1435 - val_dice_coef: 0.7551 - val_iou_coef: 0.6180 - val_loss: 0.8264 - learning_rate: 5.0000e-05
# Epoch 47/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - dice_coef: 0.9260 - iou_coef: 0.8633 - loss: 0.1315
# Epoch 47: val_dice_coef improved from 0.76272 to 0.77633, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 47: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 353ms/step - dice_coef: 0.9275 - iou_coef: 0.8656 - loss: 0.1294 - val_dice_coef: 0.7763 - val_iou_coef: 0.6436 - val_loss: 0.7367 - learning_rate: 5.0000e-05
# Epoch 48/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - dice_coef: 0.9274 - iou_coef: 0.8656 - loss: 0.1286
# Epoch 48: val_dice_coef did not improve from 0.77633
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 351ms/step - dice_coef: 0.9279 - iou_coef: 0.8665 - loss: 0.1279 - val_dice_coef: 0.7435 - val_iou_coef: 0.6028 - val_loss: 0.9250 - learning_rate: 2.5000e-05
# Epoch 49/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - dice_coef: 0.9323 - iou_coef: 0.8742 - loss: 0.1200
# Epoch 49: val_dice_coef did not improve from 0.77633
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 41s 379ms/step - dice_coef: 0.9335 - iou_coef: 0.8761 - loss: 0.1174 - val_dice_coef: 0.7487 - val_iou_coef: 0.6087 - val_loss: 0.9161 - learning_rate: 2.5000e-05
# Epoch 50/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - dice_coef: 0.9360 - iou_coef: 0.8805 - loss: 0.1146
# Epoch 50: val_dice_coef did not improve from 0.77633
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 328ms/step - dice_coef: 0.9380 - iou_coef: 0.8837 - loss: 0.1099 - val_dice_coef: 0.7620 - val_iou_coef: 0.6257 - val_loss: 0.8715 - learning_rate: 2.5000e-05
# Epoch 51/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - dice_coef: 0.9391 - iou_coef: 0.8859 - loss: 0.1093
# Epoch 51: val_dice_coef improved from 0.77633 to 0.77924, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 51: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 339ms/step - dice_coef: 0.9407 - iou_coef: 0.8886 - loss: 0.1048 - val_dice_coef: 0.7792 - val_iou_coef: 0.6475 - val_loss: 0.8000 - learning_rate: 2.5000e-05
# Epoch 52/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - dice_coef: 0.9397 - iou_coef: 0.8870 - loss: 0.1083
# Epoch 52: val_dice_coef improved from 0.77924 to 0.78212, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 52: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 327ms/step - dice_coef: 0.9423 - iou_coef: 0.8914 - loss: 0.1018 - val_dice_coef: 0.7821 - val_iou_coef: 0.6509 - val_loss: 0.7798 - learning_rate: 2.5000e-05
# Epoch 53/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - dice_coef: 0.9416 - iou_coef: 0.8903 - loss: 0.1048
# Epoch 53: val_dice_coef improved from 0.78212 to 0.78570, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 53: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 337ms/step - dice_coef: 0.9442 - iou_coef: 0.8947 - loss: 0.0982 - val_dice_coef: 0.7857 - val_iou_coef: 0.6549 - val_loss: 0.7323 - learning_rate: 2.5000e-05
# Epoch 54/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - dice_coef: 0.9342 - iou_coef: 0.8772 - loss: 0.1188
# Epoch 54: val_dice_coef did not improve from 0.78570
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 353ms/step - dice_coef: 0.9384 - iou_coef: 0.8846 - loss: 0.1099 - val_dice_coef: 0.7848 - val_iou_coef: 0.6539 - val_loss: 0.7008 - learning_rate: 1.2500e-05
# Epoch 55/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - dice_coef: 0.9363 - iou_coef: 0.8810 - loss: 0.1107
# Epoch 55: val_dice_coef improved from 0.78570 to 0.78850, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 55: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 335ms/step - dice_coef: 0.9428 - iou_coef: 0.8925 - loss: 0.0999 - val_dice_coef: 0.7885 - val_iou_coef: 0.6593 - val_loss: 0.7283 - learning_rate: 1.2500e-05
# Epoch 56/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - dice_coef: 0.9443 - iou_coef: 0.8950 - loss: 0.0960
# Epoch 56: val_dice_coef did not improve from 0.78850
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 342ms/step - dice_coef: 0.9490 - iou_coef: 0.9033 - loss: 0.0882 - val_dice_coef: 0.7877 - val_iou_coef: 0.6582 - val_loss: 0.7676 - learning_rate: 1.2500e-05
# Epoch 57/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - dice_coef: 0.9500 - iou_coef: 0.9051 - loss: 0.0863
# Epoch 57: val_dice_coef improved from 0.78850 to 0.78963, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 57: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 344ms/step - dice_coef: 0.9533 - iou_coef: 0.9111 - loss: 0.0805 - val_dice_coef: 0.7896 - val_iou_coef: 0.6608 - val_loss: 0.7815 - learning_rate: 1.2500e-05
# Epoch 58/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - dice_coef: 0.9533 - iou_coef: 0.9112 - loss: 0.0808
# Epoch 58: val_dice_coef improved from 0.78963 to 0.78977, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 58: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 41s 376ms/step - dice_coef: 0.9562 - iou_coef: 0.9163 - loss: 0.0756 - val_dice_coef: 0.7898 - val_iou_coef: 0.6610 - val_loss: 0.8051 - learning_rate: 1.2500e-05
# Epoch 59/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - dice_coef: 0.9559 - iou_coef: 0.9157 - loss: 0.0768
# Epoch 59: val_dice_coef improved from 0.78977 to 0.79171, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 59: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 330ms/step - dice_coef: 0.9584 - iou_coef: 0.9203 - loss: 0.0719 - val_dice_coef: 0.7917 - val_iou_coef: 0.6636 - val_loss: 0.8126 - learning_rate: 1.2500e-05
# Epoch 60/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - dice_coef: 0.9568 - iou_coef: 0.9174 - loss: 0.0753
# Epoch 60: val_dice_coef improved from 0.79171 to 0.79262, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 60: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 343ms/step - dice_coef: 0.9588 - iou_coef: 0.9211 - loss: 0.0714 - val_dice_coef: 0.7926 - val_iou_coef: 0.6653 - val_loss: 0.8035 - learning_rate: 6.2500e-06
# Epoch 61/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - dice_coef: 0.9575 - iou_coef: 0.9186 - loss: 0.0740
# Epoch 61: val_dice_coef improved from 0.79262 to 0.79366, saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
#
# Epoch 61: finished saving model to ../outputs/models/stage00bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 333ms/step - dice_coef: 0.9600 - iou_coef: 0.9232 - loss: 0.0693 - val_dice_coef: 0.7937 - val_iou_coef: 0.6666 - val_loss: 0.8047 - learning_rate: 6.2500e-06
# Epoch 62/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - dice_coef: 0.9584 - iou_coef: 0.9204 - loss: 0.0723
# Epoch 62: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 36s 331ms/step - dice_coef: 0.9611 - iou_coef: 0.9253 - loss: 0.0674 - val_dice_coef: 0.7933 - val_iou_coef: 0.6661 - val_loss: 0.8179 - learning_rate: 6.2500e-06
# Epoch 63/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - dice_coef: 0.9596 - iou_coef: 0.9225 - loss: 0.0703
# Epoch 63: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 326ms/step - dice_coef: 0.9621 - iou_coef: 0.9272 - loss: 0.0656 - val_dice_coef: 0.7935 - val_iou_coef: 0.6663 - val_loss: 0.8271 - learning_rate: 6.2500e-06
# Epoch 64/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - dice_coef: 0.9606 - iou_coef: 0.9244 - loss: 0.0686
# Epoch 64: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 343ms/step - dice_coef: 0.9631 - iou_coef: 0.9289 - loss: 0.0640 - val_dice_coef: 0.7932 - val_iou_coef: 0.6658 - val_loss: 0.8409 - learning_rate: 6.2500e-06
# Epoch 65/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - dice_coef: 0.9617 - iou_coef: 0.9263 - loss: 0.0669
# Epoch 65: val_dice_coef did not improve from 0.79366
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 35s 328ms/step - dice_coef: 0.9640 - iou_coef: 0.9306 - loss: 0.0624 - val_dice_coef: 0.7934 - val_iou_coef: 0.6662 - val_loss: 0.8497 - learning_rate: 6.2500e-06
# Epoch 66/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - dice_coef: 0.9620 - iou_coef: 0.9270 - loss: 0.0661
# Epoch 66: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 354ms/step - dice_coef: 0.9641 - iou_coef: 0.9308 - loss: 0.0621 - val_dice_coef: 0.7897 - val_iou_coef: 0.6614 - val_loss: 0.8855 - learning_rate: 3.1250e-06
# Epoch 67/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - dice_coef: 0.9626 - iou_coef: 0.9282 - loss: 0.0652
# Epoch 67: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 344ms/step - dice_coef: 0.9648 - iou_coef: 0.9320 - loss: 0.0610 - val_dice_coef: 0.7882 - val_iou_coef: 0.6592 - val_loss: 0.9011 - learning_rate: 3.1250e-06
# Epoch 68/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - dice_coef: 0.9634 - iou_coef: 0.9295 - loss: 0.0641
# Epoch 68: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 356ms/step - dice_coef: 0.9654 - iou_coef: 0.9332 - loss: 0.0599 - val_dice_coef: 0.7884 - val_iou_coef: 0.6595 - val_loss: 0.9043 - learning_rate: 3.1250e-06
# Epoch 69/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - dice_coef: 0.9640 - iou_coef: 0.9307 - loss: 0.0630
# Epoch 69: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 344ms/step - dice_coef: 0.9659 - iou_coef: 0.9342 - loss: 0.0589 - val_dice_coef: 0.7883 - val_iou_coef: 0.6594 - val_loss: 0.9101 - learning_rate: 3.1250e-06
# Epoch 70/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - dice_coef: 0.9645 - iou_coef: 0.9317 - loss: 0.0621
# Epoch 70: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 39s 362ms/step - dice_coef: 0.9664 - iou_coef: 0.9352 - loss: 0.0581 - val_dice_coef: 0.7886 - val_iou_coef: 0.6598 - val_loss: 0.9132 - learning_rate: 3.1250e-06
# Epoch 71/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - dice_coef: 0.9650 - iou_coef: 0.9326 - loss: 0.0613
# Epoch 71: val_dice_coef did not improve from 0.79366
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 349ms/step - dice_coef: 0.9669 - iou_coef: 0.9360 - loss: 0.0573 - val_dice_coef: 0.7888 - val_iou_coef: 0.6600 - val_loss: 0.9176 - learning_rate: 3.1250e-06
# Epoch 72/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - dice_coef: 0.9653 - iou_coef: 0.9331 - loss: 0.0609
# Epoch 72: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 353ms/step - dice_coef: 0.9670 - iou_coef: 0.9363 - loss: 0.0569 - val_dice_coef: 0.7882 - val_iou_coef: 0.6593 - val_loss: 0.9265 - learning_rate: 1.5625e-06
# Epoch 73/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - dice_coef: 0.9658 - iou_coef: 0.9340 - loss: 0.0604
# Epoch 73: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 42s 386ms/step - dice_coef: 0.9674 - iou_coef: 0.9370 - loss: 0.0564 - val_dice_coef: 0.7885 - val_iou_coef: 0.6597 - val_loss: 0.9277 - learning_rate: 1.5625e-06
# Epoch 74/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - dice_coef: 0.9661 - iou_coef: 0.9345 - loss: 0.0598
# Epoch 74: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 39s 357ms/step - dice_coef: 0.9677 - iou_coef: 0.9375 - loss: 0.0559 - val_dice_coef: 0.7887 - val_iou_coef: 0.6600 - val_loss: 0.9290 - learning_rate: 1.5625e-06
# Epoch 75/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - dice_coef: 0.9664 - iou_coef: 0.9351 - loss: 0.0593
# Epoch 75: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 338ms/step - dice_coef: 0.9680 - iou_coef: 0.9380 - loss: 0.0554 - val_dice_coef: 0.7890 - val_iou_coef: 0.6603 - val_loss: 0.9304 - learning_rate: 1.5625e-06
# Epoch 76/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - dice_coef: 0.9666 - iou_coef: 0.9355 - loss: 0.0588
# Epoch 76: val_dice_coef did not improve from 0.79366
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 38s 355ms/step - dice_coef: 0.9682 - iou_coef: 0.9385 - loss: 0.0550 - val_dice_coef: 0.7892 - val_iou_coef: 0.6606 - val_loss: 0.9320 - learning_rate: 1.5625e-06
# Epoch 76: early stopping
# Restoring model weights from the end of the best epoch: 61.

# %%
# MODEL_PATH = MODEL_DIR / "bubble_unet.keras"
MODEL_PATH = os.path.join(MODEL_DIR, f"{ACTIVE_STAGE}bubble_unet.keras")
HISTORY_PATH = os.path.join(OUTPUT_DIR, f"{ACTIVE_STAGE}training_history.json")

model.save(MODEL_PATH)
serializable_history = {
    name: [float(value) for value in values]
    for name, values in history.history.items()
}
with HISTORY_PATH.open("w") as history_file:
    json.dump(serializable_history, history_file, indent=2)

print("Saved model to:", MODEL_PATH)
print("Saved training history to:", HISTORY_PATH)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 10
#       5 model.save(MODEL_PATH)
#       6 serializable_history = {
#       7     name: [float(value) for value in values]
#       8     for name, values in history.history.items()
#       9 }
# ---> 10 with HISTORY_PATH.open("w") as history_file:
#      11     json.dump(serializable_history, history_file, indent=2)
#      13 print("Saved model to:", MODEL_PATH)
#
# AttributeError: 'str' object has no attribute 'open'

# %%
# for previously trained model

if model is None:
    model = tf.keras.models.load_model(MODEL_PATH, compile=False)

# %%
preds_val = model.predict(X_val)

print("Prediction min:", preds_val.min())
print("Prediction max:", preds_val.max())
print("Prediction mean:", preds_val.mean())
print("Ground truth foreground ratio:", Y_val.mean())

def dice_at_threshold(y_true, y_pred, threshold):
    y_pred_bin = (y_pred > threshold).astype(np.float32)
    intersection = np.sum(y_true * y_pred_bin)
    return (2 * intersection + 1) / (np.sum(y_true) + np.sum(y_pred_bin) + 1)

for t in np.arange(0.25, 0.50, 0.025):
    d = dice_at_threshold(Y_val, preds_val, t)
    fg = (preds_val > t).mean()
    print(f"Threshold {t:.3f} | Dice: {d:.4f} | Pred foreground: {fg:.4f}")
    
# for t in [0.2, 0.3, 0.4, 0.5]:
#     print(f"Foreground ratio at threshold {t}:", (preds_val > t).mean())

# %%
thresholds = np.arange(0.05, 0.951, 0.025)
threshold_results = []

for threshold in thresholds:
    dice = dice_at_threshold(Y_val, preds_val, threshold)
    foreground_ratio = float((preds_val > threshold).mean())
    threshold_results.append(
        (float(threshold), float(dice), foreground_ratio)
    )
    print(
        f"Threshold {threshold:.3f} | Dice: {dice:.4f} | "
        f"Pred foreground: {foreground_ratio:.4f}"
    )

best_threshold, best_dice, best_foreground_ratio = max(
    threshold_results,
    key=lambda result: result[1]
)

threshold_summary = {
    "best_threshold": best_threshold,
    "validation_dice": best_dice,
    "predicted_foreground_ratio": best_foreground_ratio,
    "ground_truth_foreground_ratio": float(Y_val.mean()),
}
# with (OUTPUT_DIR / "threshold_summary.json").open("w") as summary_file:
#     json.dump(threshold_summary, summary_file, indent=2)

print("\nBest validation threshold:", best_threshold)
print("Best validation Dice:", best_dice)
print("Best foreground ratio:", best_foreground_ratio)

# %%
for idx in [0, 10, 20]:
    image = X_val[idx].squeeze()
    ground_truth = Y_val[idx].squeeze() > 0.5
    probability = preds_val[idx].squeeze()
    prediction = probability > best_threshold

    tp = ground_truth & prediction
    fp = ~ground_truth & prediction
    fn = ground_truth & ~prediction

    tp_count = tp.sum()
    fp_count = fp.sum()
    fn_count = fn.sum()

    precision = tp_count / (tp_count + fp_count + 1e-8)
    recall = tp_count / (tp_count + fn_count + 1e-8)
    dice = (
        2 * tp_count /
        (2 * tp_count + fp_count + fn_count + 1e-8)
    )

    # 0 = correct background
    # 1 = true positive
    # 2 = false positive
    # 3 = false negative
    comparison = np.zeros(ground_truth.shape, dtype=np.uint8)
    comparison[tp] = 1
    comparison[fp] = 2
    comparison[fn] = 3

    comparison_cmap = ListedColormap([
        "black",       # correct background
        "limegreen",   # true positive
        "red",         # false positive
        "deepskyblue"  # false negative
    ])

    fig, axes = plt.subplots(1, 5, figsize=(21, 4))

    axes[0].imshow(image, cmap="gray")
    axes[0].set_title("Validation input\nF770W intensity")

    axes[1].imshow(
        ground_truth,
        cmap="gray",
        vmin=0,
        vmax=1
    )
    axes[1].set_title("Ground truth\nWhite = catalogue foreground")

    probability_plot = axes[2].imshow(
        probability,
        cmap="inferno",
        vmin=0,
        vmax=1
    )
    axes[2].set_title("Predicted probability")

    colorbar = fig.colorbar(
        probability_plot,
        ax=axes[2],
        fraction=0.046,
        pad=0.04
    )
    colorbar.set_label("Foreground probability")

    axes[3].imshow(
        prediction,
        cmap="gray",
        vmin=0,
        vmax=1
    )
    axes[3].set_title(
        f"Binary prediction\n"
        f"White = probability > {best_threshold:.2f}"
    )

    axes[4].imshow(
        comparison,
        cmap=comparison_cmap,
        vmin=0,
        vmax=3
    )
    axes[4].set_title(
        f"Prediction errors\n"
        f"Dice={dice:.3f}, P={precision:.3f}, R={recall:.3f}"
    )

    legend_items = [
        Patch(color="limegreen", label="True positive"),
        Patch(color="red", label="False positive"),
        Patch(color="deepskyblue", label="False negative"),
        Patch(color="black", label="Correct background")
    ]

    axes[4].legend(
        handles=legend_items,
        loc="lower center",
        bbox_to_anchor=(0.5, -0.35),
        ncol=2,
        frameon=False
    )

    for axis in axes:
        axis.axis("off")

    plt.tight_layout()
    plt.show()

# %%
# Loss curves
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOTS_DIR, "loss_curve.png"), dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['dice_coef'], label='Training Dice')
plt.plot(history.history['val_dice_coef'], label='Validation Dice')

plt.title('Dice Coefficient During Training')
plt.xlabel('Epoch')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig(os.path.join(PLOTS_DIR, "dice_curve.png"), dpi=300)
plt.show()
