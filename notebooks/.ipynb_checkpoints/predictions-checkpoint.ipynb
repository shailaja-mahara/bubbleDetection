# %%
# training rough model

import os
import json
from pathlib import Path

import numpy as np
from tensorflow.keras import layers, models
import tensorflow as tf
import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch

# %%
SEED = 42
EPOCHS = 10
BATCH_SIZE = 4

# POSITIVE_CLASS_WEIGHT = 0.5
# POSITIVE_CLASS_WEIGHT = 1.0
# POSITIVE_CLASS_WEIGHT = 1.5
POSITIVE_CLASS_WEIGHT = 2.0

EARLY_STOPPING_PATIENCE = 5

tf.keras.utils.set_random_seed(SEED)

DATA_DIR = Path("../data/processed/augmented")
FIGURE_DIR = '../outputs/figures'
MODEL_DIR = Path("../outputs/models")
OUTPUT_DIR = Path("../outputs")

os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(FIGURE_DIR, exist_ok=True)

X_train = np.load(DATA_DIR / "XtrainAug.npy").astype(np.float32)
X_val = np.load(DATA_DIR / "XVal.npy").astype(np.float32)
Y_train = np.load(DATA_DIR / "YtrainAug.npy").astype(np.float32)
Y_val = np.load(DATA_DIR / "YVal.npy").astype(np.float32)

print("X_train shape:", X_train.shape, "dtype:", X_train.dtype, "min/max:", X_train.min(), X_train.max())
print("X_val shape:", X_val.shape, "dtype:", X_val.dtype, "min/max:", X_val.min(), X_val.max())
print("Y_train shape:", Y_train.shape, "dtype:", Y_train.dtype, "min/max:", Y_train.min(), Y_train.max())
print("Y_val shape:", Y_val.shape, "dtype:", Y_val.dtype, "min/max:", Y_val.min(), Y_val.max())

print("Training foreground ratio:", float(Y_train.mean()))
print("Validation foreground ratio:", float(Y_val.mean()))
# Out:
# X_train shape: (432, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# X_val shape: (28, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_train shape: (432, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Y_val shape: (28, 256, 256, 1) dtype: float32 min/max: 0.0 1.0
# Training foreground ratio: 0.11102577298879623
# Validation foreground ratio: 0.08361434936523438

# %%
# simple unet model
# inputs → encoder → bottleneck → decoder → sigmoid mask

def build_unet(input_shape=(256, 256, 1)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D()(c1)

    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D()(c2)

    # Bottleneck
    b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
    b1 = layers.Conv2D(64, 3, activation='relu', padding='same')(b1)

    # Decoder
    u1 = layers.UpSampling2D()(b1)
    u1 = layers.concatenate([u1, c2])
    c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(u1)
    c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(c3)

    u2 = layers.UpSampling2D()(c3)
    u2 = layers.concatenate([u2, c1])
    c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(u2)
    c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(c4)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(c4)

    return models.Model(inputs, outputs, name="bubble_unet")

# %%
def dice_loss(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) /
                (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth))

def weighted_bce(y_true, y_pred):
    y_pred = tf.clip_by_value(
        y_pred,
        tf.keras.backend.epsilon(),
        1 - tf.keras.backend.epsilon()
    )

    weights = y_true * POSITIVE_CLASS_WEIGHT + 1
    bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)

    return tf.reduce_mean(weights * bce)

def combined_loss(y_true, y_pred):
    return weighted_bce(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def iou_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss,
    metrics=[dice_coef, iou_coef]
)
model.summary()
# Out:
# Model: "bubble_unet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 256, 256,  │        160 │ input_layer_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 256, 256,  │      2,320 │ conv2d_33[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 128, 128,  │          0 │ conv2d_34[0][0]   │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 128, 128,  │      4,640 │ max_pooling2d_6[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 128, 128,  │      9,248 │ conv2d_35[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 64, 64,    │          0 │ conv2d_36[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 64, 64,    │     18,496 │ max_pooling2d_7[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 64, 64,    │     36,928 │ conv2d_37[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 128, 128,  │          0 │ conv2d_38[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 128, 128,  │          0 │ up_sampling2d_6[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_36[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 128, 128,  │     27,680 │ concatenate_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 128, 128,  │      9,248 │ conv2d_39[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 256, 256,  │          0 │ conv2d_40[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 256, 256,  │          0 │ up_sampling2d_7[… │
# │ (Concatenate)       │ 48)               │            │ conv2d_34[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 256, 256,  │      6,928 │ concatenate_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 256, 256,  │      2,320 │ conv2d_41[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 256, 256,  │         17 │ conv2d_42[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 117,985 (460.88 KB)
#  Trainable params: 117,985 (460.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# checkpoint the best epoch, stop when validation stalls, lower LR on plateau

BEST_WEIGHTS_PATH = MODEL_DIR / "bubble_unet_best.weights.h5"
HISTORY_CSV_PATH = OUTPUT_DIR / "training_history.csv"

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(BEST_WEIGHTS_PATH),
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1,
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        verbose=1,
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        mode="min",
        factor=0.5,
        patience=6,
        min_lr=1e-6,
        verbose=1,
    ),
    tf.keras.callbacks.CSVLogger(str(HISTORY_CSV_PATH)),
]

# %%
history = model.fit(
    X_train,
    Y_train,
    validation_data=(X_val, Y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    shuffle=True,
    callbacks=callbacks
)

# all later evaluation must use the best checkpointed epoch, not the last one
model.load_weights(BEST_WEIGHTS_PATH)
# Out:
# Epoch 1/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - dice_coef: 0.1741 - iou_coef: 0.0972 - loss: 1.6215
# Epoch 1: val_dice_coef improved from None to 0.12093, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 1: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 228ms/step - dice_coef: 0.1590 - iou_coef: 0.0880 - loss: 1.5959 - val_dice_coef: 0.1209 - val_iou_coef: 0.0651 - val_loss: 1.5519 - learning_rate: 1.0000e-04
# Epoch 2/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - dice_coef: 0.1642 - iou_coef: 0.0908 - loss: 1.5751
# Epoch 2: val_dice_coef improved from 0.12093 to 0.15684, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 2: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 226ms/step - dice_coef: 0.1585 - iou_coef: 0.0875 - loss: 1.5525 - val_dice_coef: 0.1568 - val_iou_coef: 0.0862 - val_loss: 1.3888 - learning_rate: 1.0000e-04
# Epoch 3/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - dice_coef: 0.1736 - iou_coef: 0.0964 - loss: 1.5370
# Epoch 3: val_dice_coef improved from 0.15684 to 0.15927, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 3: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 212ms/step - dice_coef: 0.1671 - iou_coef: 0.0927 - loss: 1.5211 - val_dice_coef: 0.1593 - val_iou_coef: 0.0876 - val_loss: 1.3835 - learning_rate: 1.0000e-04
# Epoch 4/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - dice_coef: 0.1749 - iou_coef: 0.0972 - loss: 1.5334
# Epoch 4: val_dice_coef improved from 0.15927 to 0.16094, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 4: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice_coef: 0.1681 - iou_coef: 0.0932 - loss: 1.5179 - val_dice_coef: 0.1609 - val_iou_coef: 0.0886 - val_loss: 1.3797 - learning_rate: 1.0000e-04
# Epoch 5/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - dice_coef: 0.1756 - iou_coef: 0.0976 - loss: 1.5315
# Epoch 5: val_dice_coef improved from 0.16094 to 0.16183, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 5: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 217ms/step - dice_coef: 0.1686 - iou_coef: 0.0936 - loss: 1.5162 - val_dice_coef: 0.1618 - val_iou_coef: 0.0892 - val_loss: 1.3765 - learning_rate: 1.0000e-04
# Epoch 6/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - dice_coef: 0.1760 - iou_coef: 0.0978 - loss: 1.5304
# Epoch 6: val_dice_coef improved from 0.16183 to 0.16309, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 6: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 236ms/step - dice_coef: 0.1690 - iou_coef: 0.0938 - loss: 1.5152 - val_dice_coef: 0.1631 - val_iou_coef: 0.0899 - val_loss: 1.3743 - learning_rate: 1.0000e-04
# Epoch 7/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - dice_coef: 0.1764 - iou_coef: 0.0981 - loss: 1.5291
# Epoch 7: val_dice_coef did not improve from 0.16309
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - dice_coef: 0.1695 - iou_coef: 0.0941 - loss: 1.5139 - val_dice_coef: 0.1631 - val_iou_coef: 0.0899 - val_loss: 1.3726 - learning_rate: 1.0000e-04
# Epoch 8/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - dice_coef: 0.1767 - iou_coef: 0.0983 - loss: 1.5282
# Epoch 8: val_dice_coef improved from 0.16309 to 0.16380, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 8: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 230ms/step - dice_coef: 0.1698 - iou_coef: 0.0942 - loss: 1.5128 - val_dice_coef: 0.1638 - val_iou_coef: 0.0903 - val_loss: 1.3716 - learning_rate: 1.0000e-04
# Epoch 9/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - dice_coef: 0.1770 - iou_coef: 0.0985 - loss: 1.5272
# Epoch 9: val_dice_coef improved from 0.16380 to 0.16442, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 9: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 230ms/step - dice_coef: 0.1700 - iou_coef: 0.0944 - loss: 1.5118 - val_dice_coef: 0.1644 - val_iou_coef: 0.0907 - val_loss: 1.3709 - learning_rate: 1.0000e-04
# Epoch 10/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - dice_coef: 0.1773 - iou_coef: 0.0987 - loss: 1.5263
# Epoch 10: val_dice_coef improved from 0.16442 to 0.16460, saving model to ../outputs/models/bubble_unet_best.weights.h5
#
# Epoch 10: finished saving model to ../outputs/models/bubble_unet_best.weights.h5
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 230ms/step - dice_coef: 0.1702 - iou_coef: 0.0945 - loss: 1.5109 - val_dice_coef: 0.1646 - val_iou_coef: 0.0908 - val_loss: 1.3701 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 10.

# %%
MODEL_PATH = MODEL_DIR / "bubble_unet.keras"
HISTORY_PATH = OUTPUT_DIR / "training_history.json"

model.save(MODEL_PATH)
serializable_history = {
    name: [float(value) for value in values]
    for name, values in history.history.items()
}
with HISTORY_PATH.open("w") as history_file:
    json.dump(serializable_history, history_file, indent=2)

print("Saved model to:", MODEL_PATH)
print("Saved training history to:", HISTORY_PATH)
# Out:
# Saved model to: ../outputs/models/bubble_unet.keras
# Saved training history to: ../outputs/training_history.json

# %%
preds_val = model.predict(X_val)

print("Prediction min:", preds_val.min())
print("Prediction max:", preds_val.max())
print("Prediction mean:", preds_val.mean())
print("Ground truth foreground ratio:", Y_val.mean())

def dice_at_threshold(y_true, y_pred, threshold):
    y_pred_bin = (y_pred > threshold).astype(np.float32)
    intersection = np.sum(y_true * y_pred_bin)
    return (2 * intersection + 1) / (np.sum(y_true) + np.sum(y_pred_bin) + 1)

for t in np.arange(0.25, 0.50, 0.025):
    d = dice_at_threshold(Y_val, preds_val, t)
    fg = (preds_val > t).mean()
    print(f"Threshold {t:.3f} | Dice: {d:.4f} | Pred foreground: {fg:.4f}")
    
# for t in [0.2, 0.3, 0.4, 0.5]:
#     print(f"Foreground ratio at threshold {t}:", (preds_val > t).mean())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# Prediction min: 0.0
# Prediction max: 0.4452752
# Prediction mean: 0.23995765
# Ground truth foreground ratio: 0.08361435
# Threshold 0.250 | Dice: 0.2069 | Pred foreground: 0.7155
# Threshold 0.275 | Dice: 0.2099 | Pred foreground: 0.6939
# Threshold 0.300 | Dice: 0.2147 | Pred foreground: 0.6404
# Threshold 0.325 | Dice: 0.2201 | Pred foreground: 0.4780
# Threshold 0.350 | Dice: 0.0758 | Pred foreground: 0.0806
# Threshold 0.375 | Dice: 0.0254 | Pred foreground: 0.0098
# Threshold 0.400 | Dice: 0.0064 | Pred foreground: 0.0021
# Threshold 0.425 | Dice: 0.0001 | Pred foreground: 0.0000
# Threshold 0.450 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.475 | Dice: 0.0000 | Pred foreground: 0.0000

# %%
thresholds = np.arange(0.05, 0.951, 0.025)
threshold_results = []

for threshold in thresholds:
    dice = dice_at_threshold(Y_val, preds_val, threshold)
    foreground_ratio = float((preds_val > threshold).mean())
    threshold_results.append(
        (float(threshold), float(dice), foreground_ratio)
    )
    print(
        f"Threshold {threshold:.3f} | Dice: {dice:.4f} | "
        f"Pred foreground: {foreground_ratio:.4f}"
    )

best_threshold, best_dice, best_foreground_ratio = max(
    threshold_results,
    key=lambda result: result[1]
)

threshold_summary = {
    "best_threshold": best_threshold,
    "validation_dice": best_dice,
    "predicted_foreground_ratio": best_foreground_ratio,
    "ground_truth_foreground_ratio": float(Y_val.mean()),
}
# with (OUTPUT_DIR / "threshold_summary.json").open("w") as summary_file:
#     json.dump(threshold_summary, summary_file, indent=2)

print("\nBest validation threshold:", best_threshold)
print("Best validation Dice:", best_dice)
# print("Best validation Dice:", best_dice)
# Out:
# Threshold 0.050 | Dice: 0.2042 | Pred foreground: 0.7355
# Threshold 0.075 | Dice: 0.2044 | Pred foreground: 0.7347
# Threshold 0.100 | Dice: 0.2045 | Pred foreground: 0.7343
# Threshold 0.125 | Dice: 0.2046 | Pred foreground: 0.7336
# Threshold 0.150 | Dice: 0.2048 | Pred foreground: 0.7331
# Threshold 0.175 | Dice: 0.2049 | Pred foreground: 0.7326
# Threshold 0.200 | Dice: 0.2050 | Pred foreground: 0.7322
# Threshold 0.225 | Dice: 0.2051 | Pred foreground: 0.7317
# Threshold 0.250 | Dice: 0.2069 | Pred foreground: 0.7155
# Threshold 0.275 | Dice: 0.2099 | Pred foreground: 0.6939
# Threshold 0.300 | Dice: 0.2147 | Pred foreground: 0.6404
# Threshold 0.325 | Dice: 0.2201 | Pred foreground: 0.4780
# Threshold 0.350 | Dice: 0.0758 | Pred foreground: 0.0806
# Threshold 0.375 | Dice: 0.0254 | Pred foreground: 0.0098
# Threshold 0.400 | Dice: 0.0064 | Pred foreground: 0.0021
# Threshold 0.425 | Dice: 0.0001 | Pred foreground: 0.0000
# Threshold 0.450 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.475 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.500 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.525 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.550 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.575 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.600 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.625 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.650 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.675 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.700 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.725 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.750 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.775 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.800 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.825 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.850 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.875 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.900 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.925 | Dice: 0.0000 | Pred foreground: 0.0000
# Threshold 0.950 | Dice: 0.0000 | Pred foreground: 0.0000
#
# Best validation threshold: 0.32500000000000007
# Best validation Dice: 0.2200753390789032

# %%
for idx in [0, 5, 10]:
    image = X_val[idx].squeeze()
    ground_truth = Y_val[idx].squeeze() > 0.5
    probability = preds_val[idx].squeeze()
    prediction = probability > best_threshold

    tp = ground_truth & prediction
    fp = ~ground_truth & prediction
    fn = ground_truth & ~prediction

    tp_count = tp.sum()
    fp_count = fp.sum()
    fn_count = fn.sum()

    precision = tp_count / (tp_count + fp_count + 1e-8)
    recall = tp_count / (tp_count + fn_count + 1e-8)
    dice = (
        2 * tp_count /
        (2 * tp_count + fp_count + fn_count + 1e-8)
    )

    # 0 = correct background
    # 1 = true positive
    # 2 = false positive
    # 3 = false negative
    comparison = np.zeros(ground_truth.shape, dtype=np.uint8)
    comparison[tp] = 1
    comparison[fp] = 2
    comparison[fn] = 3

    comparison_cmap = ListedColormap([
        "black",       # correct background
        "limegreen",   # true positive
        "red",         # false positive
        "deepskyblue"  # false negative
    ])

    fig, axes = plt.subplots(1, 5, figsize=(21, 4))

    axes[0].imshow(image, cmap="gray")
    axes[0].set_title("Validation input\nF770W intensity")

    axes[1].imshow(
        ground_truth,
        cmap="gray",
        vmin=0,
        vmax=1
    )
    axes[1].set_title("Ground truth\nWhite = catalogue foreground")

    probability_plot = axes[2].imshow(
        probability,
        cmap="inferno",
        vmin=0,
        vmax=1
    )
    axes[2].set_title("Predicted probability")

    colorbar = fig.colorbar(
        probability_plot,
        ax=axes[2],
        fraction=0.046,
        pad=0.04
    )
    colorbar.set_label("Foreground probability")

    axes[3].imshow(
        prediction,
        cmap="gray",
        vmin=0,
        vmax=1
    )
    axes[3].set_title(
        f"Binary prediction\n"
        f"White = probability > {best_threshold:.2f}"
    )

    axes[4].imshow(
        comparison,
        cmap=comparison_cmap,
        vmin=0,
        vmax=3
    )
    axes[4].set_title(
        f"Prediction errors\n"
        f"Dice={dice:.3f}, P={precision:.3f}, R={recall:.3f}"
    )

    legend_items = [
        Patch(color="limegreen", label="True positive"),
        Patch(color="red", label="False positive"),
        Patch(color="deepskyblue", label="False negative"),
        Patch(color="black", label="Correct background")
    ]

    axes[4].legend(
        handles=legend_items,
        loc="lower center",
        bbox_to_anchor=(0.5, -0.35),
        ncol=2,
        frameon=False
    )

    for axis in axes:
        axis.axis("off")

    plt.tight_layout()
    plt.show()

# %%
# Loss curves
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, "loss_curve.png"), dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['dice_coef'], label='Training Dice')
plt.plot(history.history['val_dice_coef'], label='Validation Dice')

plt.title('Dice Coefficient During Training')
plt.xlabel('Epoch')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig(os.path.join(FIGURE_DIR, "dice_curve.png"), dpi=300)
plt.show()
