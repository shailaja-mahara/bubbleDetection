# %%
# !pip install astropy
# !pip install scikit-image

import os

from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

import re
from astropy.wcs import WCS

from skimage.draw import ellipse

# %%
fits_path = "../data/raw/fits/jw02107-o039_t018_miri_f770w_i2d.fits"

hdul = fits.open(fits_path)
hdul.info()
# Out:
# Filename: ../data/raw/fits/jw02107-o039_t018_miri_f770w_i2d.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     265   ()
#   1  SCI           1 ImageHDU        75   (2380, 1177)   float32
#   2  ERR           1 ImageHDU        10   (2380, 1177)   float32
#   3  CON           1 ImageHDU        10   (2380, 1177, 1)   int32
#   4  WHT           1 ImageHDU         9   (2380, 1177)   float32
#   5  VAR_POISSON    1 ImageHDU         9   (2380, 1177)   float32
#   6  VAR_RNOISE    1 ImageHDU         9   (2380, 1177)   float32
#   7  VAR_FLAT      1 ImageHDU         9   (2380, 1177)   float32
#   8  HDRTAB        1 BinTableHDU    502   12R x 246C   [23A, 5A, 3A, 48A, 7A, 13A, 6A, 5A, 6A, 7A, 10A, 4A, L, D, D, 32A, 50A, 70A, 11A, 2A, 47A, 10A, 12A, 23A, 23A, 26A, 11A, 5A, 3A, 3A, 2A, 1A, 2A, 1A, L, 12A, 6A, 2A, 26A, 20A, 27A, 10A, K, L, L, L, L, 7A, 7A, 5A, D, D, D, D, D, D, 27A, D, D, 4A, 8A, 5A, 4A, 3A, 4A, K, 5A, 9A, D, D, D, D, D, D, D, D, D, 6A, K, K, K, K, K, K, K, K, K, D, D, D, D, D, D, D, D, D, K, K, L, L, K, K, D, 4A, K, K, K, K, K, K, 12A, K, K, D, D, 7A, 10A, D, D, D, D, D, D, D, D, D, D, D, D, D, 10A, 11A, D, D, D, D, D, D, D, D, D, D, D, D, K, 27A, 27A, 10A, D, D, D, D, D, D, D, 9A, 27A, 6A, 14A, 31A, 3A, 3A, 31A, 3A, 37A, 34A, 39A, 31A, 3A, 3A, 3A, 3A, 3A, 31A, 3A, 3A, 3A, 36A, 31A, 3A, 3A, 33A, 36A, 3A, 32A, 31A, 37A, 3A, 3A, 3A, 8A, 7A, 7A, 8A, 8A, 8A, 8A, 8A, 7A, 7A, 7A, 8A, 8A, 8A, 8A, 8A, 8A, 7A, 8A, 8A, 8A, 8A, 8A, 5A, D, L, 6A, D, D, D, D, 4A, D, D, D, K, D, D, D, D, 12A, 12A, 3A, 3A, D, D, D, D, 117A, D, D, K, D, D, D, D]
#   9  ASDF          1 BinTableHDU     11   1R x 1C   [108350B]

# %%
data = hdul[1].data
header = hdul[1].header

# %%
print(data.shape)
print(np.nanmin(data), np.nanmax(data))
print(header)
# Out:
# (1177, 2380)
# 7.1088414 411.28107
# XTENSION= 'IMAGE   '           / Image extension                                BITPIX  =                  -32 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                 2380                                                  NAXIS2  =                 1177                                                  PCOUNT  =                    0 / number of parameters                           GCOUNT  =                    1 / number of groups                               EXTNAME = 'SCI     '           / extension name                                 MJD-BEG =     59777.4644468287 / [d] exposure start time in MJD                 MJD-AVG =    59777.50131464893 / [d] exposure mid-point in MJD                  MJD-END =   59777.538032592594 / [d] exposure end time in MJD                   TDB-BEG =   59777.464825825205 / [d] TDB time of exposure start in MJD          TDB-MID =    59777.50169723314 / [d] TDB time of exposure mid-point in MJD      TDB-END =   59777.538418749995 / [d] TDB time of exposure end in MJD            XPOSURE =    266.3999999999999 / [s] Effective exposure time                    TELAPSE =    266.3999999999999 / [s] Total elapsed exposure time                                                                                                        JWST ephemeris information                                                                                                                              REFFRAME= 'EME2000 '           / Ephemeris reference frame (EME2000)            EPH_TYPE= 'Definitive'         / Definitive or Predicted                        EPH_TIME=   59777.464575300924 / [d] MJD time of position and velocity vectors  JWST_X  =    62327710.30781233 / [km] barycentric JWST X coordinate at MJD-AVG  JWST_Y  =  -127959459.23075028 / [km] barycentric JWST Y coordinate at MJD-AVG  JWST_Z  =   -55943501.56721501 / [km] barycentric JWST Z coordinate at MJD-AVG  OBSGEO-X=     469984475.988658 / [m] geocentric JWST X coordinate at MJD-AVG    OBSGEO-Y=  -1297380895.9316792 / [m] geocentric JWST Y coordinate at MJD-AVG    OBSGEO-Z=  -1068583353.7301109 / [m] geocentric JWST Z coordinate at MJD-AVG    JWST_DX =   26.657968482397294 / [km/s] barycentric JWST X velocity at MJD-AVG  JWST_DY =    11.24699514151296 / [km/s] barycentric JWST Y velocity at MJD-AVG  JWST_DZ =    4.916572260328366 / [km/s] barycentric JWST Z velocity at MJD-AVG  OBSGEODX=    56.44524418335703 / [m/s] geocentric JWST X velocity at MJD-AVG    OBSGEODY=   12.708399950300006 / [m/s] geocentric JWST Y velocity at MJD-AVG    OBSGEODZ=   47.017581361032406 / [m/s] geocentric JWST Z velocity at MJD-AVG    PA_APER =   249.99015237657673 / [deg] Position angle of aperture used          VA_SCALE=    1.000097317348658 / Velocity aberration scale factor               BUNIT   = 'MJy/sr  '           / physical units of the array values                                                                                                     Photometry information                                                                                                                                  PHOTMJSR=   0.2549386403917156 / Flux density (MJy/steradian) producing 1 cps   PHOTUJA2=    5.992187564819135 / Flux density (uJy/arcsec2) producing 1 cps     PIXAR_SR= 2.89211125860830E-13 / Nominal pixel area in steradians               PIXAR_A2= 0.012304536601290928 / Nominal pixel area in arcsec^2                                                                                                         Information about the coordinates in the file                                                                                                           RADESYS = 'ICRS    '           / Name of the coordinate reference frame                                                                                                 Spacecraft pointing information                                          ...

# %%
plt.figure(figsize=(8, 8))
plt.imshow(data, origin="lower", cmap="gray",
           vmin=np.nanpercentile(data, 1),
           vmax=np.nanpercentile(data, 99))
plt.colorbar()
plt.title("JWST F770W Image")
plt.show()

# %%
data_clean = np.nan_to_num(data, nan=0.0)

# %%
p1, p99 = np.percentile(data_clean, (1, 99))
data_clipped = np.clip(data_clean, p1, p99)

data_norm = (data_clipped - p1) / (p99 - p1)

# %%
print (data_norm.shape)
print (data_norm.max())
# Out:
# (1177, 2380)
# 1.0

# %%
# saving ngc 628 png file

# Does directory exist?
os.makedirs("../data/processed/images", exist_ok=True)

# Saving normalized image
np.save("../data/processed/images/ngc628_f770w_norm.npy", data_norm)

# %%
# now sanity check

loaded = np.load("../data/processed/images/ngc628_f770w_norm.npy")
print(loaded.shape, loaded.min(), loaded.max())
# Out:
# (1177, 2380) 0.0 1.0

# %%
import pandas as pd

df = pd.read_csv("../data/raw/catalogue/jwst_bubble_properties_A.txt")

print(df.head())
print(df.columns)
# Out:
#    ID       RA_DMS      DEC_DMS  SEMI_MAJ_PC  SEMI_MIN_PC  AVG_RAD_PC  PA_DEG  \
# 0   1  24d08m55.9s   15d48m7.9s           86           86          86       0
# 1   2  24d08m56.7s   15d48m2.9s           24           24          24       0
# 2   3  24d08m57.0s   15d48m9.0s           42           42          42       0
# 3   4  24d08m58.0s  15d47m44.9s           25           25          25       0
# 4   5  24d08m58.2s   15d48m2.6s           24           24          24       0
#
#    ARM  DIST_ARM_PC  GAL_RAD_KPC
# 0    3          145         5.22
# 1    3          127         5.05
# 2    3          138         5.21
# 3    3          101         4.54
# 4    3          114         4.98
# Index(['ID', 'RA_DMS', 'DEC_DMS', 'SEMI_MAJ_PC', 'SEMI_MIN_PC', 'AVG_RAD_PC',
#        'PA_DEG', 'ARM', 'DIST_ARM_PC', 'GAL_RAD_KPC'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['ID', 'RA_DMS', 'DEC_DMS', 'SEMI_MAJ_PC', 'SEMI_MIN_PC', 'AVG_RAD_PC',
#        'PA_DEG', 'ARM', 'DIST_ARM_PC', 'GAL_RAD_KPC'],
#       dtype='str')

# %%
df.head()
# Out:
#    ID       RA_DMS      DEC_DMS  SEMI_MAJ_PC  SEMI_MIN_PC  AVG_RAD_PC  PA_DEG  \
# 0   1  24d08m55.9s   15d48m7.9s           86           86          86       0
# 1   2  24d08m56.7s   15d48m2.9s           24           24          24       0
# 2   3  24d08m57.0s   15d48m9.0s           42           42          42       0
# 3   4  24d08m58.0s  15d47m44.9s           25           25          25       0
# 4   5  24d08m58.2s   15d48m2.6s           24           24          24       0
#
#    ARM  DIST_ARM_PC  GAL_RAD_KPC
# 0    3          145         5.22
# 1    3          127         5.05
# 2    3          138         5.21
# 3    3          101         4.54
# 4    3          114         4.98

# %%
wcs = WCS(header)
print(wcs)
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN' 'DEC--TAN'
# CUNIT : 'deg' 'deg'
# CRVAL : 24.171680195437894 15.788156932392056
# CRPIX : 1176.2406743555237 589.0158147454987
# PC1_1 PC1_2  : 0.3421816464879256 -0.939633822723944
# PC2_1 PC2_2  : -0.939633822723944 -0.3421816464879256
# CDELT : 3.08127265990853e-05 3.08127265990853e-05
# NAXIS : 2380  1177
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-07-17T11:08:48.206' from MJD-BEG.
# Set DATE-AVG to '2022-07-17T12:01:53.586' from MJD-AVG.
# Set DATE-END to '2022-07-17T12:54:46.016' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -70.086759 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -37.754891 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1738895745.202 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
ra_dms = df['RA_DMS'].tolist()      # degree to dms
dec_dms = df['DEC_DMS'].tolist()

def ra_dec_to_deg(ra_str, dec_str):
    ra_pattern = re.compile(r'(\d+)d(\d+)m(\d+\.\d+)s')
    dec_pattern = re.compile(r'(\d+)d(\d+)m(\d+\.\d+)s')
    ra_deg, ra_min, ra_sec = map(float, ra_pattern.match(ra_str).groups())
    dec_deg, dec_min, dec_sec = map(float, dec_pattern.match(dec_str).groups())
    ra_decimal = ra_deg + ra_min / 60 + ra_sec / 3600
    dec_decimal = dec_deg + dec_min / 60 + dec_sec / 3600

    return ra_decimal, dec_decimal

def deg_to_dec(data_in_str):
    data_pattern = re.compile(r'(\d+)d(\d+)m(\d+\.\d+)s')
    data_deg, data_min, data_sec = map(float, data_pattern.match(data_in_str).groups())
    data_in_decimal = data_deg + data_min / 60 + data_sec / 3600

    return data_in_decimal


ra_degrees = np.zeros(len(df), dtype=float)
dec_degrees = np.zeros(len(df), dtype=float)
for i, row in df.iterrows():
    ra_deg, dec_deg = ra_dec_to_deg(row['RA_DMS'], row['DEC_DMS'])
    ra_degrees[i] = ra_deg
    dec_degrees[i] = dec_deg

# %%
# x_pix, y_pix = wcs.world_to_pixel_values(ra, dec)
x_pix, y_pix = wcs.all_world2pix(ra_degrees, dec_degrees, 0)

# %%
# sanity check  

plt.figure(figsize=(8, 8))
# plt.imshow(data_norm, origin="lower", cmap="gray")
plt.imshow(data, origin="lower", cmap="gray",
           vmin=np.nanpercentile(data, 1),
           vmax=np.nanpercentile(data, 99))

plt.scatter(x_pix, y_pix, s=5, color='red')
plt.title("Bubble positions on JWST image")

plt.show()

# %%
# saving bubble position overlay png file

os.makedirs("../outputs/figures", exist_ok=True)

plt.figure(figsize=(10, 10))
plt.imshow(data_norm, origin="lower", cmap="gray")
plt.scatter(x_pix, y_pix, s=5, color="red", alpha=0.7)
plt.title("Bubble Positions on JWST F770W Image")
plt.xlabel("X pixel")
plt.ylabel("Y pixel")

plt.savefig(
    "../outputs/figures/ngc628_f770w_bubble_positions_overlay.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
# mask generation :  parsec to pixel


# Distance to NGC 628 in parsecs
distance_pc = 9.77e6

# Pixel scale from FITS header
pixel_scale_deg = abs(header['CDELT1'])
pixel_scale_arcsec = pixel_scale_deg * 3600

# Physical scale
pc_per_arcsec = distance_pc / 206265
pc_per_pixel = pixel_scale_arcsec * pc_per_arcsec

print("pc per pixel:", pc_per_pixel)
# Out:
# pc per pixel: 5.254140159227344

# %%
# semi major and semi minor conversion

semi_major_pix = df['SEMI_MAJ_PC'] / pc_per_pixel
semi_minor_pix = df['SEMI_MIN_PC'] / pc_per_pixel
pa_deg = df['PA_DEG']

# %%
mask = np.zeros(data_norm.shape, dtype=np.uint8)     # empty binary mask

# %%
height, width = mask.shape

for i in range(len(df)):
    x0 = x_pix[i]
    y0 = y_pix[i]

    a = semi_major_pix.iloc[i]
    b = semi_minor_pix.iloc[i]
    pa = np.deg2rad(pa_deg.iloc[i])

    if np.isnan(x0) or np.isnan(y0) or np.isnan(a) or np.isnan(b):
        continue

    rr, cc = ellipse(
        r=y0,
        c=x0,
        r_radius=b,
        c_radius=a,
        rotation=pa,
        shape=mask.shape
    )

    mask[rr, cc] = 1

# %%
plt.figure(figsize=(8, 8))
plt.imshow(mask, origin="lower", cmap="gray")
plt.title("Binary Superbubble Mask")
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(data_norm, origin="lower", cmap="gray")
plt.imshow(mask, origin="lower", alpha=0.35)
plt.title("Superbubble Mask Overlay on JWST F770W")
plt.show()

# %%
os.makedirs("../data/processed/masks", exist_ok=True)

np.save("../data/processed/masks/ngc628_superbubble_mask.npy", mask)

# %%
loaded = np.load("../data/processed/masks/ngc628_superbubble_mask.npy")
print(loaded.shape, loaded.min(), loaded.max())
# Out:
# (1177, 2380) 0 1

# %%
plt.imsave(
    "../outputs/figures/ngc628_f770w_norm.png",
    data_norm, 
    cmap="gray"
)

# %%
# saving mask overlay png file

plt.figure(figsize=(10, 10))
plt.imshow(data_norm, origin="lower", cmap="gray")
plt.imshow(mask, origin="lower", alpha=0.35)
plt.title("Superbubble Mask Overlay on JWST F770W")
plt.savefig(
    "../outputs/figures/ngc628_superbubble_mask_overlay.png",
    dpi=300,
    bbox_inches="tight"
)
plt.show()
