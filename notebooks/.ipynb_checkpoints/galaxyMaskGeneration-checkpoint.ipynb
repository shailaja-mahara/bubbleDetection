# %%
# !pip install astropy
# !pip install scikit-image

import os

from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
from matplotlib.patches import Ellipse

from skimage.draw import ellipse

# %%
fits_path = "../data/raw/fits/jw02107-o039_t018_miri_f770w_i2d.fits"

catalogue_path = "../data/processed/metadata/cleanedSegregatedMergedCatalogue.txt"

output_file = "../outputs/figures"
output_image_path = "../data/processed/images"
output_mask_path = "../data/processed/masks"

os.makedirs(output_file, exist_ok=True)
os.makedirs("../data/processed/images", exist_ok=True)
os.makedirs("../data/processed/masks", exist_ok=True)

CURRICULUM_STAGES = {
    "stage00": ["edgeLarge"],
    "stage01": ["giants", "edgeLarge"],
    "stage02": ["large", "giants", "edgeLarge"],
    "stage03": ["medium", "large", "giants", "edgeLarge"],
    "stage04": ["small", "medium", "large", "giants", "edgeLarge"],
    "stage05": ["tiny", "small", "medium", "large", "giants", "edgeLarge"],
}

ACTIVE_STAGE = "stage00"

# %%
hdul = fits.open(fits_path)
hdul.info()

data = hdul[1].data
header = hdul[1].header

print(data.shape)
print(np.nanmin(data), np.nanmax(data))
# Out:
# Filename: ../data/raw/fits/jw02107-o039_t018_miri_f770w_i2d.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     265   ()
#   1  SCI           1 ImageHDU        75   (2380, 1177)   float32
#   2  ERR           1 ImageHDU        10   (2380, 1177)   float32
#   3  CON           1 ImageHDU        10   (2380, 1177, 1)   int32
#   4  WHT           1 ImageHDU         9   (2380, 1177)   float32
#   5  VAR_POISSON    1 ImageHDU         9   (2380, 1177)   float32
#   6  VAR_RNOISE    1 ImageHDU         9   (2380, 1177)   float32
#   7  VAR_FLAT      1 ImageHDU         9   (2380, 1177)   float32
# ...

# %%
plt.figure(figsize=(8, 8))
plt.imshow(data, origin="lower", cmap="gray",
           vmin=np.nanpercentile(data, 1),
           vmax=np.nanpercentile(data, 99))

plt.title("JWST F770W Image")
plt.show()

# %%
# saving ngc 628 png file
output_path = os.path.join(output_image_path, "ngc628.npy")

# Saving image
np.save(output_path, data)

# %%
data_clean = np.nan_to_num(data, nan=0.0)

# %%
p1, p99 = np.percentile(data_clean, (1, 99))
data_clipped = np.clip(data_clean, p1, p99)

data_norm = (data_clipped - p1) / (p99 - p1)

# %%
print (data_norm.shape)
print (data_norm.max())
# Out:
# (1177, 2380)
# 1.0

# %%
# saving ngc 628 png file
output_norm_path = os.path.join(output_image_path, "ngc628Norm.npy")

# Saving normalized image
np.save(output_norm_path, data_norm)

# %%
# now sanity check

loaded = np.load(output_norm_path)
print(loaded.shape, loaded.min(), loaded.max())
# Out:
# (1177, 2380) 0.0 1.0

# %%
df_all = pd.read_csv(catalogue_path)

assert "SIZE_CLASS" in df_all.columns, (
    "cleanedSegregatedMergedCatalogue.txt has no SIZE_CLASS column - "
    "re-run catalogueSegregation.ipynb"
)

active_classes = CURRICULUM_STAGES[ACTIVE_STAGE]
unknown = set(df_all["SIZE_CLASS"]) - set(CURRICULUM_STAGES["stage05"])
assert not unknown, f"unrecognised SIZE_CLASS values in the catalogue: {sorted(unknown)}"

df = df_all[df_all["SIZE_CLASS"].isin(active_classes)].reset_index(drop=True)

assert len(df) > 0, f"no bubbles left for {ACTIVE_STAGE} - check ACTIVE_STAGE"

print(f"Stage {ACTIVE_STAGE}: {active_classes}")
print(f"Bubbles painted into the mask: {len(df)} of {len(df_all)}\n")
print(df["SIZE_CLASS"].value_counts().reindex(active_classes).to_string())
print()
print(df.head())
print(df.columns)
# Out:
# Stage stage00: ['edgeLarge']
# Bubbles painted into the mask: 87 of 2702
#
# SIZE_CLASS
# edgeLarge    87
#
#    GLOBAL_ID  ID       RA_DMS      DEC_DMS  SEMI_MAJ_PC  SEMI_MIN_PC  \
# 0         10  10  24d08m59.3s   15d48m6.1s          209          171
# 1         12  12   24d09m0.4s  15d47m52.2s          163           93
# 2         44  44  24d09m12.5s  15d48m12.1s          144           91
# 3         74  74  24d09m17.3s   15d47m3.6s          129           87
# 4         98  98  24d09m20.8s   15d48m1.4s          260          187
#
#    AVG_RAD_PC  PA_DEG CATALOGUE SIZE_CLASS
# 0         196       0         A  edgeLarge
# 1         139      20         A  edgeLarge
# 2         127     -60         A  edgeLarge
# 3         115      20         A  edgeLarge
# 4         236      70         A  edgeLarge
# Index(['GLOBAL_ID', 'ID', 'RA_DMS', 'DEC_DMS', 'SEMI_MAJ_PC', 'SEMI_MIN_PC',
#        'AVG_RAD_PC', 'PA_DEG', 'CATALOGUE', 'SIZE_CLASS'],
#       dtype='str')

# %%
def ra_dec_to_deg(ra_str, dec_str):
    coords = SkyCoord(ra=ra_str, dec=dec_str, frame="icrs")
    return coords.ra.deg, coords.dec.deg

ra_degrees, dec_degrees = ra_dec_to_deg(
        df["RA_DMS"].to_numpy(),
        df["DEC_DMS"].to_numpy()
    )

# %%
wcs = WCS(header)
print(wcs) 

x_pix, y_pix = wcs.all_world2pix(ra_degrees, dec_degrees, 0)
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN' 'DEC--TAN'
# CUNIT : 'deg' 'deg'
# CRVAL : 24.171680195437894 15.788156932392056
# CRPIX : 1176.2406743555237 589.0158147454987
# PC1_1 PC1_2  : 0.3421816464879256 -0.939633822723944
# PC2_1 PC2_2  : -0.939633822723944 -0.3421816464879256
# CDELT : 3.08127265990853e-05 3.08127265990853e-05
# NAXIS : 2380  1177
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-07-17T11:08:48.206' from MJD-BEG.
# Set DATE-AVG to '2022-07-17T12:01:53.586' from MJD-AVG.
# Set DATE-END to '2022-07-17T12:54:46.016' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -70.086759 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -37.754891 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1738895745.202 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
# sanity check  

plt.figure(figsize=(8, 8))

# plt.imshow(data_norm, origin="lower", cmap="gray")
plt.imshow(data, origin="lower", cmap="gray",
           vmin=np.nanpercentile(data, 1),
           vmax=np.nanpercentile(data, 99))

plt.scatter(x_pix, y_pix, s=1, color='red')
plt.title("Bubble positions on JWST image")

plt.show()

# %%
# mask generation :  parsec to pixel

# Distance to NGC 628 in parsecs
distance_pc = 9.77e6

# Pixel scale from FITS header
pixel_scale_deg = abs(header['CDELT1'])
pixel_scale_arcsec = pixel_scale_deg * 3600

# Physical scale
pc_per_arcsec = distance_pc / 206265
pc_per_pixel = pixel_scale_arcsec * pc_per_arcsec

print("pc per pixel:", pc_per_pixel)
# Out:
# pc per pixel: 5.254140159227344

# %%
mask = np.zeros(data_norm.shape, dtype=np.uint8)

# %%
# semi major and semi minor conversion

semi_major_pix = df['SEMI_MAJ_PC'] / pc_per_pixel
semi_minor_pix = df['SEMI_MIN_PC'] / pc_per_pixel
pa_deg = df['PA_DEG']

# %%
fig, ax = plt.subplots(figsize=(10, 10))

plt.imshow(data, origin="lower", cmap="gray",
           vmin=np.nanpercentile(data, 1),
           vmax=np.nanpercentile(data, 99))

for i in range(len(df)):
    x0 = x_pix[i]
    y0 = y_pix[i]

    a = semi_major_pix.iloc[i]
    b = semi_minor_pix.iloc[i]
    pa = pa_deg.iloc[i]

    if np.isnan(x0) or np.isnan(y0) or np.isnan(a) or np.isnan(b):
        continue

    ellipse_patch = Ellipse(
        xy=(x0, y0),
        width=2 * a,
        height=2 * b,
        angle=pa,
        edgecolor="purple",
        facecolor="none",
        linewidth=1.2,
        alpha=0.9,
    )

    ax.add_patch(ellipse_patch)

ax.set_title("Bubble Ellipse Overlay")
ax.set_axis_off()

output_overlay_path = os.path.join(output_file, "ngc628_f770w_bubble_positions.png")

plt.savefig(
    output_overlay_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
for i in range(len(df)):
    x0 = x_pix[i]
    y0 = y_pix[i]

    a = semi_major_pix.iloc[i]
    b = semi_minor_pix.iloc[i]
    pa = np.deg2rad(pa_deg.iloc[i])

    if np.isnan(x0) or np.isnan(y0) or np.isnan(a) or np.isnan(b):
        continue

    rr, cc = ellipse(
        r=y0,
        c=x0,
        r_radius=b,
        c_radius=a,
        rotation=pa,
        shape=mask.shape
    )

    mask[rr, cc] = 1

# %%
# Marking those pixels "don't know" instead means the loss simply skips them:
#   mask   = 1  ->  bubble, train on it
#   ignore = 1  ->  unknown, contributes nothing to the loss
#   both 0      ->  background, train on it

df_ignore = df_all[~df_all["SIZE_CLASS"].isin(active_classes)].reset_index(drop=True)

ignore_mask = np.zeros(mask.shape, dtype=np.uint8)

if len(df_ignore):
    ra_ignore, dec_ignore = ra_dec_to_deg(
        df_ignore["RA_DMS"].to_numpy(),
        df_ignore["DEC_DMS"].to_numpy(),
    )
    x_ignore, y_ignore = wcs.all_world2pix(ra_ignore, dec_ignore, 0)

    semi_major_ignore = df_ignore["SEMI_MAJ_PC"] / pc_per_pixel
    semi_minor_ignore = df_ignore["SEMI_MIN_PC"] / pc_per_pixel

    for i in range(len(df_ignore)):
        x0 = x_ignore[i]
        y0 = y_ignore[i]

        a = semi_major_ignore.iloc[i]
        b = semi_minor_ignore.iloc[i]
        pa = np.deg2rad(df_ignore["PA_DEG"].iloc[i])

        if np.isnan(x0) or np.isnan(y0) or np.isnan(a) or np.isnan(b):
            continue

        rr, cc = ellipse(
            r=y0,
            c=x0,
            r_radius=b,
            c_radius=a,
            rotation=pa,
            shape=ignore_mask.shape,
        )

        ignore_mask[rr, cc] = 1

# an active bubble always wins: a pixel inside both an active and an inactive
# bubble is positive, not unknown
ignore_mask[mask == 1] = 0

n_bg = int(((mask == 0) & (ignore_mask == 0)).sum())

print(f"ignored bubbles : {len(df_ignore):>6} "
      f"({', '.join(sorted(set(df_ignore['SIZE_CLASS']))) or 'none'})")
print(f"positive px     : {int(mask.sum()):>9}  ({mask.mean():.4f})")
print(f"ignored px      : {int(ignore_mask.sum()):>9}  ({ignore_mask.mean():.4f})")
print(f"background px   : {n_bg:>9}  ({n_bg / mask.size:.4f})")
assert not ((mask == 1) & (ignore_mask == 1)).any(), "a pixel is both positive and ignored"
# Out:
# WARNING: IllegalSecondWarning: 'second' was found  to be '60.0', which is not in range [0,60). Treating as 0 sec, +1 min [astropy.coordinates.angles.formats]
# ignored bubbles :   2615 (giants, large, medium, small, tiny)
# positive px     :    238937  (0.0853)
# ignored px      :    278255  (0.0993)
# background px   :   2284068  (0.8154)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(mask, origin="lower", cmap="gray")
plt.title("Binary Superbubble Mask")

overlayabc_path = os.path.join(output_file,"ngc628MaskABC.png")

plt.savefig(overlayabc_path, dpi=300, bbox_inches="tight")

plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(data_norm, origin="lower", cmap="gray")
plt.imshow(mask, origin="lower", alpha=0.35)
plt.title("Superbubble Mask Overlay JWST F770W - ABC catalogue")

overlayabc_path = os.path.join(output_file,"ngc628NormMaskOverlayABC.png")

plt.savefig(overlayabc_path, dpi=300, bbox_inches="tight")

plt.show()

# %%
# saving mask overlay png file

plt.figure(figsize=(10, 10))
plt.imshow(data, origin="lower", cmap="gray",
           vmin=np.nanpercentile(data, 1),
           vmax=np.nanpercentile(data, 99))
plt.imshow(mask, origin="lower", alpha=0.35)
    
plt.title(f"Superbubble Mask Overlay JWST F770W - {ACTIVE_STAGE}")

output_maskoverlay_path = os.path.join(output_file, "ngc628MaskOverlayABC.png")

plt.savefig(
    output_maskoverlay_path,
    dpi=300,
    bbox_inches="tight"
    )

plt.show()

# Saving normalized mask
mask_path = os.path.join(output_mask_path, "ngc628NormMask.npy")
np.save(mask_path, mask)

# ignore mask travels as a SEPARATE file so ngc628NormMask.npy keeps its 0/1
# meaning - patchMaker's sanity asserts and perClassEvaluation's Y_val equality
# check both depend on that
ignore_path = os.path.join(output_mask_path, "ngc628IgnoreMask.npy")
np.save(ignore_path, ignore_mask)

# neither filename carries a stage, so state which stage these are - patchMaker
# reads whatever was written last
print(f"Saved mask for {ACTIVE_STAGE} ({len(df)} bubbles, "
      f"foreground {mask.mean():.4f}) to {mask_path}")
print(f"Saved ignore mask ({len(df_ignore)} bubbles, "
      f"{ignore_mask.mean():.4f} of the frame) to {ignore_path}")
# Out:
# Saved mask for stage00 (87 bubbles, foreground 0.0853) to ../data/processed/masks/ngc628NormMask.npy
# Saved ignore mask (2615 bubbles, 0.0993 of the frame) to ../data/processed/masks/ngc628IgnoreMask.npy
