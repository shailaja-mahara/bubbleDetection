# %%
# imports and constants

# !pip install tqdm

import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
# loading image and mask

IMAGE_PATH = "../data/processed/images/ngc628Norm.npy"
MASK_PATH = "../data/processed/masks/ngc628NormMask.npy"
OUTPUT_DIR = "../data/processed/patches"
# DATA_DIR = "../data/processed"

os.makedirs(OUTPUT_DIR, exist_ok=True)

metadata_path = os.path.join(OUTPUT_DIR, "patchMetadata.csv")

PATCH_SIZE = 256
STRIDE = 128  # liitle overlap 

# THRESHOLD = 0.05
LOW_THRESHOLD = 0.001   # negative patch threshold
HIGH_THRESHOLD = 0.05   # positive patch threshold


# spatial hold-out: exam regions fixed in sky coordinates, never regenerated
VAL_REGIONS_PATH = "../data/processed/metadata/valRegions.csv"

# %%
# validation and normalization

image = np.load(IMAGE_PATH).astype(np.float32)
mask = np.load(MASK_PATH).astype(np.float32)

# %%
# small sanity check
print("Image shape:", image.shape, "dtype:", image.dtype, "min/max:", image.min(), image.max())
print("Mask shape:", mask.shape, "dtype:", mask.dtype, "min/max:", mask.min(), mask.max())
print("Bubble pixels:", int(mask.sum()))

unique_vals = np.unique(mask)
print("Mask unique values:", unique_vals[:10])
# Out:
# Image shape: (1177, 2380) dtype: float32 min/max: 0.0 1.0
# Mask shape: (1177, 2380) dtype: float32 min/max: 0.0 1.0
# Bubble pixels: 517192
# Mask unique values: [0. 1.]

# %%
assert image.shape == mask.shape, "Image and mask must have the same height and width."
assert image.ndim == 2, "Expected image to be a 2D array."
# assert mask.sum() > 0, "Mask contains no bubble pixels"

# %%
def extract_patches(
    image,
    mask,
    patch_size=256,
    stride=128,
    low_threshold=0.001,
    high_threshold=0.05
):
    H, W = image.shape

    pos_patches = []
    weak_patches = []
    neg_patches = []

    for y_start in range(
        0,
        H - patch_size + 1,
        stride
    ):
        for x_start in range(
            0,
            W - patch_size + 1,
            stride
        ):
            image_patch = image[
                y_start:y_start + patch_size,
                x_start:x_start + patch_size
            ]

            mask_patch = mask[
                y_start:y_start + patch_size,
                x_start:x_start + patch_size
            ]

            bubble_ratio = mask_patch.mean()

            patch_record = {
                "image": image_patch,
                "mask": mask_patch,
                "y_start": y_start,
                "x_start": x_start,
                "bubble_ratio": bubble_ratio,
            }

            if bubble_ratio >= high_threshold:
                patch_record["category"] = "positive"
                pos_patches.append(patch_record)

            elif bubble_ratio >= low_threshold:
                patch_record["category"] = "weak"
                weak_patches.append(patch_record)

            else:
                patch_record["category"] = "negative"
                neg_patches.append(patch_record)

    return pos_patches, weak_patches, neg_patches

# %%
SEED = 42
np.random.seed(SEED)

pos, weak, neg = extract_patches(image, mask, patch_size=PATCH_SIZE, stride=STRIDE, low_threshold=LOW_THRESHOLD, high_threshold=HIGH_THRESHOLD)

print(f"Positive patches: {len(pos)}")
print(f"Weak patches: {len(weak)}")
print(f"Negative patches: {len(neg)}")
# Out:
# Positive patches: 114
# Weak patches: 10
# Negative patches: 12

# %%
# spatial split: patches are assigned by sky position, not array index
val_regions = pd.read_csv(VAL_REGIONS_PATH)

def assign_split(y, x, patch_size=PATCH_SIZE):
    for _, region in val_regions.iterrows():
        y0, x0 = region.y_start, region.x_start
        y1, x1 = y0 + region.height, x0 + region.width
        if y >= y0 and y + patch_size <= y1 and x >= x0 and x + patch_size <= x1:
            return "val"        # fully inside an exam region
        if not (y + patch_size <= y0 or y >= y1 or x + patch_size <= x0 or x >= x1):
            return "excluded"   # straddles an exam boundary: used by neither side
    return "train"

for record in pos + weak + neg:
    record["split"] = assign_split(record["y_start"], record["x_start"])

# balancing only applies to the training pool; every val patch is always kept
pos_train = [r for r in pos if r["split"] == "train"]
weak_train = [r for r in weak if r["split"] == "train"]
neg_train = [r for r in neg if r["split"] == "train"]

np.random.shuffle(weak_train)
np.random.shuffle(neg_train)

n_positive = len(pos_train)
n_weak = min(len(weak_train), n_positive)
n_neg = min(len(neg_train), n_positive // 2)

val_patches = [r for r in pos + weak + neg if r["split"] == "val"]
dataset = pos_train + weak_train[:n_weak] + neg_train[:n_neg] + val_patches

np.random.shuffle(dataset)

n_excluded = sum(r["split"] == "excluded" for r in pos + weak + neg)
print(f"Dataset: {len(dataset)} "
      f"(train {len(dataset) - len(val_patches)}, val {len(val_patches)}, "
      f"excluded {n_excluded} dropped at exam boundaries)")
# Out:
# Dataset: 117 (train 96, val 21, excluded 19 dropped at exam boundaries)

# %%
X = np.array(
    [record["image"] for record in dataset],
    dtype=np.float32
)

Y = np.array(
    [record["mask"] for record in dataset],
    dtype=np.float32
)

X = X[..., np.newaxis]
Y = Y[..., np.newaxis]

print("X shape:", X.shape)
print("Y shape:", Y.shape)

assert X.shape == Y.shape
assert X.ndim == 4
# Out:
# X shape: (117, 256, 256, 1)
# Y shape: (117, 256, 256, 1)

# %%
# sanity check

for i in range(10):

    plt.figure(figsize=(15,6))

    plt.subplot(1,3,1)
    plt.imshow(X[i].squeeze(), cmap="gray")
    plt.title("Image patch")

    plt.subplot(1,3,2)
    plt.imshow(Y[i].squeeze(), cmap="gray")
    plt.title("Mask patch")

    plt.subplot(1,3,3)
    plt.imshow(X[i].squeeze(), cmap="gray")
    plt.imshow(Y[i].squeeze(), alpha=0.35)
    plt.title("Filled-mask overlay")
    
    plt.show()

# %%
metadata = pd.DataFrame([
    {
        "patch_id": patch_id,
        "y_start": record["y_start"],
        "x_start": record["x_start"],
        "category": record["category"],
        "bubble_ratio": record["bubble_ratio"],
        "split": record["split"],
    }
    for patch_id, record in enumerate(dataset)
])

metadata.head()
# Out:
#    patch_id  y_start  x_start  category  bubble_ratio  split
# 0         0      640      256  positive      0.081970  train
# 1         1      768     1280  positive      0.219894  train
# 2         2      384      896  positive      0.193604  train
# 3         3      512      384  positive      0.192490  train
# 4         4      128      512  positive      0.347565    val

# %%
assert len(metadata) == len(X), (
    f"Metadata has {len(metadata)} rows, "
    f"but X has {len(X)} patches."
)

assert np.array_equal(
    metadata["patch_id"].to_numpy(),
    np.arange(len(X))
), "Patch IDs do not correspond to the X/Y array positions."

print("Number of patches:", len(X))
print("Number of metadata rows:", len(metadata))
print("Unique patch IDs:", metadata["patch_id"].nunique())
# Out:
# Number of patches: 117
# Number of metadata rows: 117
# Unique patch IDs: 117

# %%
metadata.to_csv(metadata_path, index=False)

print("Saved metadata to:", metadata_path)
# Out:
# Saved metadata to: ../data/processed/patches/patchMetadata.csv

# %%
np.save(os.path.join(OUTPUT_DIR, "X.npy"), X)
np.save(os.path.join(OUTPUT_DIR, "Y.npy"), Y)

print("Saved complete patch datasets.")
# Out:
# Saved complete patch datasets.
